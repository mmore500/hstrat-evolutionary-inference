# %%
import itertools as it
import os

from cliffs_delta import cliffs_delta
from iterpop import iterpop as ip
from matplotlib import pyplot as plt
from nbmetalog import nbmetalog as nbm
import numpy as np
import pandas as pd
from scipy import stats as scipy_stats
import seaborn as sns
from teeplot import teeplot as tp

from pylib import describe_effect

# %%
# prints metadata about notebook runtime
nbm.print_metadata()
# Out:
# context: ci
# hostname: fv-az801-737
# interpreter: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# nbcellexec: null
# nbname: perfect-tree-phylometrics
# nbpath: /home/runner/work/hstrat-evolutionary-inference/hstrat-evolutionary-inference/binder/avida-splayed/perfect-tree-phylometrics.ipynb
# revision: null
# session: c8d4fb43-fdee-4313-8291-e3132f1e26da
# timestamp: 2024-03-25T23:49:38Z00:00
#
#
# IPython==8.13.0
# keyname==0.5.2
# yaml==6.0
# iterpop==0.4.1
# matplotlib==3.7.1
# nbmetalog==0.2.6
# numpy==1.21.6
# pandas==1.3.5
# scipy==1.7.3
# seaborn==0.12.1
# teeplot==1.0.1
# re==2.2.1
# comm==0.2.2
# logging==0.5.1.2
# psutil==5.9.8
# zmq==24.0.1
# json==2.0.9
# ipykernel==6.29.3

# %%
df = pd.read_csv("https://osf.io/652sy/download")
dfdigest = np.bitwise_xor.reduce(
    pd.util.hash_pandas_object(df),
)
print("{:x}".format(dfdigest))
df
# Out:
# 5fb6feda4c9a5259
#                         a  epoch mut_distn             treatment  seed  \
# 0     collapsed-phylogeny      0   default         spatial_plain   285
# 1     collapsed-phylogeny      0   default          ecology_rich    33
# 2     collapsed-phylogeny      0   default      selection_strong   134
# 3     collapsed-phylogeny      0   default  spatial_ecology_rich   187
# 4     collapsed-phylogeny      0   default         spatial_plain   294
# ...                   ...    ...       ...                   ...   ...
# 1495   reconstructed-tree      0   default  spatial_ecology_weak   263
# 1496   reconstructed-tree      0   default        selection_weak   154
# 1497   reconstructed-tree      0   default                 plain    16
# 1498   reconstructed-tree      0   default  spatial_ecology_rich   195
# 1499   reconstructed-tree      0   default          ecology_rich    40
#
#       phylogeny-snapshot-100000.csv  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 1495                            NaN
# 1496                            NaN
# 1497                            NaN
# 1498                            NaN
# 1499                            NaN
#
#                                                       _  colless_like_index  \
# 0     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        14547.062036
# 1     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        21377.279536
# 2     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20065.836953
# 3     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15924.842182
# 4     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20467.689495
# ...                                                 ...                 ...
# 1495  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15140.272932
# 1496  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        18601.307687
# 1497  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        16506.571577
# 1498  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        14050.806040
# 1499  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        12786.565184
#
#       average_depth  average_origin_time  ...  \
# 0               inf         99867.606183  ...
# 1               inf         99840.501329  ...
# 2               inf         99881.033582  ...
# 3               inf         99765.448969  ...
# 4               inf         99884.075214  ...
# ...             ...                  ...  ...
# 1495      30.106327         99876.986791  ...
# 1496      31.370884         99888.553148  ...
# 1497      30.177863         99884.039235  ...
# 1498      24.826365         99774.839237  ...
# 1499      26.786413         99788.413315  ...
#
#       variance_pairwise_distance_branch_only  mrca_depth  sackin_index  \
# 0                                  46.616294           1         34635
# 1                                  60.946211           1         46980
# 2                                  49.649800           1         43928
# 3                                  33.945309           1         40208
# 4                                 115.576998           1         40465
# ...                                      ...         ...           ...
# 1495                               27.683607           1         23076
# 1496                               32.479546           1         27151
# 1497                               34.083522           1         27401
# 1498                               26.367311           0         27268
# 1499                               30.064919           1         24643
#
#       mean_evolutionary_distinctiveness  sum_evolutionary_distinctiveness  \
# 0                            133.976702                     320070.339908
# 1                            183.463632                     541768.104932
# 2                            122.695857                     343671.095395
# 3                            309.312889                     901337.757694
# 4                             84.873983                     180611.835443
# ...                                 ...                               ...
# 1495                         184.833007                     283349.000000
# 1496                         161.257366                     279136.500000
# 1497                         168.551211                     306089.000000
# 1498                         485.414904                     986848.500000
# 1499                         406.891576                     748680.500000
#
#       variance_evolutionary_distinctiveness  resolution  subsampling-fraction  \
# 0                               7650.381356         NaN                   NaN
# 1                              31659.583125         NaN                   NaN
# 2                               9794.843999         NaN                   NaN
# 3                              30320.539630         NaN                   NaN
# 4                              10889.881433         NaN                   NaN
# ...                                     ...         ...                   ...
# 1495                           15979.575234       100.0                   1.0
# 1496                           10477.952430        33.0                   1.0
# 1497                            9983.297787        33.0                   1.0
# 1498                           37193.321937         3.0                   1.0
# 1499                           16038.397320        33.0                   1.0
#
#       trie-postprocess      ext
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...                ...      ...
# 1495             naive  .csv.gz
# 1496             naive  .csv.gz
# 1497             naive  .csv.gz
# 1498             naive  .csv.gz
# 1499             naive  .csv.gz
#
# [1500 rows x 36 columns]

# %%
# phylometrics whittled down to descriptive, non-redundant set
df["colless-like index"] = df["colless_like_index"]
df["mean pairwise distance"] = df["mean_pairwise_distance"]
df["sum distance"] = df["sum_distance"]
df["mean evolutionary distinctiveness"] = df[
    "mean_evolutionary_distinctiveness"
]

phylometrics = [
    #     'diversity',
    "colless-like index",
    #     'average_depth',
    #     'average_origin_time',
    #     'average_origin_time_normalized',
    #     'max_depth',
    "mean pairwise distance",
    #     'mean_pairwise_distance_branch_only',
    #     'num_active',
    "sum distance",
    # "num_ancestors",
    #     'num_outside',
    #     'num_roots',
    #     'num_taxa',
    #     'phylogenetic_diversity',
    #     'sum_pairwise_distance',
    #     'sum_pairwise_distance_branch_only',
    #     'total_orgs',
    #     'tree_size',
    #     'variance_pairwise_distance',
    #     'variance_pairwise_distance_branch_only',
    #     'mrca_depth',
    #     'sackin_index',
    "mean evolutionary distinctiveness",
    #     'sum_evolutionary_distinctiveness',
    #     'variance_evolutionary_distinctiveness',
]

# %%
methodological_variables = [
    "resolution",
]

# %%
evolutionary_variables = [
    "num_islands",
    "num_niches",
    "tournament_size",
    "p_niche_invasion",
]

# %%
sensitivity_analysis_variables = [
    "epoch",
    "mut_distn",
]

# %%
fixed_variables = [
    "subsampling-fraction",  # only use 1.0
    "trie-postprocess",  # just use naive postprocessing for now
]

# %%
# ensure fixed variables
df = df[
    ((df["subsampling-fraction"] == 1.0) | df["subsampling-fraction"].isna())
    & ((df["trie-postprocess"] == "naive") | df["trie-postprocess"].isna())
].copy()

for fixed_variable in fixed_variables:
    assert len(df[fixed_variable].dropna().unique()) == 1

df
# Out:
#                         a  epoch mut_distn             treatment  seed  \
# 0     collapsed-phylogeny      0   default         spatial_plain   285
# 1     collapsed-phylogeny      0   default          ecology_rich    33
# 2     collapsed-phylogeny      0   default      selection_strong   134
# 3     collapsed-phylogeny      0   default  spatial_ecology_rich   187
# 4     collapsed-phylogeny      0   default         spatial_plain   294
# ...                   ...    ...       ...                   ...   ...
# 1495   reconstructed-tree      0   default  spatial_ecology_weak   263
# 1496   reconstructed-tree      0   default        selection_weak   154
# 1497   reconstructed-tree      0   default                 plain    16
# 1498   reconstructed-tree      0   default  spatial_ecology_rich   195
# 1499   reconstructed-tree      0   default          ecology_rich    40
#
#       phylogeny-snapshot-100000.csv  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 1495                            NaN
# 1496                            NaN
# 1497                            NaN
# 1498                            NaN
# 1499                            NaN
#
#                                                       _  colless_like_index  \
# 0     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        14547.062036
# 1     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        21377.279536
# 2     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20065.836953
# 3     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15924.842182
# 4     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20467.689495
# ...                                                 ...                 ...
# 1495  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15140.272932
# 1496  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        18601.307687
# 1497  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        16506.571577
# 1498  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        14050.806040
# 1499  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        12786.565184
#
#       average_depth  average_origin_time  ...  \
# 0               inf         99867.606183  ...
# 1               inf         99840.501329  ...
# 2               inf         99881.033582  ...
# 3               inf         99765.448969  ...
# 4               inf         99884.075214  ...
# ...             ...                  ...  ...
# 1495      30.106327         99876.986791  ...
# 1496      31.370884         99888.553148  ...
# 1497      30.177863         99884.039235  ...
# 1498      24.826365         99774.839237  ...
# 1499      26.786413         99788.413315  ...
#
#       sum_evolutionary_distinctiveness  variance_evolutionary_distinctiveness  \
# 0                        320070.339908                            7650.381356
# 1                        541768.104932                           31659.583125
# 2                        343671.095395                            9794.843999
# 3                        901337.757694                           30320.539630
# 4                        180611.835443                           10889.881433
# ...                                ...                                    ...
# 1495                     283349.000000                           15979.575234
# 1496                     279136.500000                           10477.952430
# 1497                     306089.000000                            9983.297787
# 1498                     986848.500000                           37193.321937
# 1499                     748680.500000                           16038.397320
#
#       resolution  subsampling-fraction  trie-postprocess      ext  \
# 0            NaN                   NaN               NaN      NaN
# 1            NaN                   NaN               NaN      NaN
# 2            NaN                   NaN               NaN      NaN
# 3            NaN                   NaN               NaN      NaN
# 4            NaN                   NaN               NaN      NaN
# ...          ...                   ...               ...      ...
# 1495       100.0                   1.0             naive  .csv.gz
# 1496        33.0                   1.0             naive  .csv.gz
# 1497        33.0                   1.0             naive  .csv.gz
# 1498         3.0                   1.0             naive  .csv.gz
# 1499        33.0                   1.0             naive  .csv.gz
#
#       colless-like index  mean pairwise distance  sum distance  \
# 0           14547.062036               24.898421      375700.0
# 1           21377.279536               27.669175      546002.0
# 2           20065.836953               26.584946      403064.0
# 3           15924.842182               24.786206      864578.0
# 4           20467.689495               30.634396      263110.0
# ...                  ...                     ...           ...
# 1495        15140.272932               23.361504      359912.5
# 1496        18601.307687               24.251576      355733.0
# 1497        16506.571577               24.518472      379823.5
# 1498        14050.806040               24.032608      954352.5
# 1499        12786.565184               24.192511      733473.0
#
#       mean evolutionary distinctiveness
# 0                            133.976702
# 1                            183.463632
# 2                            122.695857
# 3                            309.312889
# 4                             84.873983
# ...                                 ...
# 1495                         184.833007
# 1496                         161.257366
# 1497                         168.551211
# 1498                         485.414904
# 1499                         406.891576
#
# [1500 rows x 40 columns]

# %%
# exclude extraneous variable values
df = df[(df["a"] == "collapsed-phylogeny")].copy()

df
# Out:
#                        a  epoch mut_distn             treatment  seed  \
# 0    collapsed-phylogeny      0   default         spatial_plain   285
# 1    collapsed-phylogeny      0   default          ecology_rich    33
# 2    collapsed-phylogeny      0   default      selection_strong   134
# 3    collapsed-phylogeny      0   default  spatial_ecology_rich   187
# 4    collapsed-phylogeny      0   default         spatial_plain   294
# ..                   ...    ...       ...                   ...   ...
# 295  collapsed-phylogeny      0   default         spatial_plain   292
# 296  collapsed-phylogeny      0   default  spatial_ecology_weak   253
# 297  collapsed-phylogeny      0   default  spatial_ecology_weak   251
# 298  collapsed-phylogeny      0   default        selection_weak   176
# 299  collapsed-phylogeny      0   default          ecology_some    69
#
#      phylogeny-snapshot-100000.csv  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 295                            NaN
# 296                            NaN
# 297                            NaN
# 298                            NaN
# 299                            NaN
#
#                                                      _  colless_like_index  \
# 0    /mnt/home/mmore500/scratch/data/hstrat-evoluti...        14547.062036
# 1    /mnt/home/mmore500/scratch/data/hstrat-evoluti...        21377.279536
# 2    /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20065.836953
# 3    /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15924.842182
# 4    /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20467.689495
# ..                                                 ...                 ...
# 295  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        14952.741746
# 296  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        13095.289994
# 297  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        18163.734918
# 298  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        22529.256824
# 299  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15826.611561
#
#      average_depth  average_origin_time  ...  \
# 0              inf         99867.606183  ...
# 1              inf         99840.501329  ...
# 2              inf         99881.033582  ...
# 3              inf         99765.448969  ...
# 4              inf         99884.075214  ...
# ..             ...                  ...  ...
# 295            inf         99898.391919  ...
# 296            inf         99838.996152  ...
# 297            inf         99798.675230  ...
# 298            inf         99890.485099  ...
# 299            inf         99873.799049  ...
#
#      sum_evolutionary_distinctiveness  variance_evolutionary_distinctiveness  \
# 0                       320070.339908                            7650.381356
# 1                       541768.104932                           31659.583125
# 2                       343671.095395                            9794.843999
# 3                       901337.757694                           30320.539630
# 4                       180611.835443                           10889.881433
# ..                                ...                                    ...
# 295                     204831.841956                            2767.537331
# 296                     504736.753488                           18322.511901
# 297                     759251.725067                           23843.012537
# 298                     294464.455058                            6780.211503
# 299                     382792.001050                            5340.933959
#
#      resolution  subsampling-fraction  trie-postprocess  ext  \
# 0           NaN                   NaN               NaN  NaN
# 1           NaN                   NaN               NaN  NaN
# 2           NaN                   NaN               NaN  NaN
# 3           NaN                   NaN               NaN  NaN
# 4           NaN                   NaN               NaN  NaN
# ..          ...                   ...               ...  ...
# 295         NaN                   NaN               NaN  NaN
# 296         NaN                   NaN               NaN  NaN
# 297         NaN                   NaN               NaN  NaN
# 298         NaN                   NaN               NaN  NaN
# 299         NaN                   NaN               NaN  NaN
#
#      colless-like index  mean pairwise distance  sum distance  \
# 0          14547.062036               24.898421      375700.0
# 1          21377.279536               27.669175      546002.0
# 2          20065.836953               26.584946      403064.0
# 3          15924.842182               24.786206      864578.0
# 4          20467.689495               30.634396      263110.0
# ..                  ...                     ...           ...
# 295        14952.741746               24.425292      284830.0
# 296        13095.289994               24.446645      546648.0
# 297        18163.734918               24.771554      762456.0
# 298        22529.256824               26.310692      359234.0
# 299        15826.611561               26.183827      392978.0
#
#      mean evolutionary distinctiveness
# 0                           133.976702
# 1                           183.463632
# 2                           122.695857
# 3                           309.312889
# 4                            84.873983
# ..                                 ...
# 295                          87.199592
# 296                         187.425456
# 297                         261.090690
# 298                         104.642663
# 299                         147.511368
#
# [300 rows x 40 columns]

# %%
df["a"].unique()
# Out:
# array(['collapsed-phylogeny'], dtype=object)

# %%
df["regime"] = df["treatment"].map(
    {
        "plain": "plain",
        "selection_weak": "weak selection",
        "selection_strong": "strong selection",
        "spatial_plain": "spatial structure",
        "ecology_some": "ecology",
        "ecology_rich": "rich ecology",
        "spatial_ecology_rich": "rich ecology, spatial",
        "spatial_ecology_some": "ecology, spatial",
        "ecology_weak": "weak ecology",
        "spatial_ecology_weak": "weak ecology, spatial",
    },
)
df["regime"].unique()
# Out:
# array(['spatial structure', 'rich ecology', 'strong selection',
#        'rich ecology, spatial', 'plain', 'ecology, spatial',
#        'weak ecology', 'weak ecology, spatial', 'ecology',
#        'weak selection'], dtype=object)

# %%
df[df["a"] == "collapsed-phylogeny"]["regime"].unique()
# Out:
# array(['spatial structure', 'rich ecology', 'strong selection',
#        'rich ecology, spatial', 'plain', 'ecology, spatial',
#        'weak ecology', 'weak ecology, spatial', 'ecology',
#        'weak selection'], dtype=object)

# %% [markdown]
# # Phylometrics by Regime, Perfect Data

# %%
melted_df = df[(df["a"] == "collapsed-phylogeny")].melt(
    id_vars=(
        # evolutionary_variables
        # methodological_variables
        sensitivity_analysis_variables
        + ["regime"]
    ),
    value_vars=phylometrics,
)
melted_df["phylometric"] = melted_df["variable"]
melted_df
# Out:
#       epoch mut_distn                 regime  \
# 0         0   default      spatial structure
# 1         0   default           rich ecology
# 2         0   default       strong selection
# 3         0   default  rich ecology, spatial
# 4         0   default      spatial structure
# ...     ...       ...                    ...
# 1195      0   default      spatial structure
# 1196      0   default  weak ecology, spatial
# 1197      0   default  weak ecology, spatial
# 1198      0   default         weak selection
# 1199      0   default                ecology
#
#                                variable         value  \
# 0                    colless-like index  14547.062036
# 1                    colless-like index  21377.279536
# 2                    colless-like index  20065.836953
# 3                    colless-like index  15924.842182
# 4                    colless-like index  20467.689495
# ...                                 ...           ...
# 1195  mean evolutionary distinctiveness     87.199592
# 1196  mean evolutionary distinctiveness    187.425456
# 1197  mean evolutionary distinctiveness    261.090690
# 1198  mean evolutionary distinctiveness    104.642663
# 1199  mean evolutionary distinctiveness    147.511368
#
#                             phylometric
# 0                    colless-like index
# 1                    colless-like index
# 2                    colless-like index
# 3                    colless-like index
# 4                    colless-like index
# ...                                 ...
# 1195  mean evolutionary distinctiveness
# 1196  mean evolutionary distinctiveness
# 1197  mean evolutionary distinctiveness
# 1198  mean evolutionary distinctiveness
# 1199  mean evolutionary distinctiveness
#
# [1200 rows x 6 columns]

# %%
def make_do_plot(plotter):
    def do_plot(data, col, x, y):
        g = sns.FacetGrid(
            data,
            col=col,
            sharex=False,
        ).set_titles(template="{col_name}")
        g.map(
            plotter,
            x,
            y,
            order=[
                "plain",
                "weak selection",
                "strong selection",
                "spatial structure",
                "weak ecology",
                "ecology",
                "rich ecology",
            ],
            palette=sns.color_palette("Set2", 7),
        )

    return do_plot


for viz, (group, group_df) in it.product(
    [
        sns.barplot,
        sns.boxplot,
        sns.violinplot,
    ],
    melted_df.groupby(sensitivity_analysis_variables),
):
    do_plot = make_do_plot(viz)
    do_plot.__name__ = viz.__name__
    tp.tee(
        do_plot,
        data=group_df,
        col="phylometric",
        x="value",
        y="regime",
        teeplot_outattrs=dict(
            zip(sensitivity_analysis_variables, group),
        ),
    )
# Out:
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=barplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=barplot+x=value+y=regime+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=boxplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=boxplot+x=value+y=regime+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=violinplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=violinplot+x=value+y=regime+ext=.png

# %% [markdown]
# ## With space

# %%
def make_do_plot(plotter):
    def do_plot(data, col, x, y):
        g = sns.FacetGrid(
            data,
            col=col,
            sharex=False,
        ).set_titles(template="{col_name}")
        g.map(
            plotter,
            x,
            y,
            order=[
                "spatial structure",
                "weak ecology, spatial",
                "ecology, spatial",
                "rich ecology, spatial",
            ],
            palette=sns.color_palette("Set2", 4),
        )
        g.set(
            yticklabels=[
                "plain",
                "weak ecology",
                "ecology",
                "rich ecology",
            ],
        )

    return do_plot


for viz, (group, group_df) in it.product(
    [
        sns.barplot,
        sns.boxplot,
        sns.violinplot,
    ],
    melted_df.groupby(sensitivity_analysis_variables),
):
    do_plot = make_do_plot(viz)
    do_plot.__name__ = viz.__name__
    tp.tee(
        do_plot,
        data=group_df,
        col="phylometric",
        x="value",
        y="regime",
        teeplot_outattrs={
            "spatial": "true",
            **dict(zip(sensitivity_analysis_variables, group)),
        },
    )
# Out:
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=barplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=barplot+x=value+y=regime+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=boxplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=boxplot+x=value+y=regime+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=violinplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=violinplot+x=value+y=regime+ext=.png

# %% [markdown]
# # regime heatmap signatures

# %%
for (group, group_df) in df[
    df["regime"].isin(
        [
            "plain",
            "weak selection",
            "strong selection",
            "spatial structure",
            "weak ecology",
            "ecology",
            "rich ecology",
        ],
    )
].groupby(sensitivity_analysis_variables):

    fil = (
        group_df[(group_df["a"] == "collapsed-phylogeny")]
        .copy()
        .dropna(subset=["regime"])
    )

    melted_df = fil.melt(
        id_vars=["regime"],
        value_vars=phylometrics,
    )
    melted_df["phylometric"] = melted_df["variable"]

    def calc_cliffs_delta(group) -> float:
        phylometric, regime = group.name
        return -cliffs_delta(
            fil[fil["regime"] == "plain"][phylometric],
            fil[fil["regime"] == regime][phylometric],
        )[0]

    melted_df = melted_df.groupby(["phylometric", "regime"]).apply(
        calc_cliffs_delta,
    ).reset_index(name="value")

    fig, ax = plt.subplots(figsize=(15, 2))

    matrix = melted_df.pivot(
        index="phylometric",
        columns="regime",
        values="value",
    )
    matrix = matrix[
        sorted(
            matrix.columns,
            key=[
                "plain",
                "weak selection",
                "strong selection",
                "spatial structure",
                "weak ecology",
                "ecology",
                "rich ecology",
            ].index,
        )
    ]

    annot = []
    for metric, row in matrix.iterrows():

        def getvec(regime: str) -> np.array:
            return fil[fil["regime"] == regime][metric].to_numpy()

        annot.append(
            [
                describe_effect(getvec("plain"), getvec(regime))
                for regime in matrix.columns
            ],
        )

    tp.tee(
        sns.heatmap,
        matrix,
        annot=annot,
        fmt="",
        linewidths=2,
        cmap=sns.color_palette("vlag", as_cmap=True),
        center=0,
        cbar_kws={"label": "Cliff's delta"},
        teeplot_outattrs={
            **dict(
                zip(sensitivity_analysis_variables, group),
            ),
            **{
                "x": "regime",
                "y": "phylometric",
            },
        },
        teeplot_outexclude=["fmt"],
        vmin=-1,
        vmax=1,
    )
# Out:
# teeplots/epoch=0+mut_distn=default+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+viz=heatmap+x=regime+y=phylometric+ext=.png

# %% [markdown]
# ## regime heatmap signatures, with space

# %%
for (group, group_df) in df[
    df["regime"].isin(
        [
            "spatial structure",
            "weak ecology, spatial",
            "ecology, spatial",
            "rich ecology, spatial",
        ],
    )
].groupby(sensitivity_analysis_variables):

    fil = (
        group_df[(group_df["a"] == "collapsed-phylogeny")]
        .copy()
        .dropna(subset=["regime"])
    )
    fil["regime"] = fil["regime"].map(
        {
            "spatial structure": "plain",
            "weak ecology, spatial": "weak ecology",
            "ecology, spatial": "ecology",
            "rich ecology, spatial": "rich ecology",
        }
    )

    melted_df = fil.melt(
        id_vars=["regime"],
        value_vars=phylometrics,
    )
    melted_df["phylometric"] = melted_df["variable"]

    def calc_cliffs_delta(group) -> float:
        phylometric, regime = group.name
        return -cliffs_delta(
            fil[fil["regime"] == "plain"][phylometric],
            fil[fil["regime"] == regime][phylometric],
        )[0]

    melted_df = melted_df.groupby(["phylometric", "regime"]).apply(
        calc_cliffs_delta,
    ).reset_index(name="value")

    fig, ax = plt.subplots(figsize=(15, 2))

    matrix = melted_df.pivot(
        index="phylometric",
        columns="regime",
        values="value",
    )
    matrix = matrix[
        sorted(
            matrix.columns,
            key=[
                "plain",
                "weak ecology",
                "ecology",
                "rich ecology",
            ].index,
        )
    ]

    annot = []
    for metric, row in matrix.iterrows():

        def getvec(regime: str) -> np.array:
            return fil[fil["regime"] == regime][metric].to_numpy()

        annot.append(
            [
                describe_effect(getvec("plain"), getvec(regime))
                for regime in matrix.columns
            ],
        )

    tp.tee(
        sns.heatmap,
        matrix,
        annot=annot,
        fmt="",
        linewidths=2,
        cmap=sns.color_palette("vlag", as_cmap=True),
        center=0,
        cbar_kws={"label": "Clff's delta"},
        teeplot_outattrs={
            **dict(
                zip(sensitivity_analysis_variables, group),
            ),
            **{
                "x": "regime",
                "y": "phylometric",
                "spatial": "true",
            },
        },
        teeplot_outexclude=["fmt"],
        vmin=-1,
        vmax=1,
    )
# Out:
# teeplots/epoch=0+mut_distn=default+spatial=true+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+spatial=true+viz=heatmap+x=regime+y=phylometric+ext=.png

# %% [markdown]
# # stats: kruskal-wallis

# %%
records = []
for phylometric in phylometrics:
    for group, group_df in df.groupby(
        sensitivity_analysis_variables, as_index=False
    ):
        kw_result, n = scipy_stats.kruskal(
            *(
                quality_series
                for quality, quality_series in group_df.groupby(["regime"])[
                    phylometric
                ]
            )
        ), ip.pophomogeneous(group_df.groupby(["regime"]).count()["a"])
        records.append(
            {
                **{
                    "n": n,
                    "N": len([*group_df.groupby(["regime"])]),
                    "phylometric": phylometric,
                },
                **dict(zip(["statistic", "p"], kw_result)),
                **dict(zip(sensitivity_analysis_variables, group)),
            }
        )

with pd.option_context("display.max_colwidth", None, "display.max_rows", None):
    out_df = (
        pd.DataFrame.from_records(records)
        .sort_values(
            sensitivity_analysis_variables,
        )
        .reset_index(drop=True)
    )
    display(out_df)
    os.makedirs("outdata", exist_ok=True)
    out_df.to_csv(
        "outdata/a=phylostatistics-comparison-between-regimes-kwallis+ext=.csv",
        index=False,
    )
# Out:
#     n   N                        phylometric   statistic             p  epoch  \
# 0  30  10                 colless-like index  129.709648  1.360707e-23      0
# 1  30  10             mean pairwise distance  117.893617  3.604132e-21      0
# 2  30  10                       sum distance  154.237262  1.167122e-28      0
# 3  30  10  mean evolutionary distinctiveness  169.783654  6.845348e-32      0
#
#   mut_distn
# 0   default
# 1   default
# 2   default
# 3   default

# %% [markdown]
# # stats: wilcoxon all pairs

# %%
records = []
for phylometric in phylometrics:
    for group, group_df in df.groupby(
        sensitivity_analysis_variables, as_index=False
    ):
        for regime1, regime2 in it.combinations(
            group_df["regime"].unique(), 2
        ):
            kw_result, n = scipy_stats.wilcoxon(
                group_df[group_df["regime"] == regime1][phylometric],
                group_df[group_df["regime"] == regime2][phylometric],
            ), ip.pophomogeneous(group_df.groupby(["regime"]).count()["a"])
            records.append(
                {
                    **{
                        "regime1": regime1,
                        "regime2": regime2,
                        "n": n,
                        "phylometric": phylometric,
                    },
                    **dict(zip(["statistic", "p"], kw_result)),
                    **dict(zip(sensitivity_analysis_variables, group)),
                }
            )

with pd.option_context("display.max_colwidth", None, "display.max_rows", None):
    out_df = (
        pd.DataFrame.from_records(records)
        .sort_values(
            [*sensitivity_analysis_variables, "regime1", "regime2"],
        )
        .reset_index(drop=True)
    )
    display(out_df)
    os.makedirs("outdata", exist_ok=True)
    out_df.to_csv(
        "outdata/a=phylostatistics-comparison-between-regimes-allpairs-wilcox+ext=.csv",
        index=False,
    )
# Out:
#                    regime1                regime2   n  \
# 0                  ecology         weak selection  30
# 1                  ecology         weak selection  30
# 2                  ecology         weak selection  30
# 3                  ecology         weak selection  30
# 4         ecology, spatial                ecology  30
# 5         ecology, spatial                ecology  30
# 6         ecology, spatial                ecology  30
# 7         ecology, spatial                ecology  30
# 8         ecology, spatial           weak ecology  30
# 9         ecology, spatial           weak ecology  30
# 10        ecology, spatial           weak ecology  30
# 11        ecology, spatial           weak ecology  30
# 12        ecology, spatial  weak ecology, spatial  30
# 13        ecology, spatial  weak ecology, spatial  30
# 14        ecology, spatial  weak ecology, spatial  30
# 15        ecology, spatial  weak ecology, spatial  30
# 16        ecology, spatial         weak selection  30
# 17        ecology, spatial         weak selection  30
# 18        ecology, spatial         weak selection  30
# 19        ecology, spatial         weak selection  30
# 20                   plain                ecology  30
# 21                   plain                ecology  30
# 22                   plain                ecology  30
# 23                   plain                ecology  30
# 24                   plain       ecology, spatial  30
# 25                   plain       ecology, spatial  30
# 26                   plain       ecology, spatial  30
# 27                   plain       ecology, spatial  30
# 28                   plain           weak ecology  30
# 29                   plain           weak ecology  30
# 30                   plain           weak ecology  30
# 31                   plain           weak ecology  30
# 32                   plain  weak ecology, spatial  30
# 33                   plain  weak ecology, spatial  30
# 34                   plain  weak ecology, spatial  30
# 35                   plain  weak ecology, spatial  30
# 36                   plain         weak selection  30
# 37                   plain         weak selection  30
# 38                   plain         weak selection  30
# 39                   plain         weak selection  30
# 40            rich ecology                ecology  30
# 41            rich ecology                ecology  30
# 42            rich ecology                ecology  30
# 43            rich ecology                ecology  30
# 44            rich ecology       ecology, spatial  30
# 45            rich ecology       ecology, spatial  30
# 46            rich ecology       ecology, spatial  30
# 47            rich ecology       ecology, spatial  30
# 48            rich ecology                  plain  30
# 49            rich ecology                  plain  30
# 50            rich ecology                  plain  30
# 51            rich ecology                  plain  30
# 52            rich ecology  rich ecology, spatial  30
# 53            rich ecology  rich ecology, spatial  30
# 54            rich ecology  rich ecology, spatial  30
# 55            rich ecology  rich ecology, spatial  30
# 56            rich ecology       strong selection  30
# 57            rich ecology       strong selection  30
# 58            rich ecology       strong selection  30
# 59            rich ecology       strong selection  30
# 60            rich ecology           weak ecology  30
# 61            rich ecology           weak ecology  30
# 62            rich ecology           weak ecology  30
# 63            rich ecology           weak ecology  30
# 64            rich ecology  weak ecology, spatial  30
# 65            rich ecology  weak ecology, spatial  30
# 66            rich ecology  weak ecology, spatial  30
# 67            rich ecology  weak ecology, spatial  30
# 68            rich ecology         weak selection  30
# 69            rich ecology         weak selection  30
# 70            rich ecology         weak selection  30
# 71            rich ecology         weak selection  30
# 72   rich ecology, spatial                ecology  30
# 73   rich ecology, spatial                ecology  30
# 74   rich ecology, spatial                ecology  30
# 75   rich ecology, spatial                ecology  30
# 76   rich ecology, spatial       ecology, spatial  30
# 77   rich ecology, spatial       ecology, spatial  30
# 78   rich ecology, spatial       ecology, spatial  30
# 79   rich ecology, spatial       ecology, spatial  30
# 80   rich ecology, spatial                  plain  30
# 81   rich ecology, spatial                  plain  30
# 82   rich ecology, spatial                  plain  30
# 83   rich ecology, spatial                  plain  30
# 84   rich ecology, spatial           weak ecology  30
# 85   rich ecology, spatial           weak ecology  30
# 86   rich ecology, spatial           weak ecology  30
# 87   rich ecology, spatial           weak ecology  30
# 88   rich ecology, spatial  weak ecology, spatial  30
# 89   rich ecology, spatial  weak ecology, spatial  30
# 90   rich ecology, spatial  weak ecology, spatial  30
# 91   rich ecology, spatial  weak ecology, spatial  30
# 92   rich ecology, spatial         weak selection  30
# 93   rich ecology, spatial         weak selection  30
# 94   rich ecology, spatial         weak selection  30
# 95   rich ecology, spatial         weak selection  30
# 96       spatial structure                ecology  30
# 97       spatial structure                ecology  30
# 98       spatial structure                ecology  30
# 99       spatial structure                ecology  30
# 100      spatial structure       ecology, spatial  30
# 101      spatial structure       ecology, spatial  30
# 102      spatial structure       ecology, spatial  30
# 103      spatial structure       ecology, spatial  30
# 104      spatial structure                  plain  30
# 105      spatial structure                  plain  30
# 106      spatial structure                  plain  30
# 107      spatial structure                  plain  30
# 108      spatial structure           rich ecology  30
# 109      spatial structure           rich ecology  30
# 110      spatial structure           rich ecology  30
# 111      spatial structure           rich ecology  30
# 112      spatial structure  rich ecology, spatial  30
# 113      spatial structure  rich ecology, spatial  30
# 114      spatial structure  rich ecology, spatial  30
# 115      spatial structure  rich ecology, spatial  30
# 116      spatial structure       strong selection  30
# 117      spatial structure       strong selection  30
# 118      spatial structure       strong selection  30
# 119      spatial structure       strong selection  30
# 120      spatial structure           weak ecology  30
# 121      spatial structure           weak ecology  30
# 122      spatial structure           weak ecology  30
# 123      spatial structure           weak ecology  30
# 124      spatial structure  weak ecology, spatial  30
# 125      spatial structure  weak ecology, spatial  30
# 126      spatial structure  weak ecology, spatial  30
# 127      spatial structure  weak ecology, spatial  30
# 128      spatial structure         weak selection  30
# 129      spatial structure         weak selection  30
# 130      spatial structure         weak selection  30
# 131      spatial structure         weak selection  30
# 132       strong selection                ecology  30
# 133       strong selection                ecology  30
# 134       strong selection                ecology  30
# 135       strong selection                ecology  30
# 136       strong selection       ecology, spatial  30
# 137       strong selection       ecology, spatial  30
# 138       strong selection       ecology, spatial  30
# 139       strong selection       ecology, spatial  30
# 140       strong selection                  plain  30
# 141       strong selection                  plain  30
# 142       strong selection                  plain  30
# 143       strong selection                  plain  30
# 144       strong selection  rich ecology, spatial  30
# 145       strong selection  rich ecology, spatial  30
# 146       strong selection  rich ecology, spatial  30
# 147       strong selection  rich ecology, spatial  30
# 148       strong selection           weak ecology  30
# 149       strong selection           weak ecology  30
# 150       strong selection           weak ecology  30
# 151       strong selection           weak ecology  30
# 152       strong selection  weak ecology, spatial  30
# 153       strong selection  weak ecology, spatial  30
# 154       strong selection  weak ecology, spatial  30
# 155       strong selection  weak ecology, spatial  30
# 156       strong selection         weak selection  30
# 157       strong selection         weak selection  30
# 158       strong selection         weak selection  30
# 159       strong selection         weak selection  30
# 160           weak ecology                ecology  30
# 161           weak ecology                ecology  30
# 162           weak ecology                ecology  30
# 163           weak ecology                ecology  30
# 164           weak ecology  weak ecology, spatial  30
# 165           weak ecology  weak ecology, spatial  30
# 166           weak ecology  weak ecology, spatial  30
# 167           weak ecology  weak ecology, spatial  30
# 168           weak ecology         weak selection  30
# 169           weak ecology         weak selection  30
# 170           weak ecology         weak selection  30
# 171           weak ecology         weak selection  30
# 172  weak ecology, spatial                ecology  30
# 173  weak ecology, spatial                ecology  30
# 174  weak ecology, spatial                ecology  30
# 175  weak ecology, spatial                ecology  30
# 176  weak ecology, spatial         weak selection  30
# 177  weak ecology, spatial         weak selection  30
# 178  weak ecology, spatial         weak selection  30
# 179  weak ecology, spatial         weak selection  30
#
#                            phylometric  statistic         p  epoch mut_distn
# 0                   colless-like index      102.0  0.007271      0   default
# 1               mean pairwise distance      205.0  0.571646      0   default
# 2                         sum distance      145.0  0.071903      0   default
# 3    mean evolutionary distinctiveness      114.0  0.014795      0   default
# 4                   colless-like index       33.0  0.000041      0   default
# 5               mean pairwise distance       12.0  0.000006      0   default
# 6                         sum distance       14.0  0.000007      0   default
# 7    mean evolutionary distinctiveness        6.0  0.000003      0   default
# 8                   colless-like index       16.0  0.000008      0   default
# 9               mean pairwise distance       35.0  0.000049      0   default
# 10                        sum distance       28.0  0.000026      0   default
# 11   mean evolutionary distinctiveness       20.0  0.000012      0   default
# 12                  colless-like index      223.0  0.845080      0   default
# 13              mean pairwise distance      204.0  0.557743      0   default
# 14                        sum distance      117.0  0.017518      0   default
# 15   mean evolutionary distinctiveness       99.0  0.006035      0   default
# 16                  colless-like index       20.0  0.000012      0   default
# 17              mean pairwise distance        5.0  0.000003      0   default
# 18                        sum distance        6.0  0.000003      0   default
# 19   mean evolutionary distinctiveness        3.0  0.000002      0   default
# 20                  colless-like index      188.0  0.360039      0   default
# 21              mean pairwise distance      175.0  0.236936      0   default
# 22                        sum distance       73.0  0.001036      0   default
# 23   mean evolutionary distinctiveness       63.0  0.000490      0   default
# 24                  colless-like index       14.0  0.000007      0   default
# 25              mean pairwise distance        3.0  0.000002      0   default
# 26                        sum distance        8.0  0.000004      0   default
# 27   mean evolutionary distinctiveness        4.0  0.000003      0   default
# 28                  colless-like index      199.0  0.490798      0   default
# 29              mean pairwise distance      187.0  0.349346      0   default
# 30                        sum distance      174.0  0.228880      0   default
# 31   mean evolutionary distinctiveness      156.0  0.115608      0   default
# 32                  colless-like index       64.0  0.000529      0   default
# 33              mean pairwise distance      133.0  0.040702      0   default
# 34                        sum distance       95.0  0.004682      0   default
# 35   mean evolutionary distinctiveness       75.0  0.001197      0   default
# 36                  colless-like index      209.0  0.628843      0   default
# 37              mean pairwise distance      214.0  0.703564      0   default
# 38                        sum distance      171.0  0.205888      0   default
# 39   mean evolutionary distinctiveness      169.0  0.191522      0   default
# 40                  colless-like index      203.0  0.544006      0   default
# 41              mean pairwise distance      211.0  0.658331      0   default
# 42                        sum distance        1.0  0.000002      0   default
# 43   mean evolutionary distinctiveness        1.0  0.000002      0   default
# 44                  colless-like index       26.0  0.000022      0   default
# 45              mean pairwise distance        0.0  0.000002      0   default
# 46                        sum distance      224.0  0.861213      0   default
# 47   mean evolutionary distinctiveness      154.0  0.106394      0   default
# 48                  colless-like index      153.0  0.102011      0   default
# 49              mean pairwise distance      142.0  0.062683      0   default
# 50                        sum distance        1.0  0.000002      0   default
# 51   mean evolutionary distinctiveness        1.0  0.000002      0   default
# 52                  colless-like index       37.0  0.000058      0   default
# 53              mean pairwise distance        0.0  0.000002      0   default
# 54                        sum distance        7.0  0.000004      0   default
# 55   mean evolutionary distinctiveness        6.0  0.000003      0   default
# 56                  colless-like index      149.0  0.085896      0   default
# 57              mean pairwise distance      188.0  0.360039      0   default
# 58                        sum distance        0.0  0.000002      0   default
# 59   mean evolutionary distinctiveness        0.0  0.000002      0   default
# 60                  colless-like index       71.0  0.000894      0   default
# 61              mean pairwise distance      209.0  0.628843      0   default
# 62                        sum distance        9.0  0.000004      0   default
# 63   mean evolutionary distinctiveness        8.0  0.000004      0   default
# 64                  colless-like index       79.0  0.001593      0   default
# 65              mean pairwise distance      141.0  0.059836      0   default
# 66                        sum distance      104.0  0.008217      0   default
# 67   mean evolutionary distinctiveness      129.0  0.033269      0   default
# 68                  colless-like index       92.0  0.003854      0   default
# 69              mean pairwise distance      220.0  0.797098      0   default
# 70                        sum distance        0.0  0.000002      0   default
# 71   mean evolutionary distinctiveness        0.0  0.000002      0   default
# 72                  colless-like index       37.0  0.000058      0   default
# 73              mean pairwise distance        2.0  0.000002      0   default
# 74                        sum distance        0.0  0.000002      0   default
# 75   mean evolutionary distinctiveness        0.0  0.000002      0   default
# 76                  colless-like index      211.0  0.658331      0   default
# 77              mean pairwise distance      112.0  0.013194      0   default
# 78                        sum distance        1.0  0.000002      0   default
# 79   mean evolutionary distinctiveness        3.0  0.000002      0   default
# 80                  colless-like index       17.0  0.000009      0   default
# 81              mean pairwise distance        1.0  0.000002      0   default
# 82                        sum distance        0.0  0.000002      0   default
# 83   mean evolutionary distinctiveness        0.0  0.000002      0   default
# 84                  colless-like index       12.0  0.000006      0   default
# 85              mean pairwise distance       15.0  0.000008      0   default
# 86                        sum distance        0.0  0.000002      0   default
# 87   mean evolutionary distinctiveness        0.0  0.000002      0   default
# 88                  colless-like index      225.0  0.877403      0   default
# 89              mean pairwise distance      125.0  0.027029      0   default
# 90                        sum distance       10.0  0.000005      0   default
# 91   mean evolutionary distinctiveness        8.0  0.000004      0   default
# 92                  colless-like index        4.0  0.000003      0   default
# 93              mean pairwise distance        0.0  0.000002      0   default
# 94                        sum distance        0.0  0.000002      0   default
# 95   mean evolutionary distinctiveness        0.0  0.000002      0   default
# 96                  colless-like index       61.0  0.000420      0   default
# 97              mean pairwise distance      117.0  0.017518      0   default
# 98                        sum distance      206.0  0.585712      0   default
# 99   mean evolutionary distinctiveness      225.0  0.877403      0   default
# 100                 colless-like index      192.0  0.404835      0   default
# 101             mean pairwise distance      197.0  0.465283      0   default
# 102                       sum distance       46.0  0.000125      0   default
# 103  mean evolutionary distinctiveness       36.0  0.000053      0   default
# 104                 colless-like index       24.0  0.000018      0   default
# 105             mean pairwise distance       92.0  0.003854      0   default
# 106                       sum distance      130.0  0.035009      0   default
# 107  mean evolutionary distinctiveness       86.0  0.002585      0   default
# 108                 colless-like index       42.0  0.000089      0   default
# 109             mean pairwise distance      137.0  0.049498      0   default
# 110                       sum distance       69.0  0.000771      0   default
# 111  mean evolutionary distinctiveness       73.0  0.001036      0   default
# 112                 colless-like index      191.0  0.393334      0   default
# 113             mean pairwise distance      122.0  0.023038      0   default
# 114                       sum distance        0.0  0.000002      0   default
# 115  mean evolutionary distinctiveness        0.0  0.000002      0   default
# 116                 colless-like index       37.0  0.000058      0   default
# 117             mean pairwise distance      116.0  0.016566      0   default
# 118                       sum distance      173.0  0.221022      0   default
# 119  mean evolutionary distinctiveness      104.0  0.008217      0   default
# 120                 colless-like index       12.0  0.000006      0   default
# 121             mean pairwise distance      107.0  0.009842      0   default
# 122                       sum distance      163.0  0.152861      0   default
# 123  mean evolutionary distinctiveness      136.0  0.047162      0   default
# 124                 colless-like index      196.0  0.452807      0   default
# 125             mean pairwise distance      217.0  0.749871      0   default
# 126                       sum distance      181.0  0.289477      0   default
# 127  mean evolutionary distinctiveness      162.0  0.147040      0   default
# 128                 colless-like index        3.0  0.000002      0   default
# 129             mean pairwise distance       78.0  0.001484      0   default
# 130                       sum distance      202.0  0.530440      0   default
# 131  mean evolutionary distinctiveness      151.0  0.093676      0   default
# 132                 colless-like index      177.0  0.253644      0   default
# 133             mean pairwise distance      182.0  0.298944      0   default
# 134                       sum distance       90.0  0.003379      0   default
# 135  mean evolutionary distinctiveness       61.0  0.000420      0   default
# 136                 colless-like index       20.0  0.000012      0   default
# 137             mean pairwise distance       17.0  0.000009      0   default
# 138                       sum distance        0.0  0.000002      0   default
# 139  mean evolutionary distinctiveness        1.0  0.000002      0   default
# 140                 colless-like index      225.0  0.877403      0   default
# 141             mean pairwise distance      138.0  0.051931      0   default
# 142                       sum distance      181.0  0.289477      0   default
# 143  mean evolutionary distinctiveness      189.0  0.370935      0   default
# 144                 colless-like index       21.0  0.000014      0   default
# 145             mean pairwise distance        3.0  0.000002      0   default
# 146                       sum distance        0.0  0.000002      0   default
# 147  mean evolutionary distinctiveness        0.0  0.000002      0   default
# 148                 colless-like index      162.5  0.149918      0   default
# 149             mean pairwise distance      208.0  0.614315      0   default
# 150                       sum distance      223.0  0.845080      0   default
# 151  mean evolutionary distinctiveness      177.0  0.253644      0   default
# 152                 colless-like index       74.0  0.001114      0   default
# 153             mean pairwise distance      176.0  0.245190      0   default
# 154                       sum distance       79.0  0.001593      0   default
# 155  mean evolutionary distinctiveness       43.0  0.000097      0   default
# 156                 colless-like index      172.0  0.213358      0   default
# 157             mean pairwise distance      183.0  0.308615      0   default
# 158                       sum distance      192.0  0.404835      0   default
# 159  mean evolutionary distinctiveness      177.0  0.253644      0   default
# 160                 colless-like index      111.0  0.012453      0   default
# 161             mean pairwise distance      232.0  0.991795      0   default
# 162                       sum distance      157.0  0.120445      0   default
# 163  mean evolutionary distinctiveness      157.0  0.120445      0   default
# 164                 colless-like index       57.0  0.000306      0   default
# 165             mean pairwise distance      132.0  0.038723      0   default
# 166                       sum distance      106.0  0.009271      0   default
# 167  mean evolutionary distinctiveness       84.0  0.002255      0   default
# 168                 colless-like index      190.0  0.382034      0   default
# 169             mean pairwise distance      230.0  0.958990      0   default
# 170                       sum distance      219.0  0.781264      0   default
# 171  mean evolutionary distinctiveness      222.0  0.829013      0   default
# 172                 colless-like index       88.0  0.002957      0   default
# 173             mean pairwise distance      121.0  0.021827      0   default
# 174                       sum distance      155.0  0.110926      0   default
# 175  mean evolutionary distinctiveness      128.0  0.031603      0   default
# 176                 colless-like index       56.0  0.000283      0   default
# 177             mean pairwise distance      113.0  0.013975      0   default
# 178                       sum distance      105.0  0.008730      0   default
# 179  mean evolutionary distinctiveness       61.0  0.000420      0   default
