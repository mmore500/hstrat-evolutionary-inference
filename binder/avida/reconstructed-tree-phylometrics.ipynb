# %%
import itertools as it
import os

from cliffs_delta import cliffs_delta
from iterpop import iterpop as ip
import matplotlib as mpl
from matplotlib import pyplot as plt
from nbmetalog import nbmetalog as nbm
import numpy as np
import pandas as pd
from scipy import stats as scipy_stats
import seaborn as sns
from teeplot import teeplot as tp

from pylib import describe_effect

# %%
# prints metadata about notebook runtime
nbm.print_metadata()
# Out:
# context: ci
# hostname: fv-az1055-458
# interpreter: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# nbcellexec: null
# nbname: reconstructed-tree-phylometrics
# nbpath: /home/runner/work/hstrat-evolutionary-inference/hstrat-evolutionary-inference/binder/avida/reconstructed-tree-phylometrics.ipynb
# revision: null
# session: 7911e42f-5a60-41c0-ab69-d7620f272a0f
# timestamp: 2024-03-25T18:22:30Z00:00
#
#
# IPython==8.13.0
# keyname==0.5.2
# yaml==6.0
# iterpop==0.4.1
# matplotlib==3.7.1
# nbmetalog==0.2.6
# numpy==1.21.6
# pandas==1.3.5
# scipy==1.7.3
# seaborn==0.12.1
# teeplot==1.0.1
# re==2.2.1
# comm==0.2.2
# logging==0.5.1.2
# psutil==5.9.8
# zmq==24.0.1
# json==2.0.9
# ipykernel==6.29.3

# %%
df = pd.read_csv("https://osf.io/r29ym/download")
dfdigest = np.bitwise_xor.reduce(
    pd.util.hash_pandas_object(df),
)
print("{:x}".format(dfdigest))
df
# Out:
# 3b489380fbf2cd93
#                         a  epoch mut_distn             treatment  seed  \
# 0     collapsed-phylogeny      0   default         spatial_plain   285
# 1     collapsed-phylogeny      0   default          ecology_rich    33
# 2     collapsed-phylogeny      0   default      selection_strong   134
# 3     collapsed-phylogeny      0   default  spatial_ecology_rich   187
# 4     collapsed-phylogeny      0   default         spatial_plain   294
# ...                   ...    ...       ...                   ...   ...
# 1495   reconstructed-tree      0   default  spatial_ecology_weak   263
# 1496   reconstructed-tree      0   default        selection_weak   154
# 1497   reconstructed-tree      0   default                 plain    16
# 1498   reconstructed-tree      0   default  spatial_ecology_rich   195
# 1499   reconstructed-tree      0   default          ecology_rich    40
#
#       phylogeny-snapshot-100000.csv  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 1495                            NaN
# 1496                            NaN
# 1497                            NaN
# 1498                            NaN
# 1499                            NaN
#
#                                                       _  colless_like_index  \
# 0     /mnt/home/mmore500/scratch/data/hstrat-evoluti...         5926.098427
# 1     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        10543.308321
# 2     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        11396.501006
# 3     /mnt/home/mmore500/scratch/data/hstrat-evoluti...         9234.057184
# 4     /mnt/home/mmore500/scratch/data/hstrat-evoluti...         4768.904055
# ...                                                 ...                 ...
# 1495  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         9285.949798
# 1496  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        11563.845652
# 1497  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         9159.786185
# 1498  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         7775.489944
# 1499  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         7634.605387
#
#       average_depth  average_origin_time  ...  \
# 0               inf         84179.314332  ...
# 1               inf         88309.619155  ...
# 2               inf         88690.314255  ...
# 3               inf         82468.509778  ...
# 4               inf         75041.078479  ...
# ...             ...                  ...  ...
# 1495      20.026093         99869.493162  ...
# 1496      20.759676         99891.297172  ...
# 1497      18.497247         99891.350661  ...
# 1498      15.731431         99790.826154  ...
# 1499      18.374457         99766.372352  ...
#
#       variance_pairwise_distance_branch_only  mrca_depth  sackin_index  \
# 0                                  17.528400        1924         22823
# 1                                  29.418707         808         33964
# 2                                  28.284046        2129         35801
# 3                                  22.145263         369         33834
# 4                                  16.768323        2109         15925
# ...                                      ...         ...           ...
# 1495                               20.356872           1         19460
# 1496                               22.306339           1         22477
# 1497                               18.172297           1         20469
# 1498                               16.851802           0         21343
# 1499                               23.558659           1         20882
#
#       mean_evolutionary_distinctiveness  sum_evolutionary_distinctiveness  \
# 0                            144.974328                     316333.983563
# 1                            195.984163                     537584.557873
# 2                            119.564381                     342432.387297
# 3                            310.265704                     899770.540730
# 4                            109.035642                     176528.705163
# ...                                 ...                               ...
# 1495                         184.833007                     283349.000000
# 1496                         161.257366                     279136.500000
# 1497                         168.551211                     306089.000000
# 1498                         485.414904                     986848.500000
# 1499                         406.891576                     748680.500000
#
#       variance_evolutionary_distinctiveness  resolution  subsampling-fraction  \
# 0                               7135.200693         NaN                   NaN
# 1                              15080.442755         NaN                   NaN
# 2                               7900.355343         NaN                   NaN
# 3                              28829.404468         NaN                   NaN
# 4                              11930.297151         NaN                   NaN
# ...                                     ...         ...                   ...
# 1495                           15979.575234       100.0                   1.0
# 1496                           10477.952430        33.0                   1.0
# 1497                            9983.297787        33.0                   1.0
# 1498                           37193.321937         3.0                   1.0
# 1499                           16038.397320        33.0                   1.0
#
#       trie-postprocess      ext
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...                ...      ...
# 1495             naive  .csv.gz
# 1496             naive  .csv.gz
# 1497             naive  .csv.gz
# 1498             naive  .csv.gz
# 1499             naive  .csv.gz
#
# [1500 rows x 36 columns]

# %%
# phylometrics whittled down to descriptive, non-redundant set
phylometrics = [
    #     'diversity',
    "colless_like_index",
    #     'average_depth',
    #     'average_origin_time',
    #     'average_origin_time_normalized',
    #     'max_depth',
    "mean_pairwise_distance",
    #     'mean_pairwise_distance_branch_only',
    #     'num_active',
    # "num_ancestors",
    "sum_distance",
    #     'num_outside',
    #     'num_roots',
    #     'num_taxa',
    #     'phylogenetic_diversity',
    #     'sum_pairwise_distance',
    #     'sum_pairwise_distance_branch_only',
    #     'total_orgs',
    #     'tree_size',
    #     'variance_pairwise_distance',
    #     'variance_pairwise_distance_branch_only',
    #     'mrca_depth',
    #     'sackin_index',
    "mean_evolutionary_distinctiveness",
    #     'sum_evolutionary_distinctiveness',
    #     'variance_evolutionary_distinctiveness',
]

# %%
methodological_variables = [
    "resolution",
]

# %%
evolutionary_variables = [
]

# %%
sensitivity_analysis_variables = [
    "epoch",
    "mut_distn",
]

# %%
fixed_variables = [
    "subsampling-fraction",  # only use 1.0
    "trie-postprocess",  # just use naive postprocessing for now
]

# %%
# ensure fixed variables
df = df[
    ((df["subsampling-fraction"] == 1.0) | df["subsampling-fraction"].isna())
    & ((df["trie-postprocess"] == "naive") | df["trie-postprocess"].isna())
].copy()

for fixed_variable in fixed_variables:
    assert len(df[fixed_variable].dropna().unique()) == 1

df
# Out:
#                         a  epoch mut_distn             treatment  seed  \
# 0     collapsed-phylogeny      0   default         spatial_plain   285
# 1     collapsed-phylogeny      0   default          ecology_rich    33
# 2     collapsed-phylogeny      0   default      selection_strong   134
# 3     collapsed-phylogeny      0   default  spatial_ecology_rich   187
# 4     collapsed-phylogeny      0   default         spatial_plain   294
# ...                   ...    ...       ...                   ...   ...
# 1495   reconstructed-tree      0   default  spatial_ecology_weak   263
# 1496   reconstructed-tree      0   default        selection_weak   154
# 1497   reconstructed-tree      0   default                 plain    16
# 1498   reconstructed-tree      0   default  spatial_ecology_rich   195
# 1499   reconstructed-tree      0   default          ecology_rich    40
#
#       phylogeny-snapshot-100000.csv  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 1495                            NaN
# 1496                            NaN
# 1497                            NaN
# 1498                            NaN
# 1499                            NaN
#
#                                                       _  colless_like_index  \
# 0     /mnt/home/mmore500/scratch/data/hstrat-evoluti...         5926.098427
# 1     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        10543.308321
# 2     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        11396.501006
# 3     /mnt/home/mmore500/scratch/data/hstrat-evoluti...         9234.057184
# 4     /mnt/home/mmore500/scratch/data/hstrat-evoluti...         4768.904055
# ...                                                 ...                 ...
# 1495  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         9285.949798
# 1496  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        11563.845652
# 1497  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         9159.786185
# 1498  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         7775.489944
# 1499  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         7634.605387
#
#       average_depth  average_origin_time  ...  \
# 0               inf         84179.314332  ...
# 1               inf         88309.619155  ...
# 2               inf         88690.314255  ...
# 3               inf         82468.509778  ...
# 4               inf         75041.078479  ...
# ...             ...                  ...  ...
# 1495      20.026093         99869.493162  ...
# 1496      20.759676         99891.297172  ...
# 1497      18.497247         99891.350661  ...
# 1498      15.731431         99790.826154  ...
# 1499      18.374457         99766.372352  ...
#
#       variance_pairwise_distance_branch_only  mrca_depth  sackin_index  \
# 0                                  17.528400        1924         22823
# 1                                  29.418707         808         33964
# 2                                  28.284046        2129         35801
# 3                                  22.145263         369         33834
# 4                                  16.768323        2109         15925
# ...                                      ...         ...           ...
# 1495                               20.356872           1         19460
# 1496                               22.306339           1         22477
# 1497                               18.172297           1         20469
# 1498                               16.851802           0         21343
# 1499                               23.558659           1         20882
#
#       mean_evolutionary_distinctiveness  sum_evolutionary_distinctiveness  \
# 0                            144.974328                     316333.983563
# 1                            195.984163                     537584.557873
# 2                            119.564381                     342432.387297
# 3                            310.265704                     899770.540730
# 4                            109.035642                     176528.705163
# ...                                 ...                               ...
# 1495                         184.833007                     283349.000000
# 1496                         161.257366                     279136.500000
# 1497                         168.551211                     306089.000000
# 1498                         485.414904                     986848.500000
# 1499                         406.891576                     748680.500000
#
#       variance_evolutionary_distinctiveness  resolution  subsampling-fraction  \
# 0                               7135.200693         NaN                   NaN
# 1                              15080.442755         NaN                   NaN
# 2                               7900.355343         NaN                   NaN
# 3                              28829.404468         NaN                   NaN
# 4                              11930.297151         NaN                   NaN
# ...                                     ...         ...                   ...
# 1495                           15979.575234       100.0                   1.0
# 1496                           10477.952430        33.0                   1.0
# 1497                            9983.297787        33.0                   1.0
# 1498                           37193.321937         3.0                   1.0
# 1499                           16038.397320        33.0                   1.0
#
#       trie-postprocess      ext
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...                ...      ...
# 1495             naive  .csv.gz
# 1496             naive  .csv.gz
# 1497             naive  .csv.gz
# 1498             naive  .csv.gz
# 1499             naive  .csv.gz
#
# [1500 rows x 36 columns]

# %%
# exclude extraneous variable values
df = df[(df["a"] != "consolidated-phylogeny")].copy()

df
# Out:
#                         a  epoch mut_distn             treatment  seed  \
# 0     collapsed-phylogeny      0   default         spatial_plain   285
# 1     collapsed-phylogeny      0   default          ecology_rich    33
# 2     collapsed-phylogeny      0   default      selection_strong   134
# 3     collapsed-phylogeny      0   default  spatial_ecology_rich   187
# 4     collapsed-phylogeny      0   default         spatial_plain   294
# ...                   ...    ...       ...                   ...   ...
# 1495   reconstructed-tree      0   default  spatial_ecology_weak   263
# 1496   reconstructed-tree      0   default        selection_weak   154
# 1497   reconstructed-tree      0   default                 plain    16
# 1498   reconstructed-tree      0   default  spatial_ecology_rich   195
# 1499   reconstructed-tree      0   default          ecology_rich    40
#
#       phylogeny-snapshot-100000.csv  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 1495                            NaN
# 1496                            NaN
# 1497                            NaN
# 1498                            NaN
# 1499                            NaN
#
#                                                       _  colless_like_index  \
# 0     /mnt/home/mmore500/scratch/data/hstrat-evoluti...         5926.098427
# 1     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        10543.308321
# 2     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        11396.501006
# 3     /mnt/home/mmore500/scratch/data/hstrat-evoluti...         9234.057184
# 4     /mnt/home/mmore500/scratch/data/hstrat-evoluti...         4768.904055
# ...                                                 ...                 ...
# 1495  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         9285.949798
# 1496  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        11563.845652
# 1497  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         9159.786185
# 1498  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         7775.489944
# 1499  /mnt/home/mmore500/scratch/data/hstrat-evoluti...         7634.605387
#
#       average_depth  average_origin_time  ...  \
# 0               inf         84179.314332  ...
# 1               inf         88309.619155  ...
# 2               inf         88690.314255  ...
# 3               inf         82468.509778  ...
# 4               inf         75041.078479  ...
# ...             ...                  ...  ...
# 1495      20.026093         99869.493162  ...
# 1496      20.759676         99891.297172  ...
# 1497      18.497247         99891.350661  ...
# 1498      15.731431         99790.826154  ...
# 1499      18.374457         99766.372352  ...
#
#       variance_pairwise_distance_branch_only  mrca_depth  sackin_index  \
# 0                                  17.528400        1924         22823
# 1                                  29.418707         808         33964
# 2                                  28.284046        2129         35801
# 3                                  22.145263         369         33834
# 4                                  16.768323        2109         15925
# ...                                      ...         ...           ...
# 1495                               20.356872           1         19460
# 1496                               22.306339           1         22477
# 1497                               18.172297           1         20469
# 1498                               16.851802           0         21343
# 1499                               23.558659           1         20882
#
#       mean_evolutionary_distinctiveness  sum_evolutionary_distinctiveness  \
# 0                            144.974328                     316333.983563
# 1                            195.984163                     537584.557873
# 2                            119.564381                     342432.387297
# 3                            310.265704                     899770.540730
# 4                            109.035642                     176528.705163
# ...                                 ...                               ...
# 1495                         184.833007                     283349.000000
# 1496                         161.257366                     279136.500000
# 1497                         168.551211                     306089.000000
# 1498                         485.414904                     986848.500000
# 1499                         406.891576                     748680.500000
#
#       variance_evolutionary_distinctiveness  resolution  subsampling-fraction  \
# 0                               7135.200693         NaN                   NaN
# 1                              15080.442755         NaN                   NaN
# 2                               7900.355343         NaN                   NaN
# 3                              28829.404468         NaN                   NaN
# 4                              11930.297151         NaN                   NaN
# ...                                     ...         ...                   ...
# 1495                           15979.575234       100.0                   1.0
# 1496                           10477.952430        33.0                   1.0
# 1497                            9983.297787        33.0                   1.0
# 1498                           37193.321937         3.0                   1.0
# 1499                           16038.397320        33.0                   1.0
#
#       trie-postprocess      ext
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...                ...      ...
# 1495             naive  .csv.gz
# 1496             naive  .csv.gz
# 1497             naive  .csv.gz
# 1498             naive  .csv.gz
# 1499             naive  .csv.gz
#
# [1500 rows x 36 columns]

# %%
df["a"].unique()
# Out:
# array(['collapsed-phylogeny', 'reconstructed-tree'], dtype=object)

# %%
df["regime"] = df["treatment"].map(
    {
        "plain": "plain",
        "selection_weak": "weak selection",
        "selection_strong": "strong selection",
        "spatial_plain": "spatial structure",
        "ecology_some": "ecology",
        "ecology_rich": "rich ecology",
        "spatial_ecology_rich": "rich ecology, spatial",
        "spatial_ecology_some": "ecology, spatial",
        "ecology_weak": "weak ecology",
        "spatial_ecology_weak": "weak ecology, spatial",
    },
)
df["regime"].unique()
# Out:
# array(['spatial structure', 'rich ecology', 'strong selection',
#        'rich ecology, spatial', 'plain', 'ecology, spatial',
#        'weak ecology', 'weak ecology, spatial', 'ecology',
#        'weak selection'], dtype=object)

# %%
df["quality"] = df.apply(
    lambda row: {
        ("reconstructed-tree", 3.0): "33% resolution",
        ("reconstructed-tree", 10.0): "10% resolution",
        ("reconstructed-tree", 33.0): "3% resolution",
        ("reconstructed-tree", 100.0): "1% resolution",
        ("collapsed-phylogeny", 0): "perfect resolution",
    }.get(
        tuple(row[["a", "resolution"]].fillna(0)),
        np.nan,  # default
    ),
    axis="columns",
)
df = df.dropna(axis="index", subset=["quality"]).copy()
df["quality"].unique()
# Out:
# array(['perfect resolution', '3% resolution', '1% resolution',
#        '10% resolution', '33% resolution'], dtype=object)

# %% [markdown]
# # Phylometrics by Regime, Reconstructed Data

# %%
melted_df = df[
    df["regime"].isin(
        [
            "plain",
            "weak selection",
            "strong selection",
            "spatial structure",
            "weak ecology",
            "ecology",
            "rich ecology",
        ],
    )
].melt(
    id_vars=evolutionary_variables
    + methodological_variables
    + sensitivity_analysis_variables
    + ["regime", "a", "quality"],
    value_vars=phylometrics,
)
melted_df["phylometric"] = melted_df["variable"]
melted_df
# Out:
#       resolution  epoch mut_distn             regime                    a  \
# 0            NaN      0   default  spatial structure  collapsed-phylogeny
# 1            NaN      0   default       rich ecology  collapsed-phylogeny
# 2            NaN      0   default   strong selection  collapsed-phylogeny
# 3            NaN      0   default  spatial structure  collapsed-phylogeny
# 4            NaN      0   default   strong selection  collapsed-phylogeny
# ...          ...    ...       ...                ...                  ...
# 4195       100.0      0   default            ecology   reconstructed-tree
# 4196        33.0      0   default              plain   reconstructed-tree
# 4197        33.0      0   default     weak selection   reconstructed-tree
# 4198        33.0      0   default              plain   reconstructed-tree
# 4199        33.0      0   default       rich ecology   reconstructed-tree
#
#                  quality                           variable         value  \
# 0     perfect resolution                 colless_like_index   5926.098427
# 1     perfect resolution                 colless_like_index  10543.308321
# 2     perfect resolution                 colless_like_index  11396.501006
# 3     perfect resolution                 colless_like_index   4768.904055
# 4     perfect resolution                 colless_like_index   9110.488061
# ...                  ...                                ...           ...
# 4195       1% resolution  mean_evolutionary_distinctiveness    153.198366
# 4196       3% resolution  mean_evolutionary_distinctiveness    114.919151
# 4197       3% resolution  mean_evolutionary_distinctiveness    161.257366
# 4198       3% resolution  mean_evolutionary_distinctiveness    168.551211
# 4199       3% resolution  mean_evolutionary_distinctiveness    406.891576
#
#                             phylometric
# 0                    colless_like_index
# 1                    colless_like_index
# 2                    colless_like_index
# 3                    colless_like_index
# 4                    colless_like_index
# ...                                 ...
# 4195  mean_evolutionary_distinctiveness
# 4196  mean_evolutionary_distinctiveness
# 4197  mean_evolutionary_distinctiveness
# 4198  mean_evolutionary_distinctiveness
# 4199  mean_evolutionary_distinctiveness
#
# [4200 rows x 9 columns]

# %%
def make_do_plot(plotter):
    def do_plot(data, col, row, x, y):
        g = sns.FacetGrid(
            data,
            col=col,
            row=row,
            row_order=[
                "plain",
                "weak selection",
                "strong selection",
                "spatial structure",
                "weak ecology",
                "ecology",
                "rich ecology",
            ],
            sharex="col",
            margin_titles=True,
        )
        g.map(
            plotter,
            x,
            y,
            order=[
                "33% resolution",
                "10% resolution",
                "3% resolution",
                "1% resolution",
                "perfect resolution",
            ],
            palette=sns.color_palette("Set1", 5),
        )

    return do_plot


for viz, (group, group_df) in it.product(
    [
        sns.barplot,
        sns.boxplot,
        sns.violinplot,
    ],
    melted_df.groupby(sensitivity_analysis_variables),
):
    do_plot = make_do_plot(viz)
    do_plot.__name__ = viz.__name__
    tp.tee(
        do_plot,
        data=group_df,
        col="phylometric",
        row="regime",
        x="value",
        y="quality",
        teeplot_outattrs=dict(
            zip(sensitivity_analysis_variables, group),
        ),
    )
# Out:
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=barplot+x=value+y=quality+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=barplot+x=value+y=quality+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=boxplot+x=value+y=quality+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=boxplot+x=value+y=quality+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=violinplot+x=value+y=quality+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=violinplot+x=value+y=quality+ext=.png

# %% [markdown]
# # regime heatmap signatures
#
# cliff's delta

# %%
group_variables = sensitivity_analysis_variables + ["resolution"]
for (group, group_df) in df[
    df["regime"].isin(
        [
            "plain",
            "weak selection",
            "strong selection",
            "spatial structure",
            "weak ecology",
            "ecology",
            "rich ecology",
        ],
    )
].groupby(
    group_variables,
):

    fil = (
        group_df[group_df["a"] == "reconstructed-tree"]
        .copy()
        .dropna(subset=["regime"])
    )

    melted_df = fil.melt(
        id_vars=["regime"],
        value_vars=phylometrics,
    )
    melted_df["phylometric"] = melted_df["variable"]

    def calc_cliffs_delta(group) -> float:
        phylometric, regime = group.name
        return -cliffs_delta(
            fil[fil["regime"] == "plain"][phylometric],
            fil[fil["regime"] == regime][phylometric],
        )[0]

    melted_df = melted_df.groupby(["phylometric", "regime"]).apply(
        calc_cliffs_delta,
    ).reset_index(name="value")

    fig, ax = plt.subplots(figsize=(15, 2))

    matrix = melted_df.pivot(
        index="phylometric",
        columns="regime",
        values="value",
    )
    matrix = matrix[
        sorted(
            matrix.columns,
            key=[
                "plain",
                "weak selection",
                "strong selection",
                "spatial structure",
                "weak ecology",
                "ecology",
                "rich ecology",
            ].index,
        )
    ]

    annot = []
    for metric, row in matrix.iterrows():

        def getvec(regime: str) -> np.array:
            return fil[fil["regime"] == regime][metric].to_numpy()

        annot.append(
            [
                describe_effect(getvec("plain"), getvec(regime))
                for regime in matrix.columns
            ],
        )

    tp.tee(
        sns.heatmap,
        matrix,
        annot=annot,
        fmt="",
        linewidths=2,
        cmap=sns.color_palette("vlag", as_cmap=True),
        center=0,
        cbar_kws={"label": "Cliff's delta"},
        teeplot_outattrs={
            **dict(
                zip(group_variables, group),
            ),
            **{
                "x": "regime",
                "y": "phylometric",
            },
        },
        teeplot_outexclude=["fmt"],
        vmin=-1,
        vmax=1,
    )
# Out:
# teeplots/epoch=0+mut_distn=default+resolution=3.0+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+resolution=3.0+viz=heatmap+x=regime+y=phylometric+ext=.png
# teeplots/epoch=0+mut_distn=default+resolution=10.0+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+resolution=10.0+viz=heatmap+x=regime+y=phylometric+ext=.png
# teeplots/epoch=0+mut_distn=default+resolution=33.0+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+resolution=33.0+viz=heatmap+x=regime+y=phylometric+ext=.png
# teeplots/epoch=0+mut_distn=default+resolution=100.0+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+resolution=100.0+viz=heatmap+x=regime+y=phylometric+ext=.png

# %% [markdown]
# # stats: comparison against perfect quality

# %%
records = []
for phylometric in phylometrics:
    for group, group_df in df.groupby(
        ["regime", *sensitivity_analysis_variables], as_index=False
    ):
        for quality in group_df["quality"].unique():
            if quality == "perfect resolution":
                continue
            kw_result, n = scipy_stats.wilcoxon(
                group_df[group_df["quality"] == "perfect resolution"][
                    phylometric
                ],
                group_df[group_df["quality"] == quality][phylometric],
            ), ip.pophomogeneous(group_df.groupby(["quality"]).count()["a"])
            records.append(
                {
                    **{"quality": quality, "n": n, "phylometric": phylometric},
                    **dict(zip(["statistic", "p"], kw_result)),
                    **dict(
                        zip(["regime", *sensitivity_analysis_variables], group)
                    ),
                }
            )

with pd.option_context("display.max_colwidth", None, "display.max_rows", None):
    out_df = (
        pd.DataFrame.from_records(records)
        .sort_values(
            [*sensitivity_analysis_variables, "regime", "phylometric"],
        )
        .reset_index(drop=True)
    )
    display(out_df)
    os.makedirs("outdata", exist_ok=True)
    out_df.to_csv(
        "outdata/a=phylostatistics-comparison-between-resolutions-allpairs-wilcox+ext=.csv",
        index=False,
    )
# Out:
#             quality   n                        phylometric  statistic  \
# 0     1% resolution  30                 colless_like_index      212.0
# 1    10% resolution  30                 colless_like_index      182.0
# 2     3% resolution  30                 colless_like_index      218.0
# 3    33% resolution  30                 colless_like_index       71.0
# 4     1% resolution  30  mean_evolutionary_distinctiveness        8.0
# 5    10% resolution  30  mean_evolutionary_distinctiveness        7.0
# 6     3% resolution  30  mean_evolutionary_distinctiveness        0.0
# 7    33% resolution  30  mean_evolutionary_distinctiveness        4.0
# 8     1% resolution  30             mean_pairwise_distance        0.0
# 9    10% resolution  30             mean_pairwise_distance        0.0
# 10    3% resolution  30             mean_pairwise_distance        0.0
# 11   33% resolution  30             mean_pairwise_distance        0.0
# 12    1% resolution  30                       sum_distance      226.0
# 13   10% resolution  30                       sum_distance      227.0
# 14    3% resolution  30                       sum_distance      231.0
# 15   33% resolution  30                       sum_distance      202.0
# 16   10% resolution  30                 colless_like_index      225.0
# 17   33% resolution  30                 colless_like_index      144.0
# 18    3% resolution  30                 colless_like_index      207.0
# 19    1% resolution  30                 colless_like_index      223.0
# 20   10% resolution  30  mean_evolutionary_distinctiveness       18.0
# 21   33% resolution  30  mean_evolutionary_distinctiveness       29.0
# 22    3% resolution  30  mean_evolutionary_distinctiveness       20.0
# 23    1% resolution  30  mean_evolutionary_distinctiveness       27.0
# 24   10% resolution  30             mean_pairwise_distance        0.0
# 25   33% resolution  30             mean_pairwise_distance        0.0
# 26    3% resolution  30             mean_pairwise_distance        0.0
# 27    1% resolution  30             mean_pairwise_distance        0.0
# 28   10% resolution  30                       sum_distance      221.0
# 29   33% resolution  30                       sum_distance      221.0
# 30    3% resolution  30                       sum_distance      219.0
# 31    1% resolution  30                       sum_distance      232.0
# 32    3% resolution  30                 colless_like_index      231.0
# 33    1% resolution  30                 colless_like_index      227.0
# 34   33% resolution  30                 colless_like_index      112.0
# 35   10% resolution  30                 colless_like_index      198.0
# 36    3% resolution  30  mean_evolutionary_distinctiveness       30.0
# 37    1% resolution  30  mean_evolutionary_distinctiveness       46.0
# 38   33% resolution  30  mean_evolutionary_distinctiveness       33.0
# 39   10% resolution  30  mean_evolutionary_distinctiveness       27.0
# 40    3% resolution  30             mean_pairwise_distance        0.0
# 41    1% resolution  30             mean_pairwise_distance        1.0
# 42   33% resolution  30             mean_pairwise_distance        0.0
# 43   10% resolution  30             mean_pairwise_distance        1.0
# 44    3% resolution  30                       sum_distance      225.0
# 45    1% resolution  30                       sum_distance      229.0
# 46   33% resolution  30                       sum_distance      225.0
# 47   10% resolution  30                       sum_distance      224.0
# 48    1% resolution  30                 colless_like_index      232.0
# 49    3% resolution  30                 colless_like_index      232.0
# 50   33% resolution  30                 colless_like_index      103.0
# 51   10% resolution  30                 colless_like_index      232.0
# 52    1% resolution  30  mean_evolutionary_distinctiveness        4.0
# 53    3% resolution  30  mean_evolutionary_distinctiveness        3.0
# 54   33% resolution  30  mean_evolutionary_distinctiveness        2.0
# 55   10% resolution  30  mean_evolutionary_distinctiveness        4.0
# 56    1% resolution  30             mean_pairwise_distance        0.0
# 57    3% resolution  30             mean_pairwise_distance        0.0
# 58   33% resolution  30             mean_pairwise_distance        0.0
# 59   10% resolution  30             mean_pairwise_distance        0.0
# 60    1% resolution  30                       sum_distance      227.0
# 61    3% resolution  30                       sum_distance      232.0
# 62   33% resolution  30                       sum_distance      220.0
# 63   10% resolution  30                       sum_distance      227.0
# 64   33% resolution  30                 colless_like_index      107.0
# 65    1% resolution  30                 colless_like_index      221.0
# 66    3% resolution  30                 colless_like_index      215.0
# 67   10% resolution  30                 colless_like_index      216.0
# 68   33% resolution  30  mean_evolutionary_distinctiveness        0.0
# 69    1% resolution  30  mean_evolutionary_distinctiveness        4.0
# 70    3% resolution  30  mean_evolutionary_distinctiveness        5.0
# 71   10% resolution  30  mean_evolutionary_distinctiveness        0.0
# 72   33% resolution  30             mean_pairwise_distance        0.0
# 73    1% resolution  30             mean_pairwise_distance        0.0
# 74    3% resolution  30             mean_pairwise_distance        0.0
# 75   10% resolution  30             mean_pairwise_distance        0.0
# 76   33% resolution  30                       sum_distance      232.0
# 77    1% resolution  30                       sum_distance      220.0
# 78    3% resolution  30                       sum_distance      221.0
# 79   10% resolution  30                       sum_distance      228.0
# 80   10% resolution  30                 colless_like_index      218.0
# 81    1% resolution  30                 colless_like_index      223.0
# 82   33% resolution  30                 colless_like_index      133.0
# 83    3% resolution  30                 colless_like_index      228.0
# 84   10% resolution  30  mean_evolutionary_distinctiveness       44.0
# 85    1% resolution  30  mean_evolutionary_distinctiveness       35.0
# 86   33% resolution  30  mean_evolutionary_distinctiveness       33.0
# 87    3% resolution  30  mean_evolutionary_distinctiveness       36.0
# 88   10% resolution  30             mean_pairwise_distance        0.0
# 89    1% resolution  30             mean_pairwise_distance        0.0
# 90   33% resolution  30             mean_pairwise_distance        0.0
# 91    3% resolution  30             mean_pairwise_distance        0.0
# 92   10% resolution  30                       sum_distance      228.0
# 93    1% resolution  30                       sum_distance      228.0
# 94   33% resolution  30                       sum_distance      222.0
# 95    3% resolution  30                       sum_distance      226.0
# 96    1% resolution  30                 colless_like_index      226.0
# 97   10% resolution  30                 colless_like_index      200.0
# 98   33% resolution  30                 colless_like_index       88.0
# 99    3% resolution  30                 colless_like_index      231.0
# 100   1% resolution  30  mean_evolutionary_distinctiveness        5.0
# 101  10% resolution  30  mean_evolutionary_distinctiveness        9.0
# 102  33% resolution  30  mean_evolutionary_distinctiveness       16.0
# 103   3% resolution  30  mean_evolutionary_distinctiveness        7.0
# 104   1% resolution  30             mean_pairwise_distance        0.0
# 105  10% resolution  30             mean_pairwise_distance        0.0
# 106  33% resolution  30             mean_pairwise_distance        0.0
# 107   3% resolution  30             mean_pairwise_distance        0.0
# 108   1% resolution  30                       sum_distance      221.0
# 109  10% resolution  30                       sum_distance      215.0
# 110  33% resolution  30                       sum_distance      205.0
# 111   3% resolution  30                       sum_distance      230.0
# 112   3% resolution  30                 colless_like_index      225.0
# 113   1% resolution  30                 colless_like_index      229.0
# 114  33% resolution  30                 colless_like_index      128.0
# 115  10% resolution  30                 colless_like_index      211.0
# 116   3% resolution  30  mean_evolutionary_distinctiveness       53.0
# 117   1% resolution  30  mean_evolutionary_distinctiveness       45.0
# 118  33% resolution  30  mean_evolutionary_distinctiveness       27.0
# 119  10% resolution  30  mean_evolutionary_distinctiveness       28.0
# 120   3% resolution  30             mean_pairwise_distance        0.0
# 121   1% resolution  30             mean_pairwise_distance        0.0
# 122  33% resolution  30             mean_pairwise_distance        0.0
# 123  10% resolution  30             mean_pairwise_distance        0.0
# 124   3% resolution  30                       sum_distance      232.0
# 125   1% resolution  30                       sum_distance      209.0
# 126  33% resolution  30                       sum_distance      224.0
# 127  10% resolution  30                       sum_distance      231.0
# 128   1% resolution  30                 colless_like_index      232.0
# 129  33% resolution  30                 colless_like_index      167.0
# 130   3% resolution  30                 colless_like_index      230.0
# 131  10% resolution  30                 colless_like_index      226.0
# 132   1% resolution  30  mean_evolutionary_distinctiveness       82.0
# 133  33% resolution  30  mean_evolutionary_distinctiveness       82.0
# 134   3% resolution  30  mean_evolutionary_distinctiveness       87.0
# 135  10% resolution  30  mean_evolutionary_distinctiveness       74.0
# 136   1% resolution  30             mean_pairwise_distance        2.0
# 137  33% resolution  30             mean_pairwise_distance        1.0
# 138   3% resolution  30             mean_pairwise_distance        2.0
# 139  10% resolution  30             mean_pairwise_distance        3.0
# 140   1% resolution  30                       sum_distance      232.0
# 141  33% resolution  30                       sum_distance      228.0
# 142   3% resolution  30                       sum_distance      228.0
# 143  10% resolution  30                       sum_distance      229.0
# 144  10% resolution  30                 colless_like_index      214.0
# 145  33% resolution  30                 colless_like_index      128.0
# 146   1% resolution  30                 colless_like_index      211.0
# 147   3% resolution  30                 colless_like_index      209.0
# 148  10% resolution  30  mean_evolutionary_distinctiveness        7.0
# 149  33% resolution  30  mean_evolutionary_distinctiveness        6.0
# 150   1% resolution  30  mean_evolutionary_distinctiveness       17.0
# 151   3% resolution  30  mean_evolutionary_distinctiveness       15.0
# 152  10% resolution  30             mean_pairwise_distance        5.0
# 153  33% resolution  30             mean_pairwise_distance        1.0
# 154   1% resolution  30             mean_pairwise_distance        0.0
# 155   3% resolution  30             mean_pairwise_distance        3.0
# 156  10% resolution  30                       sum_distance      221.0
# 157  33% resolution  30                       sum_distance      226.0
# 158   1% resolution  30                       sum_distance      231.0
# 159   3% resolution  30                       sum_distance      215.0
#
#             p                 regime  epoch mut_distn
# 0    0.673280                ecology      0   default
# 1    0.298944                ecology      0   default
# 2    0.765519                ecology      0   default
# 3    0.000894                ecology      0   default
# 4    0.000004                ecology      0   default
# 5    0.000004                ecology      0   default
# 6    0.000002                ecology      0   default
# 7    0.000003                ecology      0   default
# 8    0.000002                ecology      0   default
# 9    0.000002                ecology      0   default
# 10   0.000002                ecology      0   default
# 11   0.000002                ecology      0   default
# 12   0.893644                ecology      0   default
# 13   0.909931                ecology      0   default
# 14   0.975387                ecology      0   default
# 15   0.530440                ecology      0   default
# 16   0.877403       ecology, spatial      0   default
# 17   0.068714       ecology, spatial      0   default
# 18   0.599936       ecology, spatial      0   default
# 19   0.845080       ecology, spatial      0   default
# 20   0.000010       ecology, spatial      0   default
# 21   0.000028       ecology, spatial      0   default
# 22   0.000012       ecology, spatial      0   default
# 23   0.000024       ecology, spatial      0   default
# 24   0.000002       ecology, spatial      0   default
# 25   0.000002       ecology, spatial      0   default
# 26   0.000002       ecology, spatial      0   default
# 27   0.000002       ecology, spatial      0   default
# 28   0.813017       ecology, spatial      0   default
# 29   0.813017       ecology, spatial      0   default
# 30   0.781264       ecology, spatial      0   default
# 31   0.991795       ecology, spatial      0   default
# 32   0.975387                  plain      0   default
# 33   0.909931                  plain      0   default
# 34   0.013194                  plain      0   default
# 35   0.477947                  plain      0   default
# 36   0.000031                  plain      0   default
# 37   0.000125                  plain      0   default
# 38   0.000041                  plain      0   default
# 39   0.000024                  plain      0   default
# 40   0.000002                  plain      0   default
# 41   0.000002                  plain      0   default
# 42   0.000002                  plain      0   default
# 43   0.000002                  plain      0   default
# 44   0.877403                  plain      0   default
# 45   0.942611                  plain      0   default
# 46   0.877403                  plain      0   default
# 47   0.861213                  plain      0   default
# 48   0.991795           rich ecology      0   default
# 49   0.991795           rich ecology      0   default
# 50   0.007731           rich ecology      0   default
# 51   0.991795           rich ecology      0   default
# 52   0.000003           rich ecology      0   default
# 53   0.000002           rich ecology      0   default
# 54   0.000002           rich ecology      0   default
# 55   0.000003           rich ecology      0   default
# 56   0.000002           rich ecology      0   default
# 57   0.000002           rich ecology      0   default
# 58   0.000002           rich ecology      0   default
# 59   0.000002           rich ecology      0   default
# 60   0.909931           rich ecology      0   default
# 61   0.991795           rich ecology      0   default
# 62   0.797098           rich ecology      0   default
# 63   0.909931           rich ecology      0   default
# 64   0.009842  rich ecology, spatial      0   default
# 65   0.813017  rich ecology, spatial      0   default
# 66   0.718888  rich ecology, spatial      0   default
# 67   0.734325  rich ecology, spatial      0   default
# 68   0.000002  rich ecology, spatial      0   default
# 69   0.000003  rich ecology, spatial      0   default
# 70   0.000003  rich ecology, spatial      0   default
# 71   0.000002  rich ecology, spatial      0   default
# 72   0.000002  rich ecology, spatial      0   default
# 73   0.000002  rich ecology, spatial      0   default
# 74   0.000002  rich ecology, spatial      0   default
# 75   0.000002  rich ecology, spatial      0   default
# 76   0.991795  rich ecology, spatial      0   default
# 77   0.797098  rich ecology, spatial      0   default
# 78   0.813017  rich ecology, spatial      0   default
# 79   0.926255  rich ecology, spatial      0   default
# 80   0.765519      spatial structure      0   default
# 81   0.845080      spatial structure      0   default
# 82   0.040702      spatial structure      0   default
# 83   0.926255      spatial structure      0   default
# 84   0.000106      spatial structure      0   default
# 85   0.000049      spatial structure      0   default
# 86   0.000041      spatial structure      0   default
# 87   0.000053      spatial structure      0   default
# 88   0.000002      spatial structure      0   default
# 89   0.000002      spatial structure      0   default
# 90   0.000002      spatial structure      0   default
# 91   0.000002      spatial structure      0   default
# 92   0.926255      spatial structure      0   default
# 93   0.926255      spatial structure      0   default
# 94   0.829013      spatial structure      0   default
# 95   0.893644      spatial structure      0   default
# 96   0.893644       strong selection      0   default
# 97   0.503833       strong selection      0   default
# 98   0.002957       strong selection      0   default
# 99   0.975387       strong selection      0   default
# 100  0.000003       strong selection      0   default
# 101  0.000004       strong selection      0   default
# 102  0.000008       strong selection      0   default
# 103  0.000004       strong selection      0   default
# 104  0.000002       strong selection      0   default
# 105  0.000002       strong selection      0   default
# 106  0.000002       strong selection      0   default
# 107  0.000002       strong selection      0   default
# 108  0.813017       strong selection      0   default
# 109  0.718888       strong selection      0   default
# 110  0.571646       strong selection      0   default
# 111  0.958990       strong selection      0   default
# 112  0.877403           weak ecology      0   default
# 113  0.942611           weak ecology      0   default
# 114  0.031603           weak ecology      0   default
# 115  0.658331           weak ecology      0   default
# 116  0.000222           weak ecology      0   default
# 117  0.000115           weak ecology      0   default
# 118  0.000024           weak ecology      0   default
# 119  0.000026           weak ecology      0   default
# 120  0.000002           weak ecology      0   default
# 121  0.000002           weak ecology      0   default
# 122  0.000002           weak ecology      0   default
# 123  0.000002           weak ecology      0   default
# 124  0.991795           weak ecology      0   default
# 125  0.628843           weak ecology      0   default
# 126  0.861213           weak ecology      0   default
# 127  0.975387           weak ecology      0   default
# 128  0.991795  weak ecology, spatial      0   default
# 129  0.177907  weak ecology, spatial      0   default
# 130  0.958990  weak ecology, spatial      0   default
# 131  0.893644  weak ecology, spatial      0   default
# 132  0.001965  weak ecology, spatial      0   default
# 133  0.001965  weak ecology, spatial      0   default
# 134  0.002765  weak ecology, spatial      0   default
# 135  0.001114  weak ecology, spatial      0   default
# 136  0.000002  weak ecology, spatial      0   default
# 137  0.000002  weak ecology, spatial      0   default
# 138  0.000002  weak ecology, spatial      0   default
# 139  0.000002  weak ecology, spatial      0   default
# 140  0.991795  weak ecology, spatial      0   default
# 141  0.926255  weak ecology, spatial      0   default
# 142  0.926255  weak ecology, spatial      0   default
# 143  0.942611  weak ecology, spatial      0   default
# 144  0.703564         weak selection      0   default
# 145  0.031603         weak selection      0   default
# 146  0.658331         weak selection      0   default
# 147  0.628843         weak selection      0   default
# 148  0.000004         weak selection      0   default
# 149  0.000003         weak selection      0   default
# 150  0.000009         weak selection      0   default
# 151  0.000008         weak selection      0   default
# 152  0.000003         weak selection      0   default
# 153  0.000002         weak selection      0   default
# 154  0.000002         weak selection      0   default
# 155  0.000002         weak selection      0   default
# 156  0.813017         weak selection      0   default
# 157  0.893644         weak selection      0   default
# 158  0.975387         weak selection      0   default
# 159  0.718888         weak selection      0   default

# %%
for group, group_df in out_df[
    out_df["regime"].isin(
        [
            "plain",
            "weak selection",
            "strong selection",
            "spatial structure",
            "weak ecology",
            "ecology",
            "rich ecology",
        ],
    )
].groupby(
    sensitivity_analysis_variables, as_index=False
):
    group_df["quality threshold"] = group_df["quality"]
    group_df.loc[group_df["p"] > 0.05, "quality threshold"] = ""
    summarized_df = (
        group_df.groupby(["regime", "phylometric"])
        .agg(
            {
                "quality threshold": lambda subgroup: (
                    np.nan
                    if "1% resolution" in set(subgroup)
                    else 1
                    if "3% resolution" in set(subgroup)
                    else 3
                    if "10% resolution" in set(subgroup)
                    else 10
                    if "33% resolution" in set(subgroup)
                    else 33
                ),
                "epoch": lambda subgroup: ip.pophomogeneous(subgroup),
                "mut_distn": lambda subgroup: ip.pophomogeneous(subgroup),
            }
        )
        .reset_index()
    )

    matrix = summarized_df.pivot(
        index="phylometric",
        columns="regime",
        values="quality threshold",
    )
    matrix = matrix[
        sorted(
            matrix.columns,
            key=[
                "plain",
                "weak selection",
                "strong selection",
                "spatial structure",
                "weak ecology",
                "ecology",
                "rich ecology",
            ].index,
        )
    ]

    fig, ax = plt.subplots(figsize=(15, 5))
    formatter = mpl.ticker.ScalarFormatter(useMathText=True)
    formatter.set_scientific(False)
    tp.tee(
        sns.heatmap,
        matrix,
        linewidths=2,
        norm=mpl.colors.LogNorm(vmin=1, vmax=33),
        cmap=sns.color_palette("hls", as_cmap=True),
        center=0,
        cbar_kws={
            "label": "reconstruction error insignificance threshold",
            "ticks": [1, 3, 10, 33],
            "format": formatter,
        },
        teeplot_outattrs={
            **dict(
                zip(sensitivity_analysis_variables, group),
            ),
            **{
                "hue": "quality-threshold",
                "x": "regime",
                "y": "phylometric",
            },
        },
        vmin=1,
        vmax=33,
    )

summarized_df
# Out:
# teeplots/epoch=0+hue=quality-threshold+mut_distn=default+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+hue=quality-threshold+mut_distn=default+viz=heatmap+x=regime+y=phylometric+ext=.png
#                regime                        phylometric  quality threshold  \
# 0             ecology                 colless_like_index               10.0
# 1             ecology  mean_evolutionary_distinctiveness                NaN
# 2             ecology             mean_pairwise_distance                NaN
# 3             ecology                       sum_distance               33.0
# 4               plain                 colless_like_index               10.0
# 5               plain  mean_evolutionary_distinctiveness                NaN
# 6               plain             mean_pairwise_distance                NaN
# 7               plain                       sum_distance               33.0
# 8        rich ecology                 colless_like_index               10.0
# 9        rich ecology  mean_evolutionary_distinctiveness                NaN
# 10       rich ecology             mean_pairwise_distance                NaN
# 11       rich ecology                       sum_distance               33.0
# 12  spatial structure                 colless_like_index               10.0
# 13  spatial structure  mean_evolutionary_distinctiveness                NaN
# 14  spatial structure             mean_pairwise_distance                NaN
# 15  spatial structure                       sum_distance               33.0
# 16   strong selection                 colless_like_index               10.0
# 17   strong selection  mean_evolutionary_distinctiveness                NaN
# 18   strong selection             mean_pairwise_distance                NaN
# 19   strong selection                       sum_distance               33.0
# 20       weak ecology                 colless_like_index               10.0
# 21       weak ecology  mean_evolutionary_distinctiveness                NaN
# 22       weak ecology             mean_pairwise_distance                NaN
# 23       weak ecology                       sum_distance               33.0
# 24     weak selection                 colless_like_index               10.0
# 25     weak selection  mean_evolutionary_distinctiveness                NaN
# 26     weak selection             mean_pairwise_distance                NaN
# 27     weak selection                       sum_distance               33.0
#
#     epoch mut_distn
# 0       0   default
# 1       0   default
# 2       0   default
# 3       0   default
# 4       0   default
# 5       0   default
# 6       0   default
# 7       0   default
# 8       0   default
# 9       0   default
# 10      0   default
# 11      0   default
# 12      0   default
# 13      0   default
# 14      0   default
# 15      0   default
# 16      0   default
# 17      0   default
# 18      0   default
# 19      0   default
# 20      0   default
# 21      0   default
# 22      0   default
# 23      0   default
# 24      0   default
# 25      0   default
# 26      0   default
# 27      0   default
