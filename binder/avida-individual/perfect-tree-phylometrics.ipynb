# %%
import itertools as it
import os

from cliffs_delta import cliffs_delta
from iterpop import iterpop as ip
from matplotlib import pyplot as plt
from nbmetalog import nbmetalog as nbm
import numpy as np
import pandas as pd
from scipy import stats as scipy_stats
import seaborn as sns
from teeplot import teeplot as tp

from pylib import describe_effect

# %%
# prints metadata about notebook runtime
nbm.print_metadata()
# Out:
# context: ci
# hostname: fv-az1016-605
# interpreter: 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
# nbcellexec: null
# nbname: perfect-tree-phylometrics
# nbpath: /home/runner/work/hstrat-evolutionary-inference/hstrat-evolutionary-inference/binder/avida-individual/perfect-tree-phylometrics.ipynb
# revision: null
# session: c5d29294-af07-41dd-8ff2-756999310dc8
# timestamp: 2024-08-18T00:32:06Z00:00
#
#
# IPython==8.13.0
# keyname==0.5.2
# yaml==6.0
# iterpop==0.4.1
# matplotlib==3.7.1
# nbmetalog==0.2.6
# numpy==1.21.6
# pandas==1.3.5
# scipy==1.7.3
# seaborn==0.12.1
# teeplot==1.0.1
# re==2.2.1
# comm==0.2.2
# logging==0.5.1.2
# psutil==5.9.8
# zmq==24.0.1
# json==2.0.9
# ipykernel==6.29.3

# %%
df = pd.read_csv("https://osf.io/djevp/download")
dfdigest = np.bitwise_xor.reduce(
    pd.util.hash_pandas_object(df),
)
print("{:x}".format(dfdigest))
df
# Out:
# 877c5e50c2c17e00
#                         a  epoch mut_distn                        treatment  \
# 0     collapsed-phylogeny      0   default        individual_selection_weak
# 1     collapsed-phylogeny      0   default                    spatial_plain
# 2     collapsed-phylogeny      0   default          individual_ecology_weak
# 3     collapsed-phylogeny      0   default  individual_spatial_ecology_rich
# 4     collapsed-phylogeny      0   default                 selection_strong
# ...                   ...    ...       ...                              ...
# 2395   reconstructed-tree      0   default        individual_selection_weak
# 2396   reconstructed-tree      0   default        individual_selection_weak
# 2397   reconstructed-tree      0   default        individual_selection_weak
# 2398   reconstructed-tree      0   default  individual_spatial_ecology_some
# 2399   reconstructed-tree      0   default  individual_spatial_ecology_rich
#
#       seed  phylogeny-snapshot-100000.csv  \
# 0      166                            NaN
# 1      285                            NaN
# 2       97                            NaN
# 3      202                            NaN
# 4      134                            NaN
# ...    ...                            ...
# 2395   174                            NaN
# 2396   155                            NaN
# 2397   151                            NaN
# 2398   221                            NaN
# 2399   184                            NaN
#
#                                                       _  colless_like_index  \
# 0     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        16413.377699
# 1     /mnt/home/mmore500/scratch/data/hstrat-evoluti...         5889.044246
# 2     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        24328.758494
# 3     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        13872.550476
# 4     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        11151.009191
# ...                                                 ...                 ...
# 2395  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        13068.933629
# 2396  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        16115.370601
# 2397  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15862.794784
# 2398  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        14001.023216
# 2399  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        17509.627249
#
#       average_depth  average_origin_time  ...  \
# 0               inf         99903.330314  ...
# 1               inf         99860.938076  ...
# 2               inf         99949.740000  ...
# 3               inf         99831.008690  ...
# 4               inf         99882.926099  ...
# ...             ...                  ...  ...
# 2395      22.807692         99948.311406  ...
# 2396      25.311671         99910.315652  ...
# 2397      24.893363         99913.065014  ...
# 2398      24.323682         99911.224317  ...
# 2399      25.813136         99843.178630  ...
#
#       variance_pairwise_distance_branch_only  mrca_depth  sackin_index  \
# 0                                  29.762505           1         37604
# 1                                  17.246662           1         19441
# 2                                  26.685759           1         44783
# 3                                  25.321388           1         36795
# 4                                  27.690557           1         28725
# ...                                      ...         ...           ...
# 2395                               24.558595           1         28133
# 2396                               30.149655           1         31841
# 2397                               26.904952           1         31043
# 2398                               25.275680           1         30394
# 2399                               24.137014           1         33275
#
#       mean_evolutionary_distinctiveness  sum_evolutionary_distinctiveness  \
# 0                            116.809311                     319823.893642
# 1                            169.082623                     314155.514230
# 2                             42.032856                     113404.644817
# 3                            257.400153                     719433.428105
# 4                            146.499653                     337095.700472
# ...                                 ...                               ...
# 2395                          55.940519                     125083.000000
# 2396                         125.896994                     284779.000000
# 2397                         120.667920                     272709.500000
# 2398                         134.458081                     311136.000000
# 2399                         273.341525                     645086.000000
#
#       variance_evolutionary_distinctiveness  resolution  subsampling-fraction  \
# 0                              12111.310369         NaN                   NaN
# 1                               9583.662151         NaN                   NaN
# 2                                624.827781         NaN                   NaN
# 3                              12815.294360         NaN                   NaN
# 4                              11015.743172         NaN                   NaN
# ...                                     ...         ...                   ...
# 2395                             932.185874        10.0                   1.0
# 2396                            6755.799258       100.0                   1.0
# 2397                            4576.502673        33.0                   1.0
# 2398                            6716.805266        10.0                   1.0
# 2399                           83659.574455        10.0                   1.0
#
#       trie-postprocess      ext
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...                ...      ...
# 2395             naive  .csv.gz
# 2396             naive  .csv.gz
# 2397             naive  .csv.gz
# 2398             naive  .csv.gz
# 2399             naive  .csv.gz
#
# [2400 rows x 36 columns]

# %%
# phylometrics whittled down to descriptive, non-redundant set
df["colless-like index"] = df["colless_like_index"]
df["mean pairwise distance"] = df["mean_pairwise_distance"]
df["sum pairwise distance"] = df["sum_distance"]
df["mean evolutionary distinctiveness"] = df[
    "mean_evolutionary_distinctiveness"
]

phylometrics = [
    #     'diversity',
    "colless-like index",
    #     'average_depth',
    #     'average_origin_time',
    #     'average_origin_time_normalized',
    #     'max_depth',
    "mean pairwise distance",
    #     'mean_pairwise_distance_branch_only',
    #     'num_active',
    "sum pairwise distance",
    # "num_ancestors",
    #     'num_outside',
    #     'num_roots',
    #     'num_taxa',
    #     'phylogenetic_diversity',
    #     'sum_pairwise_distance',
    #     'sum_pairwise_distance_branch_only',
    #     'total_orgs',
    #     'tree_size',
    #     'variance_pairwise_distance',
    #     'variance_pairwise_distance_branch_only',
    #     'mrca_depth',
    #     'sackin_index',
    "mean evolutionary distinctiveness",
    #     'sum_evolutionary_distinctiveness',
    #     'variance_evolutionary_distinctiveness',
]

# %%
methodological_variables = [
    "resolution",
]

# %%
evolutionary_variables = [
    "num_islands",
    "num_niches",
    "tournament_size",
    "p_niche_invasion",
]

# %%
sensitivity_analysis_variables = [
    "epoch",
    "mut_distn",
]

# %%
fixed_variables = [
    "subsampling-fraction",  # only use 1.0
    "trie-postprocess",  # just use naive postprocessing for now
]

# %%
# ensure fixed variables
df = df[
    ((df["subsampling-fraction"] == 1.0) | df["subsampling-fraction"].isna())
    & ((df["trie-postprocess"] == "naive") | df["trie-postprocess"].isna())
].copy()

for fixed_variable in fixed_variables:
    assert len(df[fixed_variable].dropna().unique()) == 1

df
# Out:
#                         a  epoch mut_distn                        treatment  \
# 0     collapsed-phylogeny      0   default        individual_selection_weak
# 1     collapsed-phylogeny      0   default                    spatial_plain
# 2     collapsed-phylogeny      0   default          individual_ecology_weak
# 3     collapsed-phylogeny      0   default  individual_spatial_ecology_rich
# 4     collapsed-phylogeny      0   default                 selection_strong
# ...                   ...    ...       ...                              ...
# 2395   reconstructed-tree      0   default        individual_selection_weak
# 2396   reconstructed-tree      0   default        individual_selection_weak
# 2397   reconstructed-tree      0   default        individual_selection_weak
# 2398   reconstructed-tree      0   default  individual_spatial_ecology_some
# 2399   reconstructed-tree      0   default  individual_spatial_ecology_rich
#
#       seed  phylogeny-snapshot-100000.csv  \
# 0      166                            NaN
# 1      285                            NaN
# 2       97                            NaN
# 3      202                            NaN
# 4      134                            NaN
# ...    ...                            ...
# 2395   174                            NaN
# 2396   155                            NaN
# 2397   151                            NaN
# 2398   221                            NaN
# 2399   184                            NaN
#
#                                                       _  colless_like_index  \
# 0     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        16413.377699
# 1     /mnt/home/mmore500/scratch/data/hstrat-evoluti...         5889.044246
# 2     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        24328.758494
# 3     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        13872.550476
# 4     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        11151.009191
# ...                                                 ...                 ...
# 2395  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        13068.933629
# 2396  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        16115.370601
# 2397  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15862.794784
# 2398  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        14001.023216
# 2399  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        17509.627249
#
#       average_depth  average_origin_time  ...  \
# 0               inf         99903.330314  ...
# 1               inf         99860.938076  ...
# 2               inf         99949.740000  ...
# 3               inf         99831.008690  ...
# 4               inf         99882.926099  ...
# ...             ...                  ...  ...
# 2395      22.807692         99948.311406  ...
# 2396      25.311671         99910.315652  ...
# 2397      24.893363         99913.065014  ...
# 2398      24.323682         99911.224317  ...
# 2399      25.813136         99843.178630  ...
#
#       sum_evolutionary_distinctiveness  variance_evolutionary_distinctiveness  \
# 0                        319823.893642                           12111.310369
# 1                        314155.514230                            9583.662151
# 2                        113404.644817                             624.827781
# 3                        719433.428105                           12815.294360
# 4                        337095.700472                           11015.743172
# ...                                ...                                    ...
# 2395                     125083.000000                             932.185874
# 2396                     284779.000000                            6755.799258
# 2397                     272709.500000                            4576.502673
# 2398                     311136.000000                            6716.805266
# 2399                     645086.000000                           83659.574455
#
#       resolution  subsampling-fraction  trie-postprocess      ext  \
# 0            NaN                   NaN               NaN      NaN
# 1            NaN                   NaN               NaN      NaN
# 2            NaN                   NaN               NaN      NaN
# 3            NaN                   NaN               NaN      NaN
# 4            NaN                   NaN               NaN      NaN
# ...          ...                   ...               ...      ...
# 2395        10.0                   1.0             naive  .csv.gz
# 2396       100.0                   1.0             naive  .csv.gz
# 2397        33.0                   1.0             naive  .csv.gz
# 2398        10.0                   1.0             naive  .csv.gz
# 2399        10.0                   1.0             naive  .csv.gz
#
#       colless-like index  mean pairwise distance  sum pairwise distance  \
# 0           16413.377699               23.109490               385596.0
# 1            5889.044246               17.173138               375700.0
# 2           24328.758494               22.566416               202961.0
# 3           13872.550476               23.432757               701297.0
# 4           11151.009191               20.358803               403064.0
# ...                  ...                     ...                    ...
# 2395        13068.933629               22.284411               212842.5
# 2396        16115.370601               23.491732               358553.5
# 2397        15862.794784               23.423511               350074.0
# 2398        14001.023216               23.296427               372188.5
# 2399        17509.627249               23.156326               655090.5
#
#       mean evolutionary distinctiveness
# 0                            116.809311
# 1                            169.082623
# 2                             42.032856
# 3                            257.400153
# 4                            146.499653
# ...                                 ...
# 2395                          55.940519
# 2396                         125.896994
# 2397                         120.667920
# 2398                         134.458081
# 2399                         273.341525
#
# [2400 rows x 40 columns]

# %%
# exclude extraneous variable values
df = df[(df["a"] == "collapsed-phylogeny")].copy()

df
# Out:
#                        a  epoch mut_distn                        treatment  \
# 0    collapsed-phylogeny      0   default        individual_selection_weak
# 1    collapsed-phylogeny      0   default                    spatial_plain
# 2    collapsed-phylogeny      0   default          individual_ecology_weak
# 3    collapsed-phylogeny      0   default  individual_spatial_ecology_rich
# 4    collapsed-phylogeny      0   default                 selection_strong
# ..                   ...    ...       ...                              ...
# 475  collapsed-phylogeny      0   default  individual_spatial_ecology_weak
# 476  collapsed-phylogeny      0   default                   selection_weak
# 477  collapsed-phylogeny      0   default  individual_spatial_ecology_rich
# 478  collapsed-phylogeny      0   default      individual_selection_strong
# 479  collapsed-phylogeny      0   default          individual_ecology_some
#
#      seed  phylogeny-snapshot-100000.csv  \
# 0     166                            NaN
# 1     285                            NaN
# 2      97                            NaN
# 3     202                            NaN
# 4     134                            NaN
# ..    ...                            ...
# 475   268                            NaN
# 476   176                            NaN
# 477   191                            NaN
# 478   129                            NaN
# 479    83                            NaN
#
#                                                      _  colless_like_index  \
# 0    /mnt/home/mmore500/scratch/data/hstrat-evoluti...        16413.377699
# 1    /mnt/home/mmore500/scratch/data/hstrat-evoluti...         5889.044246
# 2    /mnt/home/mmore500/scratch/data/hstrat-evoluti...        24328.758494
# 3    /mnt/home/mmore500/scratch/data/hstrat-evoluti...        13872.550476
# 4    /mnt/home/mmore500/scratch/data/hstrat-evoluti...        11151.009191
# ..                                                 ...                 ...
# 475  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15098.348983
# 476  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        11295.785895
# 477  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        17584.556362
# 478  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        21284.327969
# 479  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        17772.998954
#
#      average_depth  average_origin_time  ...  \
# 0              inf         99903.330314  ...
# 1              inf         99860.938076  ...
# 2              inf         99949.740000  ...
# 3              inf         99831.008690  ...
# 4              inf         99882.926099  ...
# ..             ...                  ...  ...
# 475            inf         99876.042244  ...
# 476            inf         99892.544512  ...
# 477            inf         99851.606892  ...
# 478            inf         99908.741991  ...
# 479            inf         99918.168069  ...
#
#      sum_evolutionary_distinctiveness  variance_evolutionary_distinctiveness  \
# 0                       319823.893642                           12111.310369
# 1                       314155.514230                            9583.662151
# 2                       113404.644817                             624.827781
# 3                       719433.428105                           12815.294360
# 4                       337095.700472                           11015.743172
# ..                                ...                                    ...
# 475                     451415.639214                            8744.332004
# 476                     287755.520982                            7418.489732
# 477                     640949.436688                           21959.278535
# 478                     299114.007046                            6283.825512
# 479                     254208.861745                            4652.805125
#
#      resolution  subsampling-fraction  trie-postprocess  ext  \
# 0           NaN                   NaN               NaN  NaN
# 1           NaN                   NaN               NaN  NaN
# 2           NaN                   NaN               NaN  NaN
# 3           NaN                   NaN               NaN  NaN
# 4           NaN                   NaN               NaN  NaN
# ..          ...                   ...               ...  ...
# 475         NaN                   NaN               NaN  NaN
# 476         NaN                   NaN               NaN  NaN
# 477         NaN                   NaN               NaN  NaN
# 478         NaN                   NaN               NaN  NaN
# 479         NaN                   NaN               NaN  NaN
#
#      colless-like index  mean pairwise distance  sum pairwise distance  \
# 0          16413.377699               23.109490               385596.0
# 1           5889.044246               17.173138               375700.0
# 2          24328.758494               22.566416               202961.0
# 3          13872.550476               23.432757               701297.0
# 4          11151.009191               20.358803               403064.0
# ..                  ...                     ...                    ...
# 475        15098.348983               22.503911               513265.0
# 476        11295.785895               18.691913               359234.0
# 477        17584.556362               23.294246               615449.0
# 478        21284.327969               25.248704               365460.0
# 479        17772.998954               22.725103               328494.0
#
#      mean evolutionary distinctiveness
# 0                           116.809311
# 1                           169.082623
# 2                            42.032856
# 3                           257.400153
# 4                           146.499653
# ..                                 ...
# 475                         162.204685
# 476                         128.176179
# 477                         228.583965
# 478                         106.106423
# 479                          90.918763
#
# [480 rows x 40 columns]

# %%
df["a"].unique()
# Out:
# array(['collapsed-phylogeny'], dtype=object)

# %%
df["regime"] = df["treatment"].map(
    {
        "individual_plain": "plain",
        "individual_selection_weak": "weak selection",
        "individual_selection_strong": "strong selection",
        "individual_spatial_plain": "spatial structure",
        "individual_ecology_some": "ecology",
        "individual_ecology_rich": "rich ecology",
        "individual_spatial_ecology_rich": "rich ecology, spatial",
        "individual_spatial_ecology_some": "ecology, spatial",
        "individual_ecology_weak": "weak ecology",
        "individual_spatial_ecology_weak": "weak ecology, spatial",
    },
)
df["regime"].unique()
# Out:
# array(['weak selection', nan, 'weak ecology', 'rich ecology, spatial',
#        'spatial structure', 'weak ecology, spatial', 'rich ecology',
#        'plain', 'ecology', 'ecology, spatial', 'strong selection'],
#       dtype=object)

# %%
df[df["a"] == "collapsed-phylogeny"]["regime"].unique()
# Out:
# array(['weak selection', nan, 'weak ecology', 'rich ecology, spatial',
#        'spatial structure', 'weak ecology, spatial', 'rich ecology',
#        'plain', 'ecology', 'ecology, spatial', 'strong selection'],
#       dtype=object)

# %% [markdown]
# # Phylometrics by Regime, Perfect Data

# %%
melted_df = df[(df["a"] == "collapsed-phylogeny")].melt(
    id_vars=(
        # evolutionary_variables
        # methodological_variables
        sensitivity_analysis_variables
        + ["regime"]
    ),
    value_vars=phylometrics,
)
melted_df["phylometric"] = melted_df["variable"]
melted_df
# Out:
#       epoch mut_distn                 regime  \
# 0         0   default         weak selection
# 1         0   default                    NaN
# 2         0   default           weak ecology
# 3         0   default  rich ecology, spatial
# 4         0   default                    NaN
# ...     ...       ...                    ...
# 1915      0   default  weak ecology, spatial
# 1916      0   default                    NaN
# 1917      0   default  rich ecology, spatial
# 1918      0   default       strong selection
# 1919      0   default                ecology
#
#                                variable         value  \
# 0                    colless-like index  16413.377699
# 1                    colless-like index   5889.044246
# 2                    colless-like index  24328.758494
# 3                    colless-like index  13872.550476
# 4                    colless-like index  11151.009191
# ...                                 ...           ...
# 1915  mean evolutionary distinctiveness    162.204685
# 1916  mean evolutionary distinctiveness    128.176179
# 1917  mean evolutionary distinctiveness    228.583965
# 1918  mean evolutionary distinctiveness    106.106423
# 1919  mean evolutionary distinctiveness     90.918763
#
#                             phylometric
# 0                    colless-like index
# 1                    colless-like index
# 2                    colless-like index
# 3                    colless-like index
# 4                    colless-like index
# ...                                 ...
# 1915  mean evolutionary distinctiveness
# 1916  mean evolutionary distinctiveness
# 1917  mean evolutionary distinctiveness
# 1918  mean evolutionary distinctiveness
# 1919  mean evolutionary distinctiveness
#
# [1920 rows x 6 columns]

# %%
def make_do_plot(plotter):
    def do_plot(data, col, x, y):
        g = sns.FacetGrid(
            data,
            col=col,
            sharex=False,
        ).set_titles(template="{col_name}")
        g.map(
            plotter,
            x,
            y,
            order=[
                "plain",
                "weak selection",
                "strong selection",
                "spatial structure",
                "weak ecology",
                "ecology",
                "rich ecology",
            ],
            palette=sns.color_palette("Set2", 7),
        )

    return do_plot


for viz, (group, group_df) in it.product(
    [
        sns.barplot,
        sns.boxplot,
        sns.violinplot,
    ],
    melted_df.groupby(sensitivity_analysis_variables),
):
    do_plot = make_do_plot(viz)
    do_plot.__name__ = viz.__name__
    tp.tee(
        do_plot,
        data=group_df,
        col="phylometric",
        x="value",
        y="regime",
        teeplot_outattrs=dict(
            zip(sensitivity_analysis_variables, group),
        ),
    )
# Out:
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=barplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=barplot+x=value+y=regime+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=boxplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=boxplot+x=value+y=regime+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=violinplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+viz=violinplot+x=value+y=regime+ext=.png

# %% [markdown]
# ## With space

# %%
def make_do_plot(plotter):
    def do_plot(data, col, x, y):
        g = sns.FacetGrid(
            data,
            col=col,
            sharex=False,
        ).set_titles(template="{col_name}")
        g.map(
            plotter,
            x,
            y,
            order=[
                "spatial structure",
                "weak ecology, spatial",
                "ecology, spatial",
                "rich ecology, spatial",
            ],
            palette=sns.color_palette("Set2", 4),
        )
        g.set(
            yticklabels=[
                "plain",
                "weak ecology",
                "ecology",
                "rich ecology",
            ],
        )

    return do_plot


for viz, (group, group_df) in it.product(
    [
        sns.barplot,
        sns.boxplot,
        sns.violinplot,
    ],
    melted_df.groupby(sensitivity_analysis_variables),
):
    do_plot = make_do_plot(viz)
    do_plot.__name__ = viz.__name__
    tp.tee(
        do_plot,
        data=group_df,
        col="phylometric",
        x="value",
        y="regime",
        teeplot_outattrs={
            "spatial": "true",
            **dict(zip(sensitivity_analysis_variables, group)),
        },
    )
# Out:
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=barplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=barplot+x=value+y=regime+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=boxplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=boxplot+x=value+y=regime+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=violinplot+x=value+y=regime+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+spatial=true+viz=violinplot+x=value+y=regime+ext=.png

# %% [markdown]
# # regime heatmap signatures

# %%
for (group, group_df) in df[
    df["regime"].isin(
        [
            "plain",
            "weak selection",
            "strong selection",
            "spatial structure",
            "weak ecology",
            "ecology",
            "rich ecology",
        ],
    )
].groupby(sensitivity_analysis_variables):

    fil = (
        group_df[(group_df["a"] == "collapsed-phylogeny")]
        .copy()
        .dropna(subset=["regime"])
    )

    melted_df = fil.melt(
        id_vars=["regime"],
        value_vars=phylometrics,
    )
    melted_df["phylometric"] = melted_df["variable"]

    def calc_cliffs_delta(group) -> float:
        phylometric, regime = group.name
        return -cliffs_delta(
            fil[fil["regime"] == "plain"][phylometric],
            fil[fil["regime"] == regime][phylometric],
        )[0]

    melted_df = melted_df.groupby(["phylometric", "regime"]).apply(
        calc_cliffs_delta,
    ).reset_index(name="value")

    fig, ax = plt.subplots(figsize=(15, 2))

    matrix = melted_df.pivot(
        index="phylometric",
        columns="regime",
        values="value",
    )
    matrix = matrix[
        sorted(
            matrix.columns,
            key=[
                "plain",
                "weak selection",
                "strong selection",
                "spatial structure",
                "weak ecology",
                "ecology",
                "rich ecology",
            ].index,
        )
    ]

    annot = []
    for metric, row in matrix.iterrows():

        def getvec(regime: str) -> np.array:
            return fil[fil["regime"] == regime][metric].to_numpy()

        annot.append(
            [
                describe_effect(getvec("plain"), getvec(regime))
                for regime in matrix.columns
            ],
        )

    tp.tee(
        sns.heatmap,
        matrix,
        annot=annot,
        fmt="",
        linewidths=2,
        cmap=sns.color_palette("vlag", as_cmap=True),
        center=0,
        cbar_kws={"label": "Cliff's delta"},
        teeplot_outattrs={
            **dict(
                zip(sensitivity_analysis_variables, group),
            ),
            **{
                "x": "regime",
                "y": "phylometric",
            },
        },
        teeplot_outexclude=["fmt"],
        vmin=-1,
        vmax=1,
    )
# Out:
# teeplots/epoch=0+mut_distn=default+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+viz=heatmap+x=regime+y=phylometric+ext=.png

# %% [markdown]
# ## regime heatmap signatures, with space

# %%
for (group, group_df) in df[
    df["regime"].isin(
        [
            "spatial structure",
            "weak ecology, spatial",
            "ecology, spatial",
            "rich ecology, spatial",
        ],
    )
].groupby(sensitivity_analysis_variables):

    fil = (
        group_df[(group_df["a"] == "collapsed-phylogeny")]
        .copy()
        .dropna(subset=["regime"])
    )
    fil["regime"] = fil["regime"].map(
        {
            "spatial structure": "plain",
            "weak ecology, spatial": "weak ecology",
            "ecology, spatial": "ecology",
            "rich ecology, spatial": "rich ecology",
        }
    )

    melted_df = fil.melt(
        id_vars=["regime"],
        value_vars=phylometrics,
    )
    melted_df["phylometric"] = melted_df["variable"]

    def calc_cliffs_delta(group) -> float:
        phylometric, regime = group.name
        return -cliffs_delta(
            fil[fil["regime"] == "plain"][phylometric],
            fil[fil["regime"] == regime][phylometric],
        )[0]

    melted_df = melted_df.groupby(["phylometric", "regime"]).apply(
        calc_cliffs_delta,
    ).reset_index(name="value")

    fig, ax = plt.subplots(figsize=(15, 2))

    matrix = melted_df.pivot(
        index="phylometric",
        columns="regime",
        values="value",
    )
    matrix = matrix[
        sorted(
            matrix.columns,
            key=[
                "plain",
                "weak ecology",
                "ecology",
                "rich ecology",
            ].index,
        )
    ]

    annot = []
    for metric, row in matrix.iterrows():

        def getvec(regime: str) -> np.array:
            return fil[fil["regime"] == regime][metric].to_numpy()

        annot.append(
            [
                describe_effect(getvec("plain"), getvec(regime))
                for regime in matrix.columns
            ],
        )

    tp.tee(
        sns.heatmap,
        matrix,
        annot=annot,
        fmt="",
        linewidths=2,
        cmap=sns.color_palette("vlag", as_cmap=True),
        center=0,
        cbar_kws={"label": "Clff's delta"},
        teeplot_outattrs={
            **dict(
                zip(sensitivity_analysis_variables, group),
            ),
            **{
                "x": "regime",
                "y": "phylometric",
                "spatial": "true",
            },
        },
        teeplot_outexclude=["fmt"],
        vmin=-1,
        vmax=1,
    )
# Out:
# teeplots/epoch=0+mut_distn=default+spatial=true+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+spatial=true+viz=heatmap+x=regime+y=phylometric+ext=.png

# %% [markdown]
# # stats: kruskal-wallis

# %%
records = []
for phylometric in phylometrics:
    for group, group_df in df[
   df["regime"].isin(
        [
            "spatial structure",
            "weak ecology, spatial",
            "ecology, spatial",
            "rich ecology, spatial",
        ],
    )
    ].groupby(
        sensitivity_analysis_variables, as_index=False
    ):
        kw_result, n = scipy_stats.kruskal(
            *(
                quality_series
                for quality, quality_series in group_df.groupby(["regime"])[
                    phylometric
                ]
            )
        ), ip.pophomogeneous(group_df.groupby(["regime"]).count()["a"])
        records.append(
            {
                **{
                    "n": n,
                    "N": len([*group_df.groupby(["regime"])]),
                    "phylometric": phylometric,
                },
                **dict(zip(["statistic", "p"], kw_result)),
                **dict(zip(sensitivity_analysis_variables, group)),
            }
        )

with pd.option_context("display.max_colwidth", None, "display.max_rows", None):
    out_df = (
        pd.DataFrame.from_records(records)
        .sort_values(
            sensitivity_analysis_variables,
        )
        .reset_index(drop=True)
    )
    display(out_df)
    os.makedirs("outdata", exist_ok=True)
    out_df.to_csv(
        "outdata/a=phylostatistics-comparison-between-regimes-kwallis+ext=.csv",
        index=False,
    )
# Out:
#     n  N                        phylometric  statistic             p  epoch  \
# 0  30  4                 colless-like index  15.223196  1.635513e-03      0
# 1  30  4             mean pairwise distance  20.933168  1.086947e-04      0
# 2  30  4              sum pairwise distance  56.421102  3.415676e-12      0
# 3  30  4  mean evolutionary distinctiveness  59.557741  7.306790e-13      0
#
#   mut_distn
# 0   default
# 1   default
# 2   default
# 3   default
