# %%
import itertools as it
import os

from cliffs_delta import cliffs_delta
from iterpop import iterpop as ip
import matplotlib as mpl
from matplotlib import pyplot as plt
from nbmetalog import nbmetalog as nbm
import numpy as np
import pandas as pd
from scipy import stats as scipy_stats
import seaborn as sns
from teeplot import teeplot as tp

from pylib import describe_effect

# %%
# prints metadata about notebook runtime
nbm.print_metadata()
# Out:
# context: ci
# hostname: fv-az661-109
# interpreter: 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
# nbcellexec: null
# nbname: reconstructed-tree-phylometrics
# nbpath: /home/runner/work/hstrat-evolutionary-inference/hstrat-evolutionary-inference/binder/avida-individual-splayed/reconstructed-tree-phylometrics.ipynb
# revision: null
# session: e81540e7-5d47-4270-bdb4-b4ee47251250
# timestamp: 2024-08-11T00:31:57Z00:00
#
#
# IPython==8.13.0
# keyname==0.5.2
# yaml==6.0
# iterpop==0.4.1
# matplotlib==3.7.1
# nbmetalog==0.2.6
# numpy==1.21.6
# pandas==1.3.5
# scipy==1.7.3
# seaborn==0.12.1
# teeplot==1.0.1
# re==2.2.1
# comm==0.2.2
# logging==0.5.1.2
# psutil==5.9.8
# zmq==24.0.1
# json==2.0.9
# ipykernel==6.29.3

# %%
df = pd.read_csv("https://osf.io/acvf2/download")
dfdigest = np.bitwise_xor.reduce(
    pd.util.hash_pandas_object(df),
)
print("{:x}".format(dfdigest))
df
# Out:
# 78d782a590fd0a3b
#                         a  epoch mut_distn                        treatment  \
# 0     collapsed-phylogeny      0   default        individual_selection_weak
# 1     collapsed-phylogeny      0   default                    spatial_plain
# 2     collapsed-phylogeny      0   default          individual_ecology_weak
# 3     collapsed-phylogeny      0   default  individual_spatial_ecology_rich
# 4     collapsed-phylogeny      0   default                 selection_strong
# ...                   ...    ...       ...                              ...
# 2395   reconstructed-tree      0   default        individual_selection_weak
# 2396   reconstructed-tree      0   default        individual_selection_weak
# 2397   reconstructed-tree      0   default        individual_selection_weak
# 2398   reconstructed-tree      0   default  individual_spatial_ecology_some
# 2399   reconstructed-tree      0   default  individual_spatial_ecology_rich
#
#       seed  phylogeny-snapshot-100000.csv  \
# 0      166                            NaN
# 1      285                            NaN
# 2       97                            NaN
# 3      202                            NaN
# 4      134                            NaN
# ...    ...                            ...
# 2395   174                            NaN
# 2396   155                            NaN
# 2397   151                            NaN
# 2398   221                            NaN
# 2399   184                            NaN
#
#                                                       _  colless_like_index  \
# 0     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        22408.063200
# 1     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        14547.062036
# 2     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        29975.648222
# 3     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        17106.161085
# 4     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20065.836953
# ...                                                 ...                 ...
# 2395  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        16752.785992
# 2396  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        19985.466444
# 2397  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        19463.696000
# 2398  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15993.731189
# 2399  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20280.158309
#
#       average_depth  average_origin_time  ...  \
# 0               inf         99905.591537  ...
# 1               inf         99867.606183  ...
# 2               inf         99952.248655  ...
# 3               inf         99842.062739  ...
# 4               inf         99881.033582  ...
# ...             ...                  ...  ...
# 2395      27.948569         99949.865273  ...
# 2396      30.306366         99913.054929  ...
# 2397      29.489823         99915.578761  ...
# 2398      27.643475         99914.543971  ...
# 2399      29.474153         99850.696504  ...
#
#       variance_pairwise_distance_branch_only  mrca_depth  sackin_index  \
# 0                                  42.099054           1         45357
# 1                                  46.616294           1         34635
# 2                                  33.270348           1         51577
# 3                                  28.453829           1         41224
# 4                                  49.649800           1         43928
# ...                                      ...         ...           ...
# 2395                               28.903374           1         31246
# 2396                               33.769426           1         34276
# 2397                               31.737664           1         33323
# 2398                               27.113047           1         31983
# 2399                               25.083053           1         34779
#
#       mean_evolutionary_distinctiveness  sum_evolutionary_distinctiveness  \
# 0                            108.871856                     321825.207340
# 1                            133.976702                     320070.339908
# 2                             39.339103                     114004.720671
# 3                            243.632191                     720664.020951
# 4                            122.695857                     343671.095395
# ...                                 ...                               ...
# 2395                          55.940519                     125083.000000
# 2396                         125.896994                     284779.000000
# 2397                         120.667920                     272709.500000
# 2398                         134.458081                     311136.000000
# 2399                         273.341525                     645086.000000
#
#       variance_evolutionary_distinctiveness  resolution  subsampling-fraction  \
# 0                              11442.394743         NaN                   NaN
# 1                               7650.381356         NaN                   NaN
# 2                                594.004713         NaN                   NaN
# 3                              12390.978715         NaN                   NaN
# 4                               9794.843999         NaN                   NaN
# ...                                     ...         ...                   ...
# 2395                             932.185874        10.0                   1.0
# 2396                            6755.799258       100.0                   1.0
# 2397                            4576.502673        33.0                   1.0
# 2398                            6716.805266        10.0                   1.0
# 2399                           83659.574455        10.0                   1.0
#
#       trie-postprocess      ext
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...                ...      ...
# 2395             naive  .csv.gz
# 2396             naive  .csv.gz
# 2397             naive  .csv.gz
# 2398             naive  .csv.gz
# 2399             naive  .csv.gz
#
# [2400 rows x 36 columns]

# %%
# phylometrics whittled down to descriptive, non-redundant set
phylometrics = [
    #     'diversity',
    "colless_like_index",
    #     'average_depth',
    #     'average_origin_time',
    #     'average_origin_time_normalized',
    #     'max_depth',
    "mean_pairwise_distance",
    #     'mean_pairwise_distance_branch_only',
    #     'num_active',
    # "num_ancestors",
    "sum_distance",
    #     'num_outside',
    #     'num_roots',
    #     'num_taxa',
    #     'phylogenetic_diversity',
    #     'sum_pairwise_distance',
    #     'sum_pairwise_distance_branch_only',
    #     'total_orgs',
    #     'tree_size',
    #     'variance_pairwise_distance',
    #     'variance_pairwise_distance_branch_only',
    #     'mrca_depth',
    #     'sackin_index',
    "mean_evolutionary_distinctiveness",
    #     'sum_evolutionary_distinctiveness',
    #     'variance_evolutionary_distinctiveness',
]

# %%
methodological_variables = [
    "resolution",
]

# %%
evolutionary_variables = [
]

# %%
sensitivity_analysis_variables = [
    "epoch",
    "mut_distn",
]

# %%
fixed_variables = [
    "subsampling-fraction",  # only use 1.0
    "trie-postprocess",  # just use naive postprocessing for now
]

# %%
# ensure fixed variables
df = df[
    ((df["subsampling-fraction"] == 1.0) | df["subsampling-fraction"].isna())
    & ((df["trie-postprocess"] == "naive") | df["trie-postprocess"].isna())
].copy()

for fixed_variable in fixed_variables:
    assert len(df[fixed_variable].dropna().unique()) == 1

df
# Out:
#                         a  epoch mut_distn                        treatment  \
# 0     collapsed-phylogeny      0   default        individual_selection_weak
# 1     collapsed-phylogeny      0   default                    spatial_plain
# 2     collapsed-phylogeny      0   default          individual_ecology_weak
# 3     collapsed-phylogeny      0   default  individual_spatial_ecology_rich
# 4     collapsed-phylogeny      0   default                 selection_strong
# ...                   ...    ...       ...                              ...
# 2395   reconstructed-tree      0   default        individual_selection_weak
# 2396   reconstructed-tree      0   default        individual_selection_weak
# 2397   reconstructed-tree      0   default        individual_selection_weak
# 2398   reconstructed-tree      0   default  individual_spatial_ecology_some
# 2399   reconstructed-tree      0   default  individual_spatial_ecology_rich
#
#       seed  phylogeny-snapshot-100000.csv  \
# 0      166                            NaN
# 1      285                            NaN
# 2       97                            NaN
# 3      202                            NaN
# 4      134                            NaN
# ...    ...                            ...
# 2395   174                            NaN
# 2396   155                            NaN
# 2397   151                            NaN
# 2398   221                            NaN
# 2399   184                            NaN
#
#                                                       _  colless_like_index  \
# 0     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        22408.063200
# 1     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        14547.062036
# 2     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        29975.648222
# 3     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        17106.161085
# 4     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20065.836953
# ...                                                 ...                 ...
# 2395  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        16752.785992
# 2396  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        19985.466444
# 2397  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        19463.696000
# 2398  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15993.731189
# 2399  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20280.158309
#
#       average_depth  average_origin_time  ...  \
# 0               inf         99905.591537  ...
# 1               inf         99867.606183  ...
# 2               inf         99952.248655  ...
# 3               inf         99842.062739  ...
# 4               inf         99881.033582  ...
# ...             ...                  ...  ...
# 2395      27.948569         99949.865273  ...
# 2396      30.306366         99913.054929  ...
# 2397      29.489823         99915.578761  ...
# 2398      27.643475         99914.543971  ...
# 2399      29.474153         99850.696504  ...
#
#       variance_pairwise_distance_branch_only  mrca_depth  sackin_index  \
# 0                                  42.099054           1         45357
# 1                                  46.616294           1         34635
# 2                                  33.270348           1         51577
# 3                                  28.453829           1         41224
# 4                                  49.649800           1         43928
# ...                                      ...         ...           ...
# 2395                               28.903374           1         31246
# 2396                               33.769426           1         34276
# 2397                               31.737664           1         33323
# 2398                               27.113047           1         31983
# 2399                               25.083053           1         34779
#
#       mean_evolutionary_distinctiveness  sum_evolutionary_distinctiveness  \
# 0                            108.871856                     321825.207340
# 1                            133.976702                     320070.339908
# 2                             39.339103                     114004.720671
# 3                            243.632191                     720664.020951
# 4                            122.695857                     343671.095395
# ...                                 ...                               ...
# 2395                          55.940519                     125083.000000
# 2396                         125.896994                     284779.000000
# 2397                         120.667920                     272709.500000
# 2398                         134.458081                     311136.000000
# 2399                         273.341525                     645086.000000
#
#       variance_evolutionary_distinctiveness  resolution  subsampling-fraction  \
# 0                              11442.394743         NaN                   NaN
# 1                               7650.381356         NaN                   NaN
# 2                                594.004713         NaN                   NaN
# 3                              12390.978715         NaN                   NaN
# 4                               9794.843999         NaN                   NaN
# ...                                     ...         ...                   ...
# 2395                             932.185874        10.0                   1.0
# 2396                            6755.799258       100.0                   1.0
# 2397                            4576.502673        33.0                   1.0
# 2398                            6716.805266        10.0                   1.0
# 2399                           83659.574455        10.0                   1.0
#
#       trie-postprocess      ext
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...                ...      ...
# 2395             naive  .csv.gz
# 2396             naive  .csv.gz
# 2397             naive  .csv.gz
# 2398             naive  .csv.gz
# 2399             naive  .csv.gz
#
# [2400 rows x 36 columns]

# %%
# exclude extraneous variable values
df = df[(df["a"] != "consolidated-phylogeny")].copy()

df
# Out:
#                         a  epoch mut_distn                        treatment  \
# 0     collapsed-phylogeny      0   default        individual_selection_weak
# 1     collapsed-phylogeny      0   default                    spatial_plain
# 2     collapsed-phylogeny      0   default          individual_ecology_weak
# 3     collapsed-phylogeny      0   default  individual_spatial_ecology_rich
# 4     collapsed-phylogeny      0   default                 selection_strong
# ...                   ...    ...       ...                              ...
# 2395   reconstructed-tree      0   default        individual_selection_weak
# 2396   reconstructed-tree      0   default        individual_selection_weak
# 2397   reconstructed-tree      0   default        individual_selection_weak
# 2398   reconstructed-tree      0   default  individual_spatial_ecology_some
# 2399   reconstructed-tree      0   default  individual_spatial_ecology_rich
#
#       seed  phylogeny-snapshot-100000.csv  \
# 0      166                            NaN
# 1      285                            NaN
# 2       97                            NaN
# 3      202                            NaN
# 4      134                            NaN
# ...    ...                            ...
# 2395   174                            NaN
# 2396   155                            NaN
# 2397   151                            NaN
# 2398   221                            NaN
# 2399   184                            NaN
#
#                                                       _  colless_like_index  \
# 0     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        22408.063200
# 1     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        14547.062036
# 2     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        29975.648222
# 3     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        17106.161085
# 4     /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20065.836953
# ...                                                 ...                 ...
# 2395  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        16752.785992
# 2396  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        19985.466444
# 2397  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        19463.696000
# 2398  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        15993.731189
# 2399  /mnt/home/mmore500/scratch/data/hstrat-evoluti...        20280.158309
#
#       average_depth  average_origin_time  ...  \
# 0               inf         99905.591537  ...
# 1               inf         99867.606183  ...
# 2               inf         99952.248655  ...
# 3               inf         99842.062739  ...
# 4               inf         99881.033582  ...
# ...             ...                  ...  ...
# 2395      27.948569         99949.865273  ...
# 2396      30.306366         99913.054929  ...
# 2397      29.489823         99915.578761  ...
# 2398      27.643475         99914.543971  ...
# 2399      29.474153         99850.696504  ...
#
#       variance_pairwise_distance_branch_only  mrca_depth  sackin_index  \
# 0                                  42.099054           1         45357
# 1                                  46.616294           1         34635
# 2                                  33.270348           1         51577
# 3                                  28.453829           1         41224
# 4                                  49.649800           1         43928
# ...                                      ...         ...           ...
# 2395                               28.903374           1         31246
# 2396                               33.769426           1         34276
# 2397                               31.737664           1         33323
# 2398                               27.113047           1         31983
# 2399                               25.083053           1         34779
#
#       mean_evolutionary_distinctiveness  sum_evolutionary_distinctiveness  \
# 0                            108.871856                     321825.207340
# 1                            133.976702                     320070.339908
# 2                             39.339103                     114004.720671
# 3                            243.632191                     720664.020951
# 4                            122.695857                     343671.095395
# ...                                 ...                               ...
# 2395                          55.940519                     125083.000000
# 2396                         125.896994                     284779.000000
# 2397                         120.667920                     272709.500000
# 2398                         134.458081                     311136.000000
# 2399                         273.341525                     645086.000000
#
#       variance_evolutionary_distinctiveness  resolution  subsampling-fraction  \
# 0                              11442.394743         NaN                   NaN
# 1                               7650.381356         NaN                   NaN
# 2                                594.004713         NaN                   NaN
# 3                              12390.978715         NaN                   NaN
# 4                               9794.843999         NaN                   NaN
# ...                                     ...         ...                   ...
# 2395                             932.185874        10.0                   1.0
# 2396                            6755.799258       100.0                   1.0
# 2397                            4576.502673        33.0                   1.0
# 2398                            6716.805266        10.0                   1.0
# 2399                           83659.574455        10.0                   1.0
#
#       trie-postprocess      ext
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...                ...      ...
# 2395             naive  .csv.gz
# 2396             naive  .csv.gz
# 2397             naive  .csv.gz
# 2398             naive  .csv.gz
# 2399             naive  .csv.gz
#
# [2400 rows x 36 columns]

# %%
df["a"].unique()
# Out:
# array(['collapsed-phylogeny', 'reconstructed-tree'], dtype=object)

# %%
df["regime"] = df["treatment"].map(
    {
        "individual_plain": "plain",
        "individual_selection_weak": "weak selection",
        "individual_selection_strong": "strong selection",
        "individual_spatial_plain": "spatial structure",
        "individual_ecology_some": "ecology",
        "individual_ecology_rich": "rich ecology",
        "individual_spatial_ecology_rich": "rich ecology, spatial",
        "individual_spatial_ecology_some": "ecology, spatial",
        "individual_ecology_weak": "weak ecology",
        "individual_spatial_ecology_weak": "weak ecology, spatial",
    },
)
df["regime"].unique()
# Out:
# array(['weak selection', nan, 'weak ecology', 'rich ecology, spatial',
#        'spatial structure', 'weak ecology, spatial', 'rich ecology',
#        'plain', 'ecology', 'ecology, spatial', 'strong selection'],
#       dtype=object)

# %%
df["quality"] = df.apply(
    lambda row: {
        ("reconstructed-tree", 3.0): "33% resolution",
        ("reconstructed-tree", 10.0): "10% resolution",
        ("reconstructed-tree", 33.0): "3% resolution",
        ("reconstructed-tree", 100.0): "1% resolution",
        ("collapsed-phylogeny", 0): "perfect resolution",
    }.get(
        tuple(row[["a", "resolution"]].fillna(0)),
        np.nan,  # default
    ),
    axis="columns",
)
df = df.dropna(axis="index", subset=["quality"]).copy()
df["quality"].unique()
# Out:
# array(['perfect resolution', '1% resolution', '10% resolution',
#        '3% resolution', '33% resolution'], dtype=object)

# %% [markdown]
# # Phylometrics by Regime, Reconstructed Data

# %%
melted_df = df[
    df["regime"].isin(
        [
            "plain",
            "weak selection",
            "strong selection",
            "spatial structure",
            "weak ecology",
            "ecology",
            "rich ecology",
        ],
    )
].melt(
    id_vars=evolutionary_variables
    + methodological_variables
    + sensitivity_analysis_variables
    + ["regime", "a", "quality"],
    value_vars=phylometrics,
)
melted_df["phylometric"] = melted_df["variable"]
melted_df
# Out:
#       resolution  epoch mut_distn             regime                    a  \
# 0            NaN      0   default     weak selection  collapsed-phylogeny
# 1            NaN      0   default       weak ecology  collapsed-phylogeny
# 2            NaN      0   default  spatial structure  collapsed-phylogeny
# 3            NaN      0   default       rich ecology  collapsed-phylogeny
# 4            NaN      0   default     weak selection  collapsed-phylogeny
# ...          ...    ...       ...                ...                  ...
# 4195         3.0      0   default       weak ecology   reconstructed-tree
# 4196        10.0      0   default            ecology   reconstructed-tree
# 4197        10.0      0   default     weak selection   reconstructed-tree
# 4198       100.0      0   default     weak selection   reconstructed-tree
# 4199        33.0      0   default     weak selection   reconstructed-tree
#
#                  quality                           variable         value  \
# 0     perfect resolution                 colless_like_index  22408.063200
# 1     perfect resolution                 colless_like_index  29975.648222
# 2     perfect resolution                 colless_like_index  17818.014160
# 3     perfect resolution                 colless_like_index  16863.773837
# 4     perfect resolution                 colless_like_index  20554.438615
# ...                  ...                                ...           ...
# 4195      33% resolution  mean_evolutionary_distinctiveness    183.709839
# 4196      10% resolution  mean_evolutionary_distinctiveness     79.809167
# 4197      10% resolution  mean_evolutionary_distinctiveness     55.940519
# 4198       1% resolution  mean_evolutionary_distinctiveness    125.896994
# 4199       3% resolution  mean_evolutionary_distinctiveness    120.667920
#
#                             phylometric
# 0                    colless_like_index
# 1                    colless_like_index
# 2                    colless_like_index
# 3                    colless_like_index
# 4                    colless_like_index
# ...                                 ...
# 4195  mean_evolutionary_distinctiveness
# 4196  mean_evolutionary_distinctiveness
# 4197  mean_evolutionary_distinctiveness
# 4198  mean_evolutionary_distinctiveness
# 4199  mean_evolutionary_distinctiveness
#
# [4200 rows x 9 columns]

# %%
def make_do_plot(plotter):
    def do_plot(data, col, row, x, y):
        g = sns.FacetGrid(
            data,
            col=col,
            row=row,
            row_order=[
                "plain",
                "weak selection",
                "strong selection",
                "spatial structure",
                "weak ecology",
                "ecology",
                "rich ecology",
            ],
            sharex="col",
            margin_titles=True,
        )
        g.map(
            plotter,
            x,
            y,
            order=[
                "33% resolution",
                "10% resolution",
                "3% resolution",
                "1% resolution",
                "perfect resolution",
            ],
            palette=sns.color_palette("Set1", 5),
        )

    return do_plot


for viz, (group, group_df) in it.product(
    [
        sns.barplot,
        sns.boxplot,
        sns.violinplot,
    ],
    melted_df.groupby(sensitivity_analysis_variables),
):
    do_plot = make_do_plot(viz)
    do_plot.__name__ = viz.__name__
    tp.tee(
        do_plot,
        data=group_df,
        col="phylometric",
        row="regime",
        x="value",
        y="quality",
        teeplot_outattrs=dict(
            zip(sensitivity_analysis_variables, group),
        ),
    )
# Out:
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=barplot+x=value+y=quality+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=barplot+x=value+y=quality+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=boxplot+x=value+y=quality+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=boxplot+x=value+y=quality+ext=.png
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=violinplot+x=value+y=quality+ext=.pdf
# teeplots/col=phylometric+epoch=0+mut_distn=default+row=regime+viz=violinplot+x=value+y=quality+ext=.png

# %% [markdown]
# # regime heatmap signatures
#
# cliff's delta

# %%
group_variables = sensitivity_analysis_variables + ["resolution"]
for (group, group_df) in df[
    df["regime"].isin(
        [
            "plain",
            "weak selection",
            "strong selection",
            "spatial structure",
            "weak ecology",
            "ecology",
            "rich ecology",
        ],
    )
].groupby(
    group_variables,
):

    fil = (
        group_df[group_df["a"] == "reconstructed-tree"]
        .copy()
        .dropna(subset=["regime"])
    )

    melted_df = fil.melt(
        id_vars=["regime"],
        value_vars=phylometrics,
    )
    melted_df["phylometric"] = melted_df["variable"]

    def calc_cliffs_delta(group) -> float:
        phylometric, regime = group.name
        return -cliffs_delta(
            fil[fil["regime"] == "plain"][phylometric],
            fil[fil["regime"] == regime][phylometric],
        )[0]

    melted_df = melted_df.groupby(["phylometric", "regime"]).apply(
        calc_cliffs_delta,
    ).reset_index(name="value")

    fig, ax = plt.subplots(figsize=(15, 2))

    matrix = melted_df.pivot(
        index="phylometric",
        columns="regime",
        values="value",
    )
    matrix = matrix[
        sorted(
            matrix.columns,
            key=[
                "plain",
                "weak selection",
                "strong selection",
                "spatial structure",
                "weak ecology",
                "ecology",
                "rich ecology",
            ].index,
        )
    ]

    annot = []
    for metric, row in matrix.iterrows():

        def getvec(regime: str) -> np.array:
            return fil[fil["regime"] == regime][metric].to_numpy()

        annot.append(
            [
                describe_effect(getvec("plain"), getvec(regime))
                for regime in matrix.columns
            ],
        )

    tp.tee(
        sns.heatmap,
        matrix,
        annot=annot,
        fmt="",
        linewidths=2,
        cmap=sns.color_palette("vlag", as_cmap=True),
        center=0,
        cbar_kws={"label": "Cliff's delta"},
        teeplot_outattrs={
            **dict(
                zip(group_variables, group),
            ),
            **{
                "x": "regime",
                "y": "phylometric",
            },
        },
        teeplot_outexclude=["fmt"],
        vmin=-1,
        vmax=1,
    )
# Out:
# teeplots/epoch=0+mut_distn=default+resolution=3.0+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+resolution=3.0+viz=heatmap+x=regime+y=phylometric+ext=.png
# teeplots/epoch=0+mut_distn=default+resolution=10.0+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+resolution=10.0+viz=heatmap+x=regime+y=phylometric+ext=.png
# teeplots/epoch=0+mut_distn=default+resolution=33.0+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+resolution=33.0+viz=heatmap+x=regime+y=phylometric+ext=.png
# teeplots/epoch=0+mut_distn=default+resolution=100.0+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+mut_distn=default+resolution=100.0+viz=heatmap+x=regime+y=phylometric+ext=.png

# %% [markdown]
# # stats: comparison against perfect quality

# %%
records = []
for phylometric in phylometrics:
    for group, group_df in df.groupby(
        ["regime", *sensitivity_analysis_variables], as_index=False
    ):
        for quality in group_df["quality"].unique():
            if quality == "perfect resolution":
                continue
            kw_result, n = scipy_stats.wilcoxon(
                group_df[group_df["quality"] == "perfect resolution"][
                    phylometric
                ],
                group_df[group_df["quality"] == quality][phylometric],
            ), ip.pophomogeneous(group_df.groupby(["quality"]).count()["a"])
            records.append(
                {
                    **{"quality": quality, "n": n, "phylometric": phylometric},
                    **dict(zip(["statistic", "p"], kw_result)),
                    **dict(
                        zip(["regime", *sensitivity_analysis_variables], group)
                    ),
                }
            )

with pd.option_context("display.max_colwidth", None, "display.max_rows", None):
    out_df = (
        pd.DataFrame.from_records(records)
        .sort_values(
            [*sensitivity_analysis_variables, "regime", "phylometric"],
        )
        .reset_index(drop=True)
    )
    display(out_df)
    os.makedirs("outdata", exist_ok=True)
    out_df.to_csv(
        "outdata/a=phylostatistics-comparison-between-resolutions-allpairs-wilcox+ext=.csv",
        index=False,
    )
# Out:
#             quality   n                        phylometric  statistic  \
# 0    10% resolution  30                 colless_like_index      127.0
# 1    33% resolution  30                 colless_like_index       35.0
# 2     3% resolution  30                 colless_like_index      139.0
# 3     1% resolution  30                 colless_like_index      141.0
# 4    10% resolution  30  mean_evolutionary_distinctiveness       67.0
# 5    33% resolution  30  mean_evolutionary_distinctiveness       39.0
# 6     3% resolution  30  mean_evolutionary_distinctiveness       50.0
# 7     1% resolution  30  mean_evolutionary_distinctiveness       63.0
# 8    10% resolution  30             mean_pairwise_distance      102.0
# 9    33% resolution  30             mean_pairwise_distance        0.0
# 10    3% resolution  30             mean_pairwise_distance      127.0
# 11    1% resolution  30             mean_pairwise_distance      149.0
# 12   10% resolution  30                       sum_distance      222.0
# 13   33% resolution  30                       sum_distance      217.0
# 14    3% resolution  30                       sum_distance      230.0
# 15    1% resolution  30                       sum_distance      232.0
# 16    3% resolution  30                 colless_like_index      125.0
# 17    1% resolution  30                 colless_like_index      139.5
# 18   33% resolution  30                 colless_like_index       46.0
# 19   10% resolution  30                 colless_like_index      121.0
# 20    3% resolution  30  mean_evolutionary_distinctiveness       97.0
# 21    1% resolution  30  mean_evolutionary_distinctiveness       85.0
# 22   33% resolution  30  mean_evolutionary_distinctiveness       80.0
# 23   10% resolution  30  mean_evolutionary_distinctiveness       79.0
# 24    3% resolution  30             mean_pairwise_distance      181.0
# 25    1% resolution  30             mean_pairwise_distance      205.0
# 26   33% resolution  30             mean_pairwise_distance       40.0
# 27   10% resolution  30             mean_pairwise_distance      157.0
# 28    3% resolution  30                       sum_distance      222.0
# 29    1% resolution  30                       sum_distance      231.0
# 30   33% resolution  30                       sum_distance      218.0
# 31   10% resolution  30                       sum_distance      216.0
# 32    1% resolution  30                 colless_like_index      147.0
# 33   33% resolution  30                 colless_like_index       62.0
# 34   10% resolution  30                 colless_like_index      119.0
# 35    3% resolution  30                 colless_like_index      172.0
# 36    1% resolution  30  mean_evolutionary_distinctiveness      138.0
# 37   33% resolution  30  mean_evolutionary_distinctiveness      151.0
# 38   10% resolution  30  mean_evolutionary_distinctiveness      119.0
# 39    3% resolution  30  mean_evolutionary_distinctiveness      142.0
# 40    1% resolution  30             mean_pairwise_distance      141.0
# 41   33% resolution  30             mean_pairwise_distance       11.0
# 42   10% resolution  30             mean_pairwise_distance       73.0
# 43    3% resolution  30             mean_pairwise_distance      165.0
# 44    1% resolution  30                       sum_distance      223.0
# 45   33% resolution  30                       sum_distance      223.0
# 46   10% resolution  30                       sum_distance      224.0
# 47    3% resolution  30                       sum_distance      225.0
# 48   10% resolution  30                 colless_like_index       96.0
# 49   33% resolution  30                 colless_like_index       68.0
# 50    3% resolution  30                 colless_like_index      131.0
# 51    1% resolution  30                 colless_like_index      125.0
# 52   10% resolution  30  mean_evolutionary_distinctiveness       60.0
# 53   33% resolution  30  mean_evolutionary_distinctiveness       81.0
# 54    3% resolution  30  mean_evolutionary_distinctiveness       31.0
# 55    1% resolution  30  mean_evolutionary_distinctiveness       74.0
# 56   10% resolution  30             mean_pairwise_distance       68.0
# 57   33% resolution  30             mean_pairwise_distance       63.0
# 58    3% resolution  30             mean_pairwise_distance      137.0
# 59    1% resolution  30             mean_pairwise_distance       97.0
# 60   10% resolution  30                       sum_distance      226.0
# 61   33% resolution  30                       sum_distance      223.0
# 62    3% resolution  30                       sum_distance      216.0
# 63    1% resolution  30                       sum_distance      225.0
# 64    1% resolution  30                 colless_like_index      135.0
# 65   10% resolution  30                 colless_like_index      104.0
# 66    3% resolution  30                 colless_like_index      153.0
# 67   33% resolution  30                 colless_like_index       49.0
# 68    1% resolution  30  mean_evolutionary_distinctiveness       21.0
# 69   10% resolution  30  mean_evolutionary_distinctiveness       11.0
# 70    3% resolution  30  mean_evolutionary_distinctiveness       23.0
# 71   33% resolution  30  mean_evolutionary_distinctiveness       20.0
# 72    1% resolution  30             mean_pairwise_distance      178.0
# 73   10% resolution  30             mean_pairwise_distance      137.0
# 74    3% resolution  30             mean_pairwise_distance      174.0
# 75   33% resolution  30             mean_pairwise_distance       62.0
# 76    1% resolution  30                       sum_distance      227.0
# 77   10% resolution  30                       sum_distance      219.0
# 78    3% resolution  30                       sum_distance      230.0
# 79   33% resolution  30                       sum_distance      221.0
# 80   10% resolution  30                 colless_like_index      120.0
# 81    1% resolution  30                 colless_like_index      168.0
# 82   33% resolution  30                 colless_like_index       56.0
# 83    3% resolution  30                 colless_like_index      130.0
# 84   10% resolution  30  mean_evolutionary_distinctiveness      117.0
# 85    1% resolution  30  mean_evolutionary_distinctiveness      135.0
# 86   33% resolution  30  mean_evolutionary_distinctiveness      139.0
# 87    3% resolution  30  mean_evolutionary_distinctiveness      143.0
# 88   10% resolution  30             mean_pairwise_distance      166.0
# 89    1% resolution  30             mean_pairwise_distance      201.0
# 90   33% resolution  30             mean_pairwise_distance       59.0
# 91    3% resolution  30             mean_pairwise_distance      190.0
# 92   10% resolution  30                       sum_distance      231.0
# 93    1% resolution  30                       sum_distance      217.0
# 94   33% resolution  30                       sum_distance      216.0
# 95    3% resolution  30                       sum_distance      228.0
# 96    1% resolution  30                 colless_like_index      146.0
# 97    3% resolution  30                 colless_like_index      153.0
# 98   10% resolution  30                 colless_like_index      118.0
# 99   33% resolution  30                 colless_like_index       25.0
# 100   1% resolution  30  mean_evolutionary_distinctiveness      102.0
# 101   3% resolution  30  mean_evolutionary_distinctiveness      115.0
# 102  10% resolution  30  mean_evolutionary_distinctiveness      100.0
# 103  33% resolution  30  mean_evolutionary_distinctiveness       98.0
# 104   1% resolution  30             mean_pairwise_distance      126.0
# 105   3% resolution  30             mean_pairwise_distance      120.0
# 106  10% resolution  30             mean_pairwise_distance       88.0
# 107  33% resolution  30             mean_pairwise_distance       15.0
# 108   1% resolution  30                       sum_distance      225.0
# 109   3% resolution  30                       sum_distance      230.0
# 110  10% resolution  30                       sum_distance      214.0
# 111  33% resolution  30                       sum_distance      217.0
# 112   1% resolution  30                 colless_like_index      167.0
# 113  33% resolution  30                 colless_like_index       76.0
# 114   3% resolution  30                 colless_like_index      180.0
# 115  10% resolution  30                 colless_like_index      142.0
# 116   1% resolution  30  mean_evolutionary_distinctiveness      159.0
# 117  33% resolution  30  mean_evolutionary_distinctiveness      148.0
# 118   3% resolution  30  mean_evolutionary_distinctiveness      140.0
# 119  10% resolution  30  mean_evolutionary_distinctiveness      170.0
# 120   1% resolution  30             mean_pairwise_distance      116.0
# 121  33% resolution  30             mean_pairwise_distance        5.0
# 122   3% resolution  30             mean_pairwise_distance      131.0
# 123  10% resolution  30             mean_pairwise_distance       69.0
# 124   1% resolution  30                       sum_distance      222.0
# 125  33% resolution  30                       sum_distance      225.0
# 126   3% resolution  30                       sum_distance      222.0
# 127  10% resolution  30                       sum_distance      225.0
# 128  10% resolution  30                 colless_like_index      157.0
# 129  33% resolution  30                 colless_like_index       98.0
# 130   3% resolution  30                 colless_like_index      170.0
# 131   1% resolution  30                 colless_like_index      176.0
# 132  10% resolution  30  mean_evolutionary_distinctiveness      147.0
# 133  33% resolution  30  mean_evolutionary_distinctiveness      157.0
# 134   3% resolution  30  mean_evolutionary_distinctiveness      139.0
# 135   1% resolution  30  mean_evolutionary_distinctiveness      148.0
# 136  10% resolution  30             mean_pairwise_distance      173.0
# 137  33% resolution  30             mean_pairwise_distance       97.0
# 138   3% resolution  30             mean_pairwise_distance      178.0
# 139   1% resolution  30             mean_pairwise_distance      205.0
# 140  10% resolution  30                       sum_distance      232.0
# 141  33% resolution  30                       sum_distance      231.0
# 142   3% resolution  30                       sum_distance      226.0
# 143   1% resolution  30                       sum_distance      226.0
# 144   3% resolution  30                 colless_like_index      158.0
# 145  33% resolution  30                 colless_like_index       50.0
# 146  10% resolution  30                 colless_like_index       89.0
# 147   1% resolution  30                 colless_like_index      161.0
# 148   3% resolution  30  mean_evolutionary_distinctiveness      147.0
# 149  33% resolution  30  mean_evolutionary_distinctiveness      116.0
# 150  10% resolution  30  mean_evolutionary_distinctiveness      131.0
# 151   1% resolution  30  mean_evolutionary_distinctiveness      137.0
# 152   3% resolution  30             mean_pairwise_distance      117.0
# 153  33% resolution  30             mean_pairwise_distance        5.0
# 154  10% resolution  30             mean_pairwise_distance       52.0
# 155   1% resolution  30             mean_pairwise_distance      132.0
# 156   3% resolution  30                       sum_distance      213.0
# 157  33% resolution  30                       sum_distance      225.0
# 158  10% resolution  30                       sum_distance      207.0
# 159   1% resolution  30                       sum_distance      227.0
#
#             p                 regime  epoch mut_distn
# 0    0.030010                ecology      0   default
# 1    0.000049                ecology      0   default
# 2    0.054463                ecology      0   default
# 3    0.059836                ecology      0   default
# 4    0.000664                ecology      0   default
# 5    0.000069                ecology      0   default
# 6    0.000174                ecology      0   default
# 7    0.000490                ecology      0   default
# 8    0.007271                ecology      0   default
# 9    0.000002                ecology      0   default
# 10   0.030010                ecology      0   default
# 11   0.085896                ecology      0   default
# 12   0.829013                ecology      0   default
# 13   0.749871                ecology      0   default
# 14   0.958990                ecology      0   default
# 15   0.991795                ecology      0   default
# 16   0.027029       ecology, spatial      0   default
# 17   0.055760       ecology, spatial      0   default
# 18   0.000125       ecology, spatial      0   default
# 19   0.021827       ecology, spatial      0   default
# 20   0.005320       ecology, spatial      0   default
# 21   0.002415       ecology, spatial      0   default
# 22   0.001709       ecology, spatial      0   default
# 23   0.001593       ecology, spatial      0   default
# 24   0.289477       ecology, spatial      0   default
# 25   0.571646       ecology, spatial      0   default
# 26   0.000075       ecology, spatial      0   default
# 27   0.120445       ecology, spatial      0   default
# 28   0.829013       ecology, spatial      0   default
# 29   0.975387       ecology, spatial      0   default
# 30   0.765519       ecology, spatial      0   default
# 31   0.734325       ecology, spatial      0   default
# 32   0.078647                  plain      0   default
# 33   0.000453                  plain      0   default
# 34   0.019569                  plain      0   default
# 35   0.213358                  plain      0   default
# 36   0.051931                  plain      0   default
# 37   0.093676                  plain      0   default
# 38   0.019569                  plain      0   default
# 39   0.062683                  plain      0   default
# 40   0.059836                  plain      0   default
# 41   0.000005                  plain      0   default
# 42   0.001036                  plain      0   default
# 43   0.165027                  plain      0   default
# 44   0.845080                  plain      0   default
# 45   0.845080                  plain      0   default
# 46   0.861213                  plain      0   default
# 47   0.877403                  plain      0   default
# 48   0.004992           rich ecology      0   default
# 49   0.000716           rich ecology      0   default
# 50   0.036826           rich ecology      0   default
# 51   0.027029           rich ecology      0   default
# 52   0.000388           rich ecology      0   default
# 53   0.001833           rich ecology      0   default
# 54   0.000034           rich ecology      0   default
# 55   0.001114           rich ecology      0   default
# 56   0.000716           rich ecology      0   default
# 57   0.000490           rich ecology      0   default
# 58   0.049498           rich ecology      0   default
# 59   0.005320           rich ecology      0   default
# 60   0.893644           rich ecology      0   default
# 61   0.845080           rich ecology      0   default
# 62   0.734325           rich ecology      0   default
# 63   0.877403           rich ecology      0   default
# 64   0.044919  rich ecology, spatial      0   default
# 65   0.008217  rich ecology, spatial      0   default
# 66   0.102011  rich ecology, spatial      0   default
# 67   0.000160  rich ecology, spatial      0   default
# 68   0.000014  rich ecology, spatial      0   default
# 69   0.000005  rich ecology, spatial      0   default
# 70   0.000016  rich ecology, spatial      0   default
# 71   0.000012  rich ecology, spatial      0   default
# 72   0.262299  rich ecology, spatial      0   default
# 73   0.049498  rich ecology, spatial      0   default
# 74   0.228880  rich ecology, spatial      0   default
# 75   0.000453  rich ecology, spatial      0   default
# 76   0.909931  rich ecology, spatial      0   default
# 77   0.781264  rich ecology, spatial      0   default
# 78   0.958990  rich ecology, spatial      0   default
# 79   0.813017  rich ecology, spatial      0   default
# 80   0.020671      spatial structure      0   default
# 81   0.184622      spatial structure      0   default
# 82   0.000283      spatial structure      0   default
# 83   0.035009      spatial structure      0   default
# 84   0.017518      spatial structure      0   default
# 85   0.044919      spatial structure      0   default
# 86   0.054463      spatial structure      0   default
# 87   0.065641      spatial structure      0   default
# 88   0.171376      spatial structure      0   default
# 89   0.517048      spatial structure      0   default
# 90   0.000359      spatial structure      0   default
# 91   0.382034      spatial structure      0   default
# 92   0.975387      spatial structure      0   default
# 93   0.749871      spatial structure      0   default
# 94   0.734325      spatial structure      0   default
# 95   0.926255      spatial structure      0   default
# 96   0.075213       strong selection      0   default
# 97   0.102011       strong selection      0   default
# 98   0.018519       strong selection      0   default
# 99   0.000020       strong selection      0   default
# 100  0.007271       strong selection      0   default
# 101  0.015658       strong selection      0   default
# 102  0.006424       strong selection      0   default
# 103  0.005667       strong selection      0   default
# 104  0.028486       strong selection      0   default
# 105  0.020671       strong selection      0   default
# 106  0.002957       strong selection      0   default
# 107  0.000008       strong selection      0   default
# 108  0.877403       strong selection      0   default
# 109  0.958990       strong selection      0   default
# 110  0.703564       strong selection      0   default
# 111  0.749871       strong selection      0   default
# 112  0.177907           weak ecology      0   default
# 113  0.001287           weak ecology      0   default
# 114  0.280214           weak ecology      0   default
# 115  0.062683           weak ecology      0   default
# 116  0.130592           weak ecology      0   default
# 117  0.082206           weak ecology      0   default
# 118  0.057096           weak ecology      0   default
# 119  0.198610           weak ecology      0   default
# 120  0.016566           weak ecology      0   default
# 121  0.000003           weak ecology      0   default
# 122  0.036826           weak ecology      0   default
# 123  0.000771           weak ecology      0   default
# 124  0.829013           weak ecology      0   default
# 125  0.877403           weak ecology      0   default
# 126  0.829013           weak ecology      0   default
# 127  0.877403           weak ecology      0   default
# 128  0.120445  weak ecology, spatial      0   default
# 129  0.005667  weak ecology, spatial      0   default
# 130  0.198610  weak ecology, spatial      0   default
# 131  0.369525  weak ecology, spatial      0   default
# 132  0.078647  weak ecology, spatial      0   default
# 133  0.120445  weak ecology, spatial      0   default
# 134  0.054463  weak ecology, spatial      0   default
# 135  0.082206  weak ecology, spatial      0   default
# 136  0.221022  weak ecology, spatial      0   default
# 137  0.005320  weak ecology, spatial      0   default
# 138  0.262299  weak ecology, spatial      0   default
# 139  0.571646  weak ecology, spatial      0   default
# 140  0.991795  weak ecology, spatial      0   default
# 141  0.975387  weak ecology, spatial      0   default
# 142  0.893644  weak ecology, spatial      0   default
# 143  0.893644  weak ecology, spatial      0   default
# 144  0.125438         weak selection      0   default
# 145  0.000174         weak selection      0   default
# 146  0.003162         weak selection      0   default
# 147  0.141390         weak selection      0   default
# 148  0.078647         weak selection      0   default
# 149  0.016566         weak selection      0   default
# 150  0.036826         weak selection      0   default
# 151  0.049498         weak selection      0   default
# 152  0.017518         weak selection      0   default
# 153  0.000003         weak selection      0   default
# 154  0.000205         weak selection      0   default
# 155  0.038723         weak selection      0   default
# 156  0.688359         weak selection      0   default
# 157  0.877403         weak selection      0   default
# 158  0.599936         weak selection      0   default
# 159  0.909931         weak selection      0   default

# %%
for group, group_df in out_df[
    out_df["regime"].isin(
        [
            "plain",
            "weak selection",
            "strong selection",
            "spatial structure",
            "weak ecology",
            "ecology",
            "rich ecology",
        ],
    )
].groupby(
    sensitivity_analysis_variables, as_index=False
):
    group_df["quality threshold"] = group_df["quality"]
    group_df.loc[group_df["p"] > 0.05, "quality threshold"] = ""
    summarized_df = (
        group_df.groupby(["regime", "phylometric"])
        .agg(
            {
                "quality threshold": lambda subgroup: (
                    np.nan
                    if "1% resolution" in set(subgroup)
                    else 1
                    if "3% resolution" in set(subgroup)
                    else 3
                    if "10% resolution" in set(subgroup)
                    else 10
                    if "33% resolution" in set(subgroup)
                    else 33
                ),
                "epoch": lambda subgroup: ip.pophomogeneous(subgroup),
                "mut_distn": lambda subgroup: ip.pophomogeneous(subgroup),
            }
        )
        .reset_index()
    )

    matrix = summarized_df.pivot(
        index="phylometric",
        columns="regime",
        values="quality threshold",
    )
    matrix = matrix[
        sorted(
            matrix.columns,
            key=[
                "plain",
                "weak selection",
                "strong selection",
                "spatial structure",
                "weak ecology",
                "ecology",
                "rich ecology",
            ].index,
        )
    ]

    fig, ax = plt.subplots(figsize=(15, 5))
    formatter = mpl.ticker.ScalarFormatter(useMathText=True)
    formatter.set_scientific(False)
    tp.tee(
        sns.heatmap,
        matrix,
        linewidths=2,
        norm=mpl.colors.LogNorm(vmin=1, vmax=33),
        cmap=sns.color_palette("hls", as_cmap=True),
        center=0,
        cbar_kws={
            "label": "reconstruction error insignificance threshold",
            "ticks": [1, 3, 10, 33],
            "format": formatter,
        },
        teeplot_outattrs={
            **dict(
                zip(sensitivity_analysis_variables, group),
            ),
            **{
                "hue": "quality-threshold",
                "x": "regime",
                "y": "phylometric",
            },
        },
        vmin=1,
        vmax=33,
    )

summarized_df
# Out:
# teeplots/epoch=0+hue=quality-threshold+mut_distn=default+viz=heatmap+x=regime+y=phylometric+ext=.pdf
# teeplots/epoch=0+hue=quality-threshold+mut_distn=default+viz=heatmap+x=regime+y=phylometric+ext=.png
#                regime                        phylometric  quality threshold  \
# 0             ecology                 colless_like_index                3.0
# 1             ecology  mean_evolutionary_distinctiveness                NaN
# 2             ecology             mean_pairwise_distance                1.0
# 3             ecology                       sum_distance               33.0
# 4               plain                 colless_like_index                3.0
# 5               plain  mean_evolutionary_distinctiveness                3.0
# 6               plain             mean_pairwise_distance                3.0
# 7               plain                       sum_distance               33.0
# 8        rich ecology                 colless_like_index                NaN
# 9        rich ecology  mean_evolutionary_distinctiveness                NaN
# 10       rich ecology             mean_pairwise_distance                NaN
# 11       rich ecology                       sum_distance               33.0
# 12  spatial structure                 colless_like_index                1.0
# 13  spatial structure  mean_evolutionary_distinctiveness                NaN
# 14  spatial structure             mean_pairwise_distance               10.0
# 15  spatial structure                       sum_distance               33.0
# 16   strong selection                 colless_like_index                3.0
# 17   strong selection  mean_evolutionary_distinctiveness                NaN
# 18   strong selection             mean_pairwise_distance                NaN
# 19   strong selection                       sum_distance               33.0
# 20       weak ecology                 colless_like_index               10.0
# 21       weak ecology  mean_evolutionary_distinctiveness               33.0
# 22       weak ecology             mean_pairwise_distance                NaN
# 23       weak ecology                       sum_distance               33.0
# 24     weak selection                 colless_like_index                3.0
# 25     weak selection  mean_evolutionary_distinctiveness                NaN
# 26     weak selection             mean_pairwise_distance                NaN
# 27     weak selection                       sum_distance               33.0
#
#     epoch mut_distn
# 0       0   default
# 1       0   default
# 2       0   default
# 3       0   default
# 4       0   default
# 5       0   default
# 6       0   default
# 7       0   default
# 8       0   default
# 9       0   default
# 10      0   default
# 11      0   default
# 12      0   default
# 13      0   default
# 14      0   default
# 15      0   default
# 16      0   default
# 17      0   default
# 18      0   default
# 19      0   default
# 20      0   default
# 21      0   default
# 22      0   default
# 23      0   default
# 24      0   default
# 25      0   default
# 26      0   default
# 27      0   default
