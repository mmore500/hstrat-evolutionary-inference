# %%
from matplotlib import pyplot as plt
from nbmetalog import nbmetalog as nbm
import seaborn as sns
from teeplot import teeplot as tp

# %%
from pylib import example

# %%
nbm.print_metadata()
# Out:
# context: ci
# hostname: 9167cae5a240
# interpreter: 3.8.12 (default, Jan 15 2022, 18:39:47)  [GCC 7.5.0]
# nbcellexec: 3
# nbname: example
# nbpath: /opt/hstrat-evolutionary-inference/binder/example/example.ipynb
# revision: null
# session: 0bdc7ad1-8292-418a-a62b-b7738424ba09
# timestamp: 2023-05-07T01:06:21Z00:00
#
#
# IPython==7.16.1
# keyname==0.5.2
# yaml==6.0
# matplotlib==3.7.1
# nbmetalog==0.2.6
# seaborn==0.12.1
# teeplot==0.5.0
# re==2.2.1
# ipython_genutils==0.2.0
# logging==0.5.1.2
# zmq==22.0.3
# json==2.0.9
# six==1.16.0
# ipykernel==5.5.3

# %%
nbm.print_dataframe_synopsis(sns.load_dataset('fmri'))
# Out:
# digest: 8ce0b36ad848674ec5ee08eeed687a1cecc596874929efe703097585b57c8065
# manifest:
#   event: '     2#     ex., stim'
#   region: '    2#     ex., parietal'
#   signal: '    1064#  ex., -0.017551581538'
#   subject: '   14#    ex., s13'
#   timepoint: ' 19#    ex., 18'
# num cols: 5
# num cols all na: 0
# num cols any na: 0
# num na: 0
# num rows: 1064
# num rows all na: 0
# num rows any na: 0
# size: 208K

# %%
tp.tee(
    sns.lineplot,
    x='timepoint',
    y='signal',
    hue='region',
    style='event',
    data=sns.load_dataset('fmri'),
    teeplot_outattrs={
        **{
            'custom' : 'attr',
        },
        **nbm.collate_outattr_metadata(),
    },
)
plt.show()
# Out:
# teeplots/./custom=attr+hue=region+style=event+viz=lineplot+x=timepoint+y=signal+ext=.pdf
# teeplots/./custom=attr+hue=region+style=event+viz=lineplot+x=timepoint+y=signal+ext=.png
