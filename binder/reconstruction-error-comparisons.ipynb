# %%
import os

from iterpop import iterpop as ip
from keyname import keyname as kn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats as scipy_stats
import seaborn as sns
from teeplot import teeplot

# %%
df = pd.read_csv("https://osf.io/ck47r/download")

# %%
evolutionary_variables = [
    "mut_distn",  # sensitivity analysis
    "num_generations",  # sensitivity analysis
    "num_islands",
    "num_niches",
    "p_island_migration",  # sensitivity analysis
    "p_niche_invasion",  # sensitivity analysis
    "population_size",  # doesn't change
    "tournament_size",
]

# %%
sensitivity_analysis_variables = [
    "epoch",
    "mut_distn",
]

# %%
fixed_variables = [
    "num_generations",  # homogeneous (num generations per epoch)
    "p_island_migration",  # homogeneous
    "population_size",  # homogeneous
    "subsampling-fraction",  # only use 1.0
    "trie-postprocess",  # just use naive postprocessing for now
]

# %%
# ensure fixed variables
df = df[
    (df["p_island_migration"] == 0.01)
    & ((df["subsampling-fraction"] == 1.0) | df["subsampling-fraction"].isna())
    & ((df["trie-postprocess"] == "naive") | df["trie-postprocess"].isna())
].copy()

for fixed_variable in fixed_variables:
    assert len(df[fixed_variable].dropna().unique()) == 1

df
# Out:
#                         a  epoch                  mut_distn  num_generations  \
# 2      reconstructed-tree      0  np.random.standard_normal            32768
# 3      reconstructed-tree      0  np.random.standard_normal            32768
# 8      reconstructed-tree      0  np.random.standard_normal            32768
# 10     reconstructed-tree      0  np.random.standard_normal            32768
# 12     reconstructed-tree      0  np.random.standard_normal            32768
# ...                   ...    ...                        ...              ...
# 50391  reconstructed-tree      7      np.random.exponential            32768
# 50394  reconstructed-tree      7      np.random.exponential            32768
# 50395  reconstructed-tree      7      np.random.exponential            32768
# 50396  reconstructed-tree      7      np.random.exponential            32768
# 50399  reconstructed-tree      7      np.random.exponential            32768
#
#        num_islands  num_niches  p_island_migration  p_niche_invasion  \
# 2                1           8                0.01      3.051758e-08
# 3                1           8                0.01      3.051758e-08
# 8                1           8                0.01      3.051758e-08
# 10               1           8                0.01      3.051758e-08
# 12               1           8                0.01      3.051758e-08
# ...            ...         ...                 ...               ...
# 50391         1024           4                0.01      3.051758e-06
# 50394         1024           4                0.01      3.051758e-06
# 50395         1024           4                0.01      3.051758e-06
# 50396         1024           4                0.01      3.051758e-06
# 50399         1024           4                0.01      3.051758e-06
#
#        population_size  replicate  ...  subsampling-fraction  tournament_size  \
# 2                32768         22  ...                   1.0                2
# 3                32768         36  ...                   1.0                2
# 8                32768          7  ...                   1.0                2
# 10               32768         38  ...                   1.0                2
# 12               32768         30  ...                   1.0                2
# ...                ...        ...  ...                   ...              ...
# 50391            32768          8  ...                   1.0                2
# 50394            32768         11  ...                   1.0                2
# 50395            32768         17  ...                   1.0                2
# 50396            32768         44  ...                   1.0                2
# 50399            32768         33  ...                   1.0                2
#
#        treatment  trie-postprocess _generation  _index      ext  \
# 2             20             naive       32768     636  .csv.gz
# 3             20             naive       32768    1028  .csv.gz
# 8             20             naive       32768     216  .csv.gz
# 10            20             naive       32768    1084  .csv.gz
# 12            20             naive       32768     860  .csv.gz
# ...          ...               ...         ...     ...      ...
# 50391         25             naive      262144     249  .csv.gz
# 50394         25             naive      262144     333  .csv.gz
# 50395         25             naive      262144     501  .csv.gz
# 50396         25             naive      262144    1257  .csv.gz
# 50399         25             naive      262144     949  .csv.gz
#
#                                                        _ triplet_distance  \
# 2      /mnt/home/mmore500/scratch/data/hstrat-evoluti...     9.568345e-02
# 3      /mnt/home/mmore500/scratch/data/hstrat-evoluti...     6.547799e-04
# 8      /mnt/home/mmore500/scratch/data/hstrat-evoluti...     1.120701e-05
# 10     /mnt/home/mmore500/scratch/data/hstrat-evoluti...     1.723737e-04
# 12     /mnt/home/mmore500/scratch/data/hstrat-evoluti...     1.189480e-01
# ...                                                  ...              ...
# 50391  /mnt/home/mmore500/scratch/data/hstrat-evoluti...     2.817044e-03
# 50394  /mnt/home/mmore500/scratch/data/hstrat-evoluti...     1.390141e-04
# 50395  /mnt/home/mmore500/scratch/data/hstrat-evoluti...     9.652896e-11
# 50396  /mnt/home/mmore500/scratch/data/hstrat-evoluti...     6.865545e-04
# 50399  /mnt/home/mmore500/scratch/data/hstrat-evoluti...     5.986630e-04
#
#        quartet_distance
# 2          1.006780e-01
# 3          2.322835e-03
# 8          4.261369e-05
# 10         6.271271e-04
# 12         8.837823e-02
# ...                 ...
# 50391      8.520046e-03
# 50394      4.943354e-04
# 50395      3.860717e-10
# 50396      2.452341e-03
# 50399      1.973535e-03
#
# [16800 rows x 21 columns]

# %%
# exclude extraneous variable values
df = df[(df["a"] == "reconstructed-tree")].copy()

df
# Out:
#                         a  epoch                  mut_distn  num_generations  \
# 2      reconstructed-tree      0  np.random.standard_normal            32768
# 3      reconstructed-tree      0  np.random.standard_normal            32768
# 8      reconstructed-tree      0  np.random.standard_normal            32768
# 10     reconstructed-tree      0  np.random.standard_normal            32768
# 12     reconstructed-tree      0  np.random.standard_normal            32768
# ...                   ...    ...                        ...              ...
# 50391  reconstructed-tree      7      np.random.exponential            32768
# 50394  reconstructed-tree      7      np.random.exponential            32768
# 50395  reconstructed-tree      7      np.random.exponential            32768
# 50396  reconstructed-tree      7      np.random.exponential            32768
# 50399  reconstructed-tree      7      np.random.exponential            32768
#
#        num_islands  num_niches  p_island_migration  p_niche_invasion  \
# 2                1           8                0.01      3.051758e-08
# 3                1           8                0.01      3.051758e-08
# 8                1           8                0.01      3.051758e-08
# 10               1           8                0.01      3.051758e-08
# 12               1           8                0.01      3.051758e-08
# ...            ...         ...                 ...               ...
# 50391         1024           4                0.01      3.051758e-06
# 50394         1024           4                0.01      3.051758e-06
# 50395         1024           4                0.01      3.051758e-06
# 50396         1024           4                0.01      3.051758e-06
# 50399         1024           4                0.01      3.051758e-06
#
#        population_size  replicate  ...  subsampling-fraction  tournament_size  \
# 2                32768         22  ...                   1.0                2
# 3                32768         36  ...                   1.0                2
# 8                32768          7  ...                   1.0                2
# 10               32768         38  ...                   1.0                2
# 12               32768         30  ...                   1.0                2
# ...                ...        ...  ...                   ...              ...
# 50391            32768          8  ...                   1.0                2
# 50394            32768         11  ...                   1.0                2
# 50395            32768         17  ...                   1.0                2
# 50396            32768         44  ...                   1.0                2
# 50399            32768         33  ...                   1.0                2
#
#        treatment  trie-postprocess _generation  _index      ext  \
# 2             20             naive       32768     636  .csv.gz
# 3             20             naive       32768    1028  .csv.gz
# 8             20             naive       32768     216  .csv.gz
# 10            20             naive       32768    1084  .csv.gz
# 12            20             naive       32768     860  .csv.gz
# ...          ...               ...         ...     ...      ...
# 50391         25             naive      262144     249  .csv.gz
# 50394         25             naive      262144     333  .csv.gz
# 50395         25             naive      262144     501  .csv.gz
# 50396         25             naive      262144    1257  .csv.gz
# 50399         25             naive      262144     949  .csv.gz
#
#                                                        _ triplet_distance  \
# 2      /mnt/home/mmore500/scratch/data/hstrat-evoluti...     9.568345e-02
# 3      /mnt/home/mmore500/scratch/data/hstrat-evoluti...     6.547799e-04
# 8      /mnt/home/mmore500/scratch/data/hstrat-evoluti...     1.120701e-05
# 10     /mnt/home/mmore500/scratch/data/hstrat-evoluti...     1.723737e-04
# 12     /mnt/home/mmore500/scratch/data/hstrat-evoluti...     1.189480e-01
# ...                                                  ...              ...
# 50391  /mnt/home/mmore500/scratch/data/hstrat-evoluti...     2.817044e-03
# 50394  /mnt/home/mmore500/scratch/data/hstrat-evoluti...     1.390141e-04
# 50395  /mnt/home/mmore500/scratch/data/hstrat-evoluti...     9.652896e-11
# 50396  /mnt/home/mmore500/scratch/data/hstrat-evoluti...     6.865545e-04
# 50399  /mnt/home/mmore500/scratch/data/hstrat-evoluti...     5.986630e-04
#
#        quartet_distance
# 2          1.006780e-01
# 3          2.322835e-03
# 8          4.261369e-05
# 10         6.271271e-04
# 12         8.837823e-02
# ...                 ...
# 50391      8.520046e-03
# 50394      4.943354e-04
# 50395      3.860717e-10
# 50396      2.452341e-03
# 50399      1.973535e-03
#
# [16800 rows x 21 columns]

# %%
df["regime"] = df.apply(
    lambda row: {
        (1, 1, 2, 3.0517578125e-08): "plain",
        (1, 1, 1, 3.0517578125e-08): "weak selection",
        (1, 1, 4, 3.0517578125e-08): "strong selection",
        (1, 1, 8, 3.0517578125e-08): "weak selection",
        (1, 4, 2, 3.0517578125e-06): "weak ecology",
        (1, 4, 2, 3.0517578125e-08): "ecology",
        (1, 8, 2, 3.0517578125e-08): "rich ecology",
        (1024, 1, 2, 3.0517578125e-08): "spatial structure",
    }.get(
        tuple(
            row[
                [
                    "num_islands",
                    "num_niches",
                    "tournament_size",
                    "p_niche_invasion",
                ]
            ]
        ),
        np.nan,  # default
    ),
    axis="columns",
)
df = df.dropna(axis="index", subset=["regime"]).copy()
df["regime"].unique()
# Out:
# array(['rich ecology', 'weak ecology', 'spatial structure',
#        'strong selection', 'weak selection', 'plain', 'ecology'],
#       dtype=object)

# %%
df["quality"] = df.apply(
    lambda row: {
        ("reconstructed-tree", 3.0): "33% resolution",
        ("reconstructed-tree", 10.0): "10% resolution",
        ("reconstructed-tree", 30.0): "3% resolution",
        ("reconstructed-tree", 100.0): "1% resolution",
    }.get(
        tuple(row[["a", "resolution"]].fillna(0)),
        np.nan,  # default
    ),
    axis="columns",
)
df = df.dropna(axis="index", subset=["quality"]).copy()
df["quality"].unique()
# Out:
# array(['33% resolution', '10% resolution', '1% resolution',
#        '3% resolution'], dtype=object)

# %%
records = []
for phylometric in ["quartet_distance", "triplet_distance"]:
    for group, group_df in df.groupby(
        ["regime", *sensitivity_analysis_variables], as_index=False
    ):
        kw_result, n = scipy_stats.kruskal(
            *(
                quality_series
                for quality, quality_series in group_df.groupby(["quality"])[
                    phylometric
                ]
            )
        ), ip.pophomogeneous(group_df.groupby(["quality"]).count()["a"])
        records.append(
            {
                **{
                    "n": n,
                    "N": len([*group_df.groupby(["quality"])]),
                    "phylometric": phylometric,
                },
                **dict(zip(["statistic", "p"], kw_result)),
                **dict(
                    zip(["regime", *sensitivity_analysis_variables], group)
                ),
            }
        )

with pd.option_context("display.max_colwidth", None, "display.max_rows", None):
    out_df = (
        pd.DataFrame.from_records(records)
        .sort_values(["phylometric", *sensitivity_analysis_variables])
        .reset_index(drop=True)
    )
    display(out_df)
    os.makedirs("outdata", exist_ok=True)
    out_df.to_csv(
        "outdata/a=reconstruction-error-comparisons-between-resolutions+ext=.csv",
        index=False,
    )
# Out:
#      n  N       phylometric   statistic             p             regime  \
# 0   50  4  quartet_distance  157.594209  6.057488e-34            ecology
# 1   50  4  quartet_distance  148.945755  4.448169e-32              plain
# 2   50  4  quartet_distance  159.370245  2.506309e-34       rich ecology
# 3   50  4  quartet_distance  119.443284  1.017028e-25  spatial structure
# 4   50  4  quartet_distance  128.516346  1.129250e-27   strong selection
# 5   50  4  quartet_distance  141.116119  2.171690e-30       weak ecology
# 6   50  4  quartet_distance  131.510364  2.556070e-28     weak selection
# 7   50  4  quartet_distance  164.675976  1.794465e-35            ecology
# 8   50  4  quartet_distance  158.355188  4.150315e-34              plain
# 9   50  4  quartet_distance  127.673636  1.715440e-27       rich ecology
# 10  50  4  quartet_distance  103.031725  3.463587e-22  spatial structure
# 11  50  4  quartet_distance  147.311009  1.001837e-31   strong selection
# 12  50  4  quartet_distance  166.151343  8.619397e-36       weak ecology
# 13  50  4  quartet_distance  118.020048  2.059797e-25     weak selection
# 14  50  4  quartet_distance  157.122591  7.657030e-34            ecology
# 15  50  4  quartet_distance  159.191570  2.739004e-34              plain
# 16  50  4  quartet_distance  142.605433  1.036683e-30       rich ecology
# 17  50  4  quartet_distance  158.542842  3.780825e-34  spatial structure
# 18  50  4  quartet_distance  128.932107  9.187540e-28   strong selection
# 19  50  4  quartet_distance  131.252143  2.905523e-28       weak ecology
# 20  50  4  quartet_distance  119.549373  9.649069e-26     weak selection
# 21  50  4  quartet_distance  167.321672  4.817808e-36            ecology
# 22  50  4  quartet_distance  159.962699  1.867157e-34              plain
# 23  50  4  quartet_distance  151.142364  1.493933e-32       rich ecology
# 24  50  4  quartet_distance  149.133433  4.052262e-32  spatial structure
# 25  50  4  quartet_distance  151.291534  1.387237e-32   strong selection
# 26  50  4  quartet_distance  138.017278  1.011460e-29       weak ecology
# 27  50  4  quartet_distance  130.600585  4.014615e-28     weak selection
# 28  50  4  quartet_distance  164.357552  2.102154e-35            ecology
# 29  50  4  quartet_distance  155.214794  1.975667e-33              plain
# 30  50  4  quartet_distance  141.444812  1.844682e-30       rich ecology
# 31  50  4  quartet_distance  121.961015  2.917903e-26  spatial structure
# 32  50  4  quartet_distance  129.151499  8.239914e-28   strong selection
# 33  50  4  quartet_distance  136.833970  1.819943e-29       weak ecology
# 34  50  4  quartet_distance  139.508884  4.823386e-30     weak selection
# 35  50  4  quartet_distance  152.828072  6.466390e-33            ecology
# 36  50  4  quartet_distance  165.873278  9.896888e-36              plain
# 37  50  4  quartet_distance  144.047057  5.067053e-31       rich ecology
# 38  50  4  quartet_distance  147.246364  1.034524e-31  spatial structure
# 39  50  4  quartet_distance  147.610006  8.635854e-32   strong selection
# 40  50  4  quartet_distance  154.661266  2.601028e-33       weak ecology
# 41  50  4  quartet_distance  116.140275  5.230986e-25     weak selection
# 42  50  4  triplet_distance  158.152848  4.589279e-34            ecology
# 43  50  4  triplet_distance  141.994245  1.404248e-30              plain
# 44  50  4  triplet_distance  159.007964  3.000646e-34       rich ecology
# 45  50  4  triplet_distance  117.663224  2.458448e-25  spatial structure
# 46  50  4  triplet_distance  121.527343  3.618098e-26   strong selection
# 47  50  4  triplet_distance  137.182173  1.531054e-29       weak ecology
# 48  50  4  triplet_distance  116.758448  3.850192e-25     weak selection
# 49  50  4  triplet_distance  157.145397  7.570756e-34            ecology
# 50  50  4  triplet_distance  151.687093  1.139767e-32              plain
# 51  50  4  triplet_distance  118.783343  1.410762e-25       rich ecology
# 52  50  4  triplet_distance  101.248561  8.375608e-22  spatial structure
# 53  50  4  triplet_distance  145.459701  2.512430e-31   strong selection
# 54  50  4  triplet_distance  164.757612  1.723115e-35       weak ecology
# 55  50  4  triplet_distance  122.519546  2.211890e-26     weak selection
# 56  50  4  triplet_distance  157.034901  7.998015e-34            ecology
# 57  50  4  triplet_distance  149.044167  4.235971e-32              plain
# 58  50  4  triplet_distance  137.017110  1.661788e-29       rich ecology
# 59  50  4  triplet_distance  153.748382  4.093606e-33  spatial structure
# 60  50  4  triplet_distance  132.529946  1.541081e-28   strong selection
# 61  50  4  triplet_distance  126.119582  3.708647e-27       weak ecology
# 62  50  4  triplet_distance  115.134842  8.611014e-25     weak selection
# 63  50  4  triplet_distance  166.789552  6.276452e-36            ecology
# 64  50  4  triplet_distance  146.791881  1.296487e-31              plain
# 65  50  4  triplet_distance  151.940322  1.005045e-32       rich ecology
# 66  50  4  triplet_distance  140.291355  3.270680e-30  spatial structure
# 67  50  4  triplet_distance  145.338687  2.668049e-31   strong selection
# 68  50  4  triplet_distance  130.372955  4.494692e-28       weak ecology
# 69  50  4  triplet_distance  128.900740  9.331652e-28     weak selection
# 70  50  4  triplet_distance  160.935284  1.151560e-34            ecology
# 71  50  4  triplet_distance  143.780549  5.784025e-31              plain
# 72  50  4  triplet_distance  142.343379  1.180745e-30       rich ecology
# 73  50  4  triplet_distance  122.898221  1.833137e-26  spatial structure
# 74  50  4  triplet_distance  128.117158  1.376598e-27   strong selection
# 75  50  4  triplet_distance  121.309648  4.030596e-26       weak ecology
# 76  50  4  triplet_distance  139.276740  5.412586e-30     weak selection
# 77  50  4  triplet_distance  140.299952  3.256749e-30            ecology
# 78  50  4  triplet_distance  160.112788  1.732967e-34              plain
# 79  50  4  triplet_distance  144.615845  3.820224e-31       rich ecology
# 80  50  4  triplet_distance  144.141218  4.835580e-31  spatial structure
# 81  50  4  triplet_distance  141.425660  1.862307e-30   strong selection
# 82  50  4  triplet_distance  148.286603  6.171120e-32       weak ecology
# 83  50  4  triplet_distance  117.503940  2.660479e-25     weak selection
#
#     epoch                  mut_distn
# 0       0      np.random.exponential
# 1       0      np.random.exponential
# 2       0      np.random.exponential
# 3       0      np.random.exponential
# 4       0      np.random.exponential
# 5       0      np.random.exponential
# 6       0      np.random.exponential
# 7       0  np.random.standard_normal
# 8       0  np.random.standard_normal
# 9       0  np.random.standard_normal
# 10      0  np.random.standard_normal
# 11      0  np.random.standard_normal
# 12      0  np.random.standard_normal
# 13      0  np.random.standard_normal
# 14      2      np.random.exponential
# 15      2      np.random.exponential
# 16      2      np.random.exponential
# 17      2      np.random.exponential
# 18      2      np.random.exponential
# 19      2      np.random.exponential
# 20      2      np.random.exponential
# 21      2  np.random.standard_normal
# 22      2  np.random.standard_normal
# 23      2  np.random.standard_normal
# 24      2  np.random.standard_normal
# 25      2  np.random.standard_normal
# 26      2  np.random.standard_normal
# 27      2  np.random.standard_normal
# 28      7      np.random.exponential
# 29      7      np.random.exponential
# 30      7      np.random.exponential
# 31      7      np.random.exponential
# 32      7      np.random.exponential
# 33      7      np.random.exponential
# 34      7      np.random.exponential
# 35      7  np.random.standard_normal
# 36      7  np.random.standard_normal
# 37      7  np.random.standard_normal
# 38      7  np.random.standard_normal
# 39      7  np.random.standard_normal
# 40      7  np.random.standard_normal
# 41      7  np.random.standard_normal
# 42      0      np.random.exponential
# 43      0      np.random.exponential
# 44      0      np.random.exponential
# 45      0      np.random.exponential
# 46      0      np.random.exponential
# 47      0      np.random.exponential
# 48      0      np.random.exponential
# 49      0  np.random.standard_normal
# 50      0  np.random.standard_normal
# 51      0  np.random.standard_normal
# 52      0  np.random.standard_normal
# 53      0  np.random.standard_normal
# 54      0  np.random.standard_normal
# 55      0  np.random.standard_normal
# 56      2      np.random.exponential
# 57      2      np.random.exponential
# 58      2      np.random.exponential
# 59      2      np.random.exponential
# 60      2      np.random.exponential
# 61      2      np.random.exponential
# 62      2      np.random.exponential
# 63      2  np.random.standard_normal
# 64      2  np.random.standard_normal
# 65      2  np.random.standard_normal
# 66      2  np.random.standard_normal
# 67      2  np.random.standard_normal
# 68      2  np.random.standard_normal
# 69      2  np.random.standard_normal
# 70      7      np.random.exponential
# 71      7      np.random.exponential
# 72      7      np.random.exponential
# 73      7      np.random.exponential
# 74      7      np.random.exponential
# 75      7      np.random.exponential
# 76      7      np.random.exponential
# 77      7  np.random.standard_normal
# 78      7  np.random.standard_normal
# 79      7  np.random.standard_normal
# 80      7  np.random.standard_normal
# 81      7  np.random.standard_normal
# 82      7  np.random.standard_normal
# 83      7  np.random.standard_normal

# %%
records = []
for phylometric in ["quartet_distance", "triplet_distance"]:
    for group, group_df in df.groupby(
        ["quality", *sensitivity_analysis_variables], as_index=False
    ):
        kw_result, n = scipy_stats.kruskal(
            *(
                quality_series
                for quality, quality_series in group_df.groupby(["regime"])[
                    phylometric
                ]
            )
        ), ip.pophomogeneous(group_df.groupby(["regime"]).count()["a"])
        records.append(
            {
                **{
                    "n": n,
                    "N": len([*group_df.groupby(["regime"])]),
                    "phylometric": phylometric,
                },
                **dict(zip(["statistic", "p"], kw_result)),
                **dict(
                    zip(["quality", *sensitivity_analysis_variables], group)
                ),
            }
        )

with pd.option_context("display.max_colwidth", None, "display.max_rows", None):
    out_df = (
        pd.DataFrame.from_records(records)
        .sort_values(["phylometric", *sensitivity_analysis_variables])
        .reset_index(drop=True)
    )
    display(out_df)
    os.makedirs("outdata", exist_ok=True)
    out_df.to_csv(
        "outdata/a=reconstruction-error-comparisons-between-regimes+ext=.csv",
        index=False,
    )
# Out:
#      n  N       phylometric   statistic             p         quality  epoch  \
# 0   50  7  quartet_distance   65.935566  2.778141e-12   1% resolution      0
# 1   50  7  quartet_distance  117.932925  4.426886e-23  10% resolution      0
# 2   50  7  quartet_distance   52.914004  1.221017e-09   3% resolution      0
# 3   50  7  quartet_distance  115.721248  1.288829e-22  33% resolution      0
# 4   50  7  quartet_distance   38.789497  7.870770e-07   1% resolution      0
# 5   50  7  quartet_distance   88.340497  6.698731e-17  10% resolution      0
# 6   50  7  quartet_distance   38.149798  1.050097e-06   3% resolution      0
# 7   50  7  quartet_distance  120.202764  1.477372e-23  33% resolution      0
# 8   50  7  quartet_distance  107.742711  6.050249e-21   1% resolution      2
# 9   50  7  quartet_distance  147.547976  2.552190e-29  10% resolution      2
# 10  50  7  quartet_distance   70.234428  3.660319e-13   3% resolution      2
# 11  50  7  quartet_distance  194.434000  2.901226e-39  33% resolution      2
# 12  50  7  quartet_distance   96.988960  1.065064e-18   1% resolution      2
# 13  50  7  quartet_distance  102.784778  6.580119e-20  10% resolution      2
# 14  50  7  quartet_distance   50.744694  3.332893e-09   3% resolution      2
# 15  50  7  quartet_distance  161.915636  2.326387e-32  33% resolution      2
# 16  50  7  quartet_distance   63.672303  8.050303e-12   1% resolution      7
# 17  50  7  quartet_distance   95.970844  1.735724e-18  10% resolution      7
# 18  50  7  quartet_distance   38.626399  8.471532e-07   3% resolution      7
# 19  50  7  quartet_distance  171.438605  2.227610e-34  33% resolution      7
# 20  50  7  quartet_distance   83.149882  7.975357e-16   1% resolution      7
# 21  50  7  quartet_distance  139.951269  1.026225e-27  10% resolution      7
# 22  50  7  quartet_distance   45.430548  3.843081e-08   3% resolution      7
# 23  50  7  quartet_distance  178.353446  7.590208e-36  33% resolution      7
# 24  50  7  triplet_distance   65.050510  4.212710e-12   1% resolution      0
# 25  50  7  triplet_distance  125.224994  1.299871e-24  10% resolution      0
# 26  50  7  triplet_distance   60.081895  4.331843e-11   3% resolution      0
# 27  50  7  triplet_distance   77.065233  1.440974e-14  33% resolution      0
# 28  50  7  triplet_distance   38.793319  7.857215e-07   1% resolution      0
# 29  50  7  triplet_distance   93.797572  4.919539e-18  10% resolution      0
# 30  50  7  triplet_distance   39.049889  6.998226e-07   3% resolution      0
# 31  50  7  triplet_distance   57.029587  1.801898e-10  33% resolution      0
# 32  50  7  triplet_distance  107.760352  5.999045e-21   1% resolution      2
# 33  50  7  triplet_distance  122.682444  4.451211e-24  10% resolution      2
# 34  50  7  triplet_distance   63.883897  7.288808e-12   3% resolution      2
# 35  50  7  triplet_distance  122.469916  4.933404e-24  33% resolution      2
# 36  50  7  triplet_distance   88.779358  5.431281e-17   1% resolution      2
# 37  50  7  triplet_distance  112.393069  6.426839e-22  10% resolution      2
# 38  50  7  triplet_distance   47.078369  1.804982e-08   3% resolution      2
# 39  50  7  triplet_distance  101.316993  1.332633e-19  33% resolution      2
# 40  50  7  triplet_distance   63.561272  8.481134e-12   1% resolution      7
# 41  50  7  triplet_distance  101.185887  1.419311e-19  10% resolution      7
# 42  50  7  triplet_distance   39.763794  5.068817e-07   3% resolution      7
# 43  50  7  triplet_distance  134.864051  1.214018e-26  33% resolution      7
# 44  50  7  triplet_distance   83.324804  7.337496e-16   1% resolution      7
# 45  50  7  triplet_distance  136.293415  6.065474e-27  10% resolution      7
# 46  50  7  triplet_distance   44.409045  6.132245e-08   3% resolution      7
# 47  50  7  triplet_distance  114.529528  2.291601e-22  33% resolution      7
#
#                     mut_distn
# 0       np.random.exponential
# 1       np.random.exponential
# 2       np.random.exponential
# 3       np.random.exponential
# 4   np.random.standard_normal
# 5   np.random.standard_normal
# 6   np.random.standard_normal
# 7   np.random.standard_normal
# 8       np.random.exponential
# 9       np.random.exponential
# 10      np.random.exponential
# 11      np.random.exponential
# 12  np.random.standard_normal
# 13  np.random.standard_normal
# 14  np.random.standard_normal
# 15  np.random.standard_normal
# 16      np.random.exponential
# 17      np.random.exponential
# 18      np.random.exponential
# 19      np.random.exponential
# 20  np.random.standard_normal
# 21  np.random.standard_normal
# 22  np.random.standard_normal
# 23  np.random.standard_normal
# 24      np.random.exponential
# 25      np.random.exponential
# 26      np.random.exponential
# 27      np.random.exponential
# 28  np.random.standard_normal
# 29  np.random.standard_normal
# 30  np.random.standard_normal
# 31  np.random.standard_normal
# 32      np.random.exponential
# 33      np.random.exponential
# 34      np.random.exponential
# 35      np.random.exponential
# 36  np.random.standard_normal
# 37  np.random.standard_normal
# 38  np.random.standard_normal
# 39  np.random.standard_normal
# 40      np.random.exponential
# 41      np.random.exponential
# 42      np.random.exponential
# 43      np.random.exponential
# 44  np.random.standard_normal
# 45  np.random.standard_normal
# 46  np.random.standard_normal
# 47  np.random.standard_normal
