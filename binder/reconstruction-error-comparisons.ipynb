# %%
import os

from iterpop import iterpop as ip
from keyname import keyname as kn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats as scipy_stats
import seaborn as sns
from teeplot import teeplot

# %%
df = pd.read_csv("https://osf.io/ck47r/download")

# %%
# phylometrics whittled down to descriptive, non-redundant set
phylometrics = [
    #     'diversity',
    "colless_like_index",
    #     'average_depth',
    #     'average_origin_time',
    #     'average_origin_time_normalized',
    #     'max_depth',
    "mean_pairwise_distance",
    #     'mean_pairwise_distance_branch_only',
    #     'num_active',
    "num_ancestors",
    #     'num_outside',
    #     'num_roots',
    #     'num_taxa',
    #     'phylogenetic_diversity',
    #     'sum_pairwise_distance',
    #     'sum_pairwise_distance_branch_only',
    #     'total_orgs',
    #     'tree_size',
    #     'variance_pairwise_distance',
    #     'variance_pairwise_distance_branch_only',
    #     'mrca_depth',
    #     'sackin_index',
    "mean_evolutionary_distinctiveness",
    #     'sum_evolutionary_distinctiveness',
    #     'variance_evolutionary_distinctiveness',
]

# %%
evolutionary_variables = [
    "mut_distn",  # sensitivity analysis
    "num_generations",  # sensitivity analysis
    "num_islands",
    "num_niches",
    "p_island_migration",  # sensitivity analysis
    "p_niche_invasion",  # sensitivity analysis
    "population_size",  # doesn't change
    "tournament_size",
]

# %%
sensitivity_analysis_variables = [
    "epoch",
    "mut_distn",
]

# %%
fixed_variables = [
    "num_generations",  # homogeneous (num generations per epoch)
    "p_island_migration",  # homogeneous
    "population_size",  # homogeneous
    "subsampling-fraction",  # only use 1.0
    "trie-postprocess",  # just use naive postprocessing for now
]

# %%
# ensure fixed variables
df = df[
    (df["p_island_migration"] == 0.01)
    & ((df["subsampling-fraction"] == 1.0) | df["subsampling-fraction"].isna())
    & ((df["trie-postprocess"] == "naive") | df["trie-postprocess"].isna())
].copy()

for fixed_variable in fixed_variables:
    assert len(df[fixed_variable].dropna().unique()) == 1

df
# Out:
#                          a  epoch                  mut_distn  num_generations  \
# 7       reconstructed-tree      0  np.random.standard_normal            32768
# 9       reconstructed-tree      0  np.random.standard_normal            32768
# 19      reconstructed-tree      0  np.random.standard_normal            32768
# 21      reconstructed-tree      0  np.random.standard_normal            32768
# 23      reconstructed-tree      0  np.random.standard_normal            32768
# ...                    ...    ...                        ...              ...
# 100783  reconstructed-tree      7      np.random.exponential            32768
# 100790  reconstructed-tree      7      np.random.exponential            32768
# 100792  reconstructed-tree      7      np.random.exponential            32768
# 100795  reconstructed-tree      7      np.random.exponential            32768
# 100799  reconstructed-tree      7      np.random.exponential            32768
#
#         num_islands  num_niches  p_island_migration  p_niche_invasion  \
# 7                 1           8                0.01      3.051758e-08
# 9                 1           8                0.01      3.051758e-08
# 19                1           8                0.01      3.051758e-08
# 21                1           8                0.01      3.051758e-08
# 23                1           8                0.01      3.051758e-08
# ...             ...         ...                 ...               ...
# 100783         1024           4                0.01      3.051758e-06
# 100790         1024           4                0.01      3.051758e-06
# 100792         1024           4                0.01      3.051758e-06
# 100795         1024           4                0.01      3.051758e-06
# 100799         1024           4                0.01      3.051758e-06
#
#         population_size  replicate  ...  subsampling-fraction  \
# 7                 32768         22  ...                   1.0
# 9                 32768         36  ...                   1.0
# 19                32768          7  ...                   1.0
# 21                32768         38  ...                   1.0
# 23                32768         30  ...                   1.0
# ...                 ...        ...  ...                   ...
# 100783            32768          8  ...                   1.0
# 100790            32768         11  ...                   1.0
# 100792            32768         17  ...                   1.0
# 100795            32768         44  ...                   1.0
# 100799            32768         33  ...                   1.0
#
#         tournament_size  treatment  trie-postprocess _generation  _index  \
# 7                     2         20             naive       32768     636
# 9                     2         20             naive       32768    1028
# 19                    2         20             naive       32768     216
# 21                    2         20             naive       32768    1084
# 23                    2         20             naive       32768     860
# ...                 ...        ...               ...         ...     ...
# 100783                2         25             naive      262144     249
# 100790                2         25             naive      262144     333
# 100792                2         25             naive      262144     501
# 100795                2         25             naive      262144    1257
# 100799                2         25             naive      262144     949
#
#             ext                                                  _  \
# 7       .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 9       .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 19      .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 21      .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 23      .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# ...         ...                                                ...
# 100783  .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 100790  .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 100792  .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 100795  .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 100799  .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
#
#        triplet_distance  quartet_distance
# 7          9.568345e-02      1.006780e-01
# 9          6.547799e-04      2.322835e-03
# 19         1.120701e-05      4.261369e-05
# 21         1.723737e-04      6.271271e-04
# 23         1.189480e-01      8.837823e-02
# ...                 ...               ...
# 100783     2.817044e-03      8.520046e-03
# 100790     1.390141e-04      4.943354e-04
# 100792     9.652896e-11      3.860717e-10
# 100795     6.865545e-04      2.452341e-03
# 100799     5.986630e-04      1.973535e-03
#
# [16800 rows x 21 columns]

# %%
# exclude extraneous variable values
df = df[(df["a"] == "reconstructed-tree")].copy()

df
# Out:
#                          a  epoch                  mut_distn  num_generations  \
# 7       reconstructed-tree      0  np.random.standard_normal            32768
# 9       reconstructed-tree      0  np.random.standard_normal            32768
# 19      reconstructed-tree      0  np.random.standard_normal            32768
# 21      reconstructed-tree      0  np.random.standard_normal            32768
# 23      reconstructed-tree      0  np.random.standard_normal            32768
# ...                    ...    ...                        ...              ...
# 100783  reconstructed-tree      7      np.random.exponential            32768
# 100790  reconstructed-tree      7      np.random.exponential            32768
# 100792  reconstructed-tree      7      np.random.exponential            32768
# 100795  reconstructed-tree      7      np.random.exponential            32768
# 100799  reconstructed-tree      7      np.random.exponential            32768
#
#         num_islands  num_niches  p_island_migration  p_niche_invasion  \
# 7                 1           8                0.01      3.051758e-08
# 9                 1           8                0.01      3.051758e-08
# 19                1           8                0.01      3.051758e-08
# 21                1           8                0.01      3.051758e-08
# 23                1           8                0.01      3.051758e-08
# ...             ...         ...                 ...               ...
# 100783         1024           4                0.01      3.051758e-06
# 100790         1024           4                0.01      3.051758e-06
# 100792         1024           4                0.01      3.051758e-06
# 100795         1024           4                0.01      3.051758e-06
# 100799         1024           4                0.01      3.051758e-06
#
#         population_size  replicate  ...  subsampling-fraction  \
# 7                 32768         22  ...                   1.0
# 9                 32768         36  ...                   1.0
# 19                32768          7  ...                   1.0
# 21                32768         38  ...                   1.0
# 23                32768         30  ...                   1.0
# ...                 ...        ...  ...                   ...
# 100783            32768          8  ...                   1.0
# 100790            32768         11  ...                   1.0
# 100792            32768         17  ...                   1.0
# 100795            32768         44  ...                   1.0
# 100799            32768         33  ...                   1.0
#
#         tournament_size  treatment  trie-postprocess _generation  _index  \
# 7                     2         20             naive       32768     636
# 9                     2         20             naive       32768    1028
# 19                    2         20             naive       32768     216
# 21                    2         20             naive       32768    1084
# 23                    2         20             naive       32768     860
# ...                 ...        ...               ...         ...     ...
# 100783                2         25             naive      262144     249
# 100790                2         25             naive      262144     333
# 100792                2         25             naive      262144     501
# 100795                2         25             naive      262144    1257
# 100799                2         25             naive      262144     949
#
#             ext                                                  _  \
# 7       .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 9       .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 19      .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 21      .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 23      .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# ...         ...                                                ...
# 100783  .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 100790  .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 100792  .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 100795  .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
# 100799  .csv.gz  /mnt/home/mmore500/scratch/data/hstrat-evoluti...
#
#        triplet_distance  quartet_distance
# 7          9.568345e-02      1.006780e-01
# 9          6.547799e-04      2.322835e-03
# 19         1.120701e-05      4.261369e-05
# 21         1.723737e-04      6.271271e-04
# 23         1.189480e-01      8.837823e-02
# ...                 ...               ...
# 100783     2.817044e-03      8.520046e-03
# 100790     1.390141e-04      4.943354e-04
# 100792     9.652896e-11      3.860717e-10
# 100795     6.865545e-04      2.452341e-03
# 100799     5.986630e-04      1.973535e-03
#
# [16800 rows x 21 columns]

# %%
df["regime"] = df.apply(
    lambda row: {
        (1, 1, 2, 3.0517578125e-08): "plain",
        (1, 1, 1, 3.0517578125e-08): "weak selection",
        (1, 1, 4, 3.0517578125e-08): "strong selection",
        (1, 1, 8, 3.0517578125e-08): "weak selection",
        (1, 4, 2, 3.0517578125e-06): "weak 4 niche ecology",
        (1, 4, 2, 3.0517578125e-08): "4 niche ecology",
        (1, 8, 2, 3.0517578125e-08): "8 niche ecology",
        (1024, 1, 2, 3.0517578125e-08): "spatial structure",
    }.get(
        tuple(
            row[
                [
                    "num_islands",
                    "num_niches",
                    "tournament_size",
                    "p_niche_invasion",
                ]
            ]
        ),
        np.nan,  # default
    ),
    axis="columns",
)
df = df.dropna(axis="index", subset=["regime"]).copy()
df["regime"].unique()
# Out:
# array(['8 niche ecology', 'weak 4 niche ecology', 'spatial structure',
#        'strong selection', 'weak selection', 'plain', '4 niche ecology'],
#       dtype=object)

# %%
df["quality"] = df.apply(
    lambda row: {
        ("reconstructed-tree", 3.0): "33% resolution",
        ("reconstructed-tree", 10.0): "10% resolution",
        ("reconstructed-tree", 30.0): "3% resolution",
        ("reconstructed-tree", 100.0): "1% resolution",
    }.get(
        tuple(row[["a", "resolution"]].fillna(0)),
        np.nan,  # default
    ),
    axis="columns",
)
df = df.dropna(axis="index", subset=["quality"]).copy()
df["quality"].unique()
# Out:
# array(['33% resolution', '10% resolution', '1% resolution',
#        '3% resolution'], dtype=object)

# %%
records = []
for phylometric in ["quartet_distance", "triplet_distance"]:
    for group, group_df in df.groupby(
        ["regime", *sensitivity_analysis_variables], as_index=False
    ):
        kw_result, n = scipy_stats.kruskal(
            *(
                quality_series
                for quality, quality_series in group_df.groupby(["quality"])[
                    phylometric
                ]
            )
        ), ip.pophomogeneous(group_df.groupby(["quality"]).count()["a"])
        records.append(
            {
                **{
                    "n": n,
                    "N": len([*group_df.groupby(["quality"])]),
                    "phylometric": phylometric,
                },
                **dict(zip(["statistic", "p"], kw_result)),
                **dict(
                    zip(["regime", *sensitivity_analysis_variables], group)
                ),
            }
        )

with pd.option_context("display.max_colwidth", None, "display.max_rows", None):
    out_df = (
        pd.DataFrame.from_records(records)
        .sort_values(["phylometric", *sensitivity_analysis_variables])
        .reset_index(drop=True)
    )
    display(out_df)
    os.makedirs("outdata", exist_ok=True)
    out_df.to_csv(
        "outdata/a=reconstruction-error-comparisons-between-resolutions+ext=.csv",
        index=False,
    )
# Out:
#      n  N       phylometric   statistic             p                regime  \
# 0   50  4  quartet_distance    1.804036  6.140571e-01       4 niche ecology
# 1   50  4  quartet_distance  147.138830  1.091277e-31       8 niche ecology
# 2   50  4  quartet_distance    3.808119  2.829431e-01                 plain
# 3   50  4  quartet_distance  119.443284  1.017028e-25     spatial structure
# 4   50  4  quartet_distance    3.447104  3.276876e-01      strong selection
# 5   50  4  quartet_distance    1.756621  6.244199e-01  weak 4 niche ecology
# 6   50  4  quartet_distance   89.663200  2.587592e-19        weak selection
# 7   50  4  quartet_distance    3.085409  3.786433e-01       4 niche ecology
# 8   50  4  quartet_distance  112.909099  2.595386e-24       8 niche ecology
# 9   50  4  quartet_distance    1.194113  7.544165e-01                 plain
# 10  50  4  quartet_distance  103.031725  3.463587e-22     spatial structure
# 11  50  4  quartet_distance    2.985982  3.937915e-01      strong selection
# 12  50  4  quartet_distance    3.590770  3.091789e-01  weak 4 niche ecology
# 13  50  4  quartet_distance  100.829421  1.030737e-21        weak selection
# 14  50  4  quartet_distance    3.072119  3.806389e-01       4 niche ecology
# 15  50  4  quartet_distance    3.477815  3.236509e-01       8 niche ecology
# 16  50  4  quartet_distance    2.631510  4.519921e-01                 plain
# 17  50  4  quartet_distance  145.880728  2.038395e-31     spatial structure
# 18  50  4  quartet_distance    1.069648  7.844058e-01      strong selection
# 19  50  4  quartet_distance    0.017875  9.993678e-01  weak 4 niche ecology
# 20  50  4  quartet_distance    1.941110  5.847190e-01        weak selection
# 21  50  4  quartet_distance    5.059761  1.674731e-01       4 niche ecology
# 22  50  4  quartet_distance    2.641337  4.502886e-01       8 niche ecology
# 23  50  4  quartet_distance    9.640107  2.188663e-02                 plain
# 24  50  4  quartet_distance  148.020119  7.044412e-32     spatial structure
# 25  50  4  quartet_distance    2.605624  4.565045e-01      strong selection
# 26  50  4  quartet_distance    2.535104  4.689803e-01  weak 4 niche ecology
# 27  50  4  quartet_distance    0.758878  8.592755e-01        weak selection
# 28  50  4  quartet_distance    0.451284  9.294562e-01       4 niche ecology
# 29  50  4  quartet_distance    0.680179  8.778558e-01       8 niche ecology
# 30  50  4  quartet_distance    1.616645  6.556216e-01                 plain
# 31  50  4  quartet_distance   11.319749  1.011675e-02     spatial structure
# 32  50  4  quartet_distance    4.190937  2.415708e-01      strong selection
# 33  50  4  quartet_distance    0.232848  9.721200e-01  weak 4 niche ecology
# 34  50  4  quartet_distance    6.536454  8.823589e-02        weak selection
# 35  50  4  quartet_distance    1.982985  5.759457e-01       4 niche ecology
# 36  50  4  quartet_distance    7.032358  7.087353e-02       8 niche ecology
# 37  50  4  quartet_distance    0.966997  8.092370e-01                 plain
# 38  50  4  quartet_distance   17.612788  5.285933e-04     spatial structure
# 39  50  4  quartet_distance    2.653958  4.481084e-01      strong selection
# 40  50  4  quartet_distance    0.131009  9.878727e-01  weak 4 niche ecology
# 41  50  4  quartet_distance    1.667379  6.442104e-01        weak selection
# 42  50  4  triplet_distance    1.691761  6.387670e-01       4 niche ecology
# 43  50  4  triplet_distance  155.058710  2.134967e-33       8 niche ecology
# 44  50  4  triplet_distance    3.808119  2.829431e-01                 plain
# 45  50  4  triplet_distance  117.663224  2.458448e-25     spatial structure
# 46  50  4  triplet_distance    3.447104  3.276876e-01      strong selection
# 47  50  4  triplet_distance    1.756621  6.244199e-01  weak 4 niche ecology
# 48  50  4  triplet_distance   88.997099  3.597110e-19        weak selection
# 49  50  4  triplet_distance   14.343224  2.473310e-03       4 niche ecology
# 50  50  4  triplet_distance  111.819355  4.454174e-24       8 niche ecology
# 51  50  4  triplet_distance    1.194113  7.544165e-01                 plain
# 52  50  4  triplet_distance  101.248561  8.375608e-22     spatial structure
# 53  50  4  triplet_distance    2.985982  3.937915e-01      strong selection
# 54  50  4  triplet_distance    3.590770  3.091789e-01  weak 4 niche ecology
# 55  50  4  triplet_distance  103.893636  2.260162e-22        weak selection
# 56  50  4  triplet_distance    3.072119  3.806389e-01       4 niche ecology
# 57  50  4  triplet_distance    6.896131  7.528315e-02       8 niche ecology
# 58  50  4  triplet_distance    2.631510  4.519921e-01                 plain
# 59  50  4  triplet_distance  141.395940  1.889991e-30     spatial structure
# 60  50  4  triplet_distance    1.069648  7.844058e-01      strong selection
# 61  50  4  triplet_distance    0.017875  9.993678e-01  weak 4 niche ecology
# 62  50  4  triplet_distance    1.941110  5.847190e-01        weak selection
# 63  50  4  triplet_distance    4.849230  1.831761e-01       4 niche ecology
# 64  50  4  triplet_distance    8.847881  3.138328e-02       8 niche ecology
# 65  50  4  triplet_distance    9.640107  2.188663e-02                 plain
# 66  50  4  triplet_distance  139.204919  5.609060e-30     spatial structure
# 67  50  4  triplet_distance    2.605624  4.565045e-01      strong selection
# 68  50  4  triplet_distance    2.535104  4.689803e-01  weak 4 niche ecology
# 69  50  4  triplet_distance    0.761588  8.586308e-01        weak selection
# 70  50  4  triplet_distance    0.451284  9.294562e-01       4 niche ecology
# 71  50  4  triplet_distance    0.680179  8.778558e-01       8 niche ecology
# 72  50  4  triplet_distance    1.616645  6.556216e-01                 plain
# 73  50  4  triplet_distance   13.518710  3.639158e-03     spatial structure
# 74  50  4  triplet_distance    4.190937  2.415708e-01      strong selection
# 75  50  4  triplet_distance    0.232848  9.721200e-01  weak 4 niche ecology
# 76  50  4  triplet_distance    6.536454  8.823589e-02        weak selection
# 77  50  4  triplet_distance    1.982985  5.759457e-01       4 niche ecology
# 78  50  4  triplet_distance    7.032358  7.087353e-02       8 niche ecology
# 79  50  4  triplet_distance    0.966997  8.092370e-01                 plain
# 80  50  4  triplet_distance   19.104621  2.601130e-04     spatial structure
# 81  50  4  triplet_distance    2.653958  4.481084e-01      strong selection
# 82  50  4  triplet_distance    0.131009  9.878727e-01  weak 4 niche ecology
# 83  50  4  triplet_distance    1.667379  6.442104e-01        weak selection
#
#     epoch                  mut_distn
# 0       0      np.random.exponential
# 1       0      np.random.exponential
# 2       0      np.random.exponential
# 3       0      np.random.exponential
# 4       0      np.random.exponential
# 5       0      np.random.exponential
# 6       0      np.random.exponential
# 7       0  np.random.standard_normal
# 8       0  np.random.standard_normal
# 9       0  np.random.standard_normal
# 10      0  np.random.standard_normal
# 11      0  np.random.standard_normal
# 12      0  np.random.standard_normal
# 13      0  np.random.standard_normal
# 14      2      np.random.exponential
# 15      2      np.random.exponential
# 16      2      np.random.exponential
# 17      2      np.random.exponential
# 18      2      np.random.exponential
# 19      2      np.random.exponential
# 20      2      np.random.exponential
# 21      2  np.random.standard_normal
# 22      2  np.random.standard_normal
# 23      2  np.random.standard_normal
# 24      2  np.random.standard_normal
# 25      2  np.random.standard_normal
# 26      2  np.random.standard_normal
# 27      2  np.random.standard_normal
# 28      7      np.random.exponential
# 29      7      np.random.exponential
# 30      7      np.random.exponential
# 31      7      np.random.exponential
# 32      7      np.random.exponential
# 33      7      np.random.exponential
# 34      7      np.random.exponential
# 35      7  np.random.standard_normal
# 36      7  np.random.standard_normal
# 37      7  np.random.standard_normal
# 38      7  np.random.standard_normal
# 39      7  np.random.standard_normal
# 40      7  np.random.standard_normal
# 41      7  np.random.standard_normal
# 42      0      np.random.exponential
# 43      0      np.random.exponential
# 44      0      np.random.exponential
# 45      0      np.random.exponential
# 46      0      np.random.exponential
# 47      0      np.random.exponential
# 48      0      np.random.exponential
# 49      0  np.random.standard_normal
# 50      0  np.random.standard_normal
# 51      0  np.random.standard_normal
# 52      0  np.random.standard_normal
# 53      0  np.random.standard_normal
# 54      0  np.random.standard_normal
# 55      0  np.random.standard_normal
# 56      2      np.random.exponential
# 57      2      np.random.exponential
# 58      2      np.random.exponential
# 59      2      np.random.exponential
# 60      2      np.random.exponential
# 61      2      np.random.exponential
# 62      2      np.random.exponential
# 63      2  np.random.standard_normal
# 64      2  np.random.standard_normal
# 65      2  np.random.standard_normal
# 66      2  np.random.standard_normal
# 67      2  np.random.standard_normal
# 68      2  np.random.standard_normal
# 69      2  np.random.standard_normal
# 70      7      np.random.exponential
# 71      7      np.random.exponential
# 72      7      np.random.exponential
# 73      7      np.random.exponential
# 74      7      np.random.exponential
# 75      7      np.random.exponential
# 76      7      np.random.exponential
# 77      7  np.random.standard_normal
# 78      7  np.random.standard_normal
# 79      7  np.random.standard_normal
# 80      7  np.random.standard_normal
# 81      7  np.random.standard_normal
# 82      7  np.random.standard_normal
# 83      7  np.random.standard_normal

# %%
records = []
for phylometric in ["quartet_distance", "triplet_distance"]:
    for group, group_df in df.groupby(
        ["quality", *sensitivity_analysis_variables], as_index=False
    ):
        kw_result, n = scipy_stats.kruskal(
            *(
                quality_series
                for quality, quality_series in group_df.groupby(["regime"])[
                    phylometric
                ]
            )
        ), ip.pophomogeneous(group_df.groupby(["regime"]).count()["a"])
        records.append(
            {
                **{
                    "n": n,
                    "N": len([*group_df.groupby(["regime"])]),
                    "phylometric": phylometric,
                },
                **dict(zip(["statistic", "p"], kw_result)),
                **dict(
                    zip(["quality", *sensitivity_analysis_variables], group)
                ),
            }
        )

with pd.option_context("display.max_colwidth", None, "display.max_rows", None):
    out_df = (
        pd.DataFrame.from_records(records)
        .sort_values(["phylometric", *sensitivity_analysis_variables])
        .reset_index(drop=True)
    )
    display(out_df)
    os.makedirs("outdata", exist_ok=True)
    out_df.to_csv(
        "outdata/a=reconstruction-error-comparisons-between-regimes+ext=.csv",
        index=False,
    )
# Out:
#      n  N       phylometric   statistic             p         quality  epoch  \
# 0   50  7  quartet_distance  219.559076  1.292043e-44   1% resolution      0
# 1   50  7  quartet_distance  203.950785  2.736073e-41  10% resolution      0
# 2   50  7  quartet_distance  212.829484  3.513988e-43   3% resolution      0
# 3   50  7  quartet_distance  212.394385  4.350306e-43  33% resolution      0
# 4   50  7  quartet_distance  205.812665  1.098100e-41   1% resolution      0
# 5   50  7  quartet_distance  194.000965  3.586719e-39  10% resolution      0
# 6   50  7  quartet_distance  206.176684  9.185784e-42   3% resolution      0
# 7   50  7  quartet_distance  210.970925  8.746509e-43  33% resolution      0
# 8   50  7  quartet_distance  124.534939  1.815603e-24   1% resolution      2
# 9   50  7  quartet_distance  116.089061  1.079033e-22  10% resolution      2
# 10  50  7  quartet_distance  111.691675  9.014937e-22   3% resolution      2
# 11  50  7  quartet_distance  107.461736  6.927239e-21  33% resolution      2
# 12  50  7  quartet_distance  117.881596  4.538084e-23   1% resolution      2
# 13  50  7  quartet_distance  111.829677  8.434303e-22  10% resolution      2
# 14  50  7  quartet_distance  116.207160  1.019196e-22   3% resolution      2
# 15  50  7  quartet_distance  126.432141  7.243897e-25  33% resolution      2
# 16  50  7  quartet_distance   15.220032  1.861269e-02   1% resolution      7
# 17  50  7  quartet_distance   19.707085  3.122088e-03  10% resolution      7
# 18  50  7  quartet_distance   20.313831  2.434675e-03   3% resolution      7
# 19  50  7  quartet_distance   39.488496  5.740576e-07  33% resolution      7
# 20  50  7  quartet_distance   44.086802  7.104815e-08   1% resolution      7
# 21  50  7  quartet_distance   45.721600  3.363434e-08  10% resolution      7
# 22  50  7  quartet_distance   42.021275  1.821071e-07   3% resolution      7
# 23  50  7  quartet_distance   41.116105  2.747096e-07  33% resolution      7
# 24  50  7  triplet_distance  219.831389  1.130347e-44   1% resolution      0
# 25  50  7  triplet_distance  205.053515  1.593348e-41  10% resolution      0
# 26  50  7  triplet_distance  213.771585  2.213227e-43   3% resolution      0
# 27  50  7  triplet_distance  221.127979  5.980294e-45  33% resolution      0
# 28  50  7  triplet_distance  205.689526  1.166451e-41   1% resolution      0
# 29  50  7  triplet_distance  194.475600  2.842708e-39  10% resolution      0
# 30  50  7  triplet_distance  205.985555  1.008838e-41   3% resolution      0
# 31  50  7  triplet_distance  213.512451  2.513347e-43  33% resolution      0
# 32  50  7  triplet_distance  124.534939  1.815603e-24   1% resolution      2
# 33  50  7  triplet_distance  117.855891  4.594817e-23  10% resolution      2
# 34  50  7  triplet_distance  112.242454  6.911288e-22   3% resolution      2
# 35  50  7  triplet_distance  115.090239  1.748036e-22  33% resolution      2
# 36  50  7  triplet_distance  118.355087  3.609760e-23   1% resolution      2
# 37  50  7  triplet_distance  111.573478  9.543894e-22  10% resolution      2
# 38  50  7  triplet_distance  116.631006  8.304792e-23   3% resolution      2
# 39  50  7  triplet_distance  134.334800  1.569588e-26  33% resolution      2
# 40  50  7  triplet_distance   15.220032  1.861269e-02   1% resolution      7
# 41  50  7  triplet_distance   19.707085  3.122088e-03  10% resolution      7
# 42  50  7  triplet_distance   20.313831  2.434675e-03   3% resolution      7
# 43  50  7  triplet_distance   42.853052  1.247196e-07  33% resolution      7
# 44  50  7  triplet_distance   44.086802  7.104815e-08   1% resolution      7
# 45  50  7  triplet_distance   45.721600  3.363434e-08  10% resolution      7
# 46  50  7  triplet_distance   42.021275  1.821071e-07   3% resolution      7
# 47  50  7  triplet_distance   44.293771  6.463903e-08  33% resolution      7
#
#                     mut_distn
# 0       np.random.exponential
# 1       np.random.exponential
# 2       np.random.exponential
# 3       np.random.exponential
# 4   np.random.standard_normal
# 5   np.random.standard_normal
# 6   np.random.standard_normal
# 7   np.random.standard_normal
# 8       np.random.exponential
# 9       np.random.exponential
# 10      np.random.exponential
# 11      np.random.exponential
# 12  np.random.standard_normal
# 13  np.random.standard_normal
# 14  np.random.standard_normal
# 15  np.random.standard_normal
# 16      np.random.exponential
# 17      np.random.exponential
# 18      np.random.exponential
# 19      np.random.exponential
# 20  np.random.standard_normal
# 21  np.random.standard_normal
# 22  np.random.standard_normal
# 23  np.random.standard_normal
# 24      np.random.exponential
# 25      np.random.exponential
# 26      np.random.exponential
# 27      np.random.exponential
# 28  np.random.standard_normal
# 29  np.random.standard_normal
# 30  np.random.standard_normal
# 31  np.random.standard_normal
# 32      np.random.exponential
# 33      np.random.exponential
# 34      np.random.exponential
# 35      np.random.exponential
# 36  np.random.standard_normal
# 37  np.random.standard_normal
# 38  np.random.standard_normal
# 39  np.random.standard_normal
# 40      np.random.exponential
# 41      np.random.exponential
# 42      np.random.exponential
# 43      np.random.exponential
# 44  np.random.standard_normal
# 45  np.random.standard_normal
# 46  np.random.standard_normal
# 47  np.random.standard_normal
